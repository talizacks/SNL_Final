# %%
import pandas as pd
import sqlite3
import matplotlib
import ipywidgets
import matplotlib.pyplot as plt
import regex as re

# %% [markdown]
# # IMDb Data
# Found on: https://datasets.imdbws.com/
#
# Lisence: Subsets of IMDb data are available for access to customers for personal and non-commercial use. https://help.imdb.com/article/imdb/general-information/can-i-use-imdb-data-in-my-software/G5JTRESSHJBBHTGX?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=3aefe545-f8d3-4562-976a-e5eb47d1bb18&pf_rd_r=4T3EYTP8F7MDAN370387&pf_rd_s=center-1&pf_rd_t=60601&pf_rd_i=interfaces&ref_=fea_mn_lk1
#
# - name.basics.tsv.gz – Contains the following information for names:
#     - nconst (string) - alphanumeric unique identifier of the name/person
#     - primaryName (string)– name by which the person is most often credited
#     - birthYear – in YYYY format
#     - deathYear – in YYYY format if applicable, else '\N'
#     - primaryProfession (array of strings)– the top-3 professions of the person
#     - knownForTitles (array of tconsts) – titles the person is known for
# - title.basics.tsv.gz - Contains the following information for titles:
#     - tconst (string) - alphanumeric unique identifier of the title
#     - titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
#     - primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
#     - originalTitle (string) - original title, in the original language
#     - isAdult (boolean) - 0: non-adult title; 1: adult title
#     - startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
#     - endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
#     - runtimeMinutes – primary runtime of the title, in minutes
#     - genres (string array) – includes up to three genres associated with the title
# - title.principals.tsv.gz – Contains the principal cast/crew for titles
#     - tconst (string) - alphanumeric unique identifier of the title
#     - ordering (integer) – a number to uniquely identify rows for a given titleId
#     - nconst (string) - alphanumeric unique identifier of the name/person
#     - category (string) - the category of job that person was in
#     - job (string) - the specific job title if applicable, else '\N'
#     - characters (string) - the name of the character played if applicable, else '\N'
#
# These files are essentially all of the IMDb data so the unzipped files are HUGE! Therefore, I included them in my .gitignore file.

# %%
# !pwd
# Out:
# /Users/tzacks2/Desktop/GradSchool/Spring22/SNL_Final

# %%
principals = pd.read_csv('Imdb_data/title.principals.tsv',delimiter='\t')
basics = pd.read_csv('Imdb_data/title.basics.tsv',delimiter='\t')
imdb_names = pd.read_csv('Imdb_data/name.basics.tsv',delimiter='\t')
# Out:
# /Users/tzacks2/.conda/envs/DataViz2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # SNL UIDs
# - tt0715791
# - tt0715791
# - tt0971348
# - tt10809086
# * **tt0072562**
# - tt1372614
# - tt2173702

# %% [markdown]
# # SNL Archive Data
# - Kaggle: https://www.kaggle.com/hhllcks/snldb
# - GitHub: https://github.com/hhllcks/snldb
# - SNL Archive: http://www.snlarchives.net/

# %%
actors = pd.read_csv('SNL_data/actors.csv')
appearances = pd.read_csv('SNL_data/appearances.csv')
casts = pd.read_csv('SNL_data/casts.csv')
characters = pd.read_csv('SNL_data/characters.csv')
episodes = pd.read_csv('SNL_data/episodes.csv')
hosts = pd.read_csv('SNL_data/hosts.csv')
impressions = pd.read_csv('SNL_data/impressions.csv')
seasons = pd.read_csv('SNL_data/seasons.csv')
sketches = pd.read_csv('SNL_data/sketches.csv')
tenure = pd.read_csv('SNL_data/tenure.csv')
titles = pd.read_csv('SNL_data/titles.csv')

# %%
actors #includes guests?
# Out:
#                       aid          url   type   gender
# 0           Kate McKinnon  /Cast/?KaMc   cast   female
# 1             Alex Moffat  /Cast/?AlMo   cast     male
# 2              Ego Nwodim  /Cast/?EgNw   cast  unknown
# 3              Chris Redd  /Cast/?ChRe   cast     male
# 4          Kenan Thompson  /Cast/?KeTh   cast     male
# ...                   ...          ...    ...      ...
# 2301  Jesse Dixon Singers  /Guests/?16  guest     male
# 2302       Connie Hawkins  /Guests/?21  guest   female
# 2303        Billy Preston   /Guests/?3  guest     male
# 2304            Janis Ian   /Guests/?2  guest   female
# 2305      Valri Bromfield   /Guests/?5  guest  unknown
#
# [2306 rows x 4 columns]

# %%
cast_members = actors.loc[actors.type == 'cast']
cast_members #why so many?
# Out:
#                  aid          url  type   gender
# 0      Kate McKinnon  /Cast/?KaMc  cast   female
# 1        Alex Moffat  /Cast/?AlMo  cast     male
# 2         Ego Nwodim  /Cast/?EgNw  cast  unknown
# 3         Chris Redd  /Cast/?ChRe  cast     male
# 4     Kenan Thompson  /Cast/?KeTh  cast     male
# ...              ...          ...   ...      ...
# 2048   Peter Aykroyd  /Cast/?PeAy  cast     male
# 2049     Jane Curtin  /Cast/?JaCu  cast   female
# 2051  Laraine Newman  /Cast/?LaNe  cast   female
# 2054    Gilda Radner  /Cast/?GiRa  cast   female
# 2132      George Coe  /Cast/?GeCo  cast     male
#
# [154 rows x 4 columns]

# %% [markdown]
# # Wikipedia SNL Cast Member Table
# https://en.wikipedia.org/wiki/List_of_Saturday_Night_Live_cast_members
# - converted to csv using: https://wikitable2csv.ggor.de/

# %%
wiki_table = pd.read_csv('wiki_cast.csv')

# %%
wiki_table
# Out:
#             Performer   Time on SNL  No. of seasons  Repertory Player  \
# 0        Fred Armisen     2002–2013              11               NaN
# 1    Aristotle Athari  2021–present               1               NaN
# 2         Dan Aykroyd     1975–1979               4               NaN
# 3       Peter Aykroyd          1980               1               NaN
# 4      Morwenna Banks          1995               1               NaN
# ..                ...           ...             ...               ...
# 154      Casey Wilson     2008–2009               2               NaN
# 155         Fred Wolf     1996–1996               2               NaN
# 156        Bowen Yang  2019–present               3               NaN
# 157    Sasheer Zamata     2014–2017               4               NaN
# 158      Alan Zweibel          1980               1               NaN
#
#      Featured Player  Middle Group  "Weekend Update" Anchor  Hosted  \
# 0                NaN           NaN                      NaN     NaN
# 1                NaN           NaN                      NaN     NaN
# 2                NaN           NaN                      NaN     NaN
# 3                NaN           NaN                      NaN     NaN
# 4                NaN           NaN                      NaN     NaN
# ..               ...           ...                      ...     ...
# 154              NaN           NaN                      NaN     NaN
# 155              NaN           NaN                      NaN     NaN
# 156              NaN           NaN                      NaN     NaN
# 157              NaN           NaN                      NaN     NaN
# 158              NaN           NaN                      NaN     NaN
#
#      Best of...  Writer
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN
# ..          ...     ...
# 154         NaN     NaN
# 155         NaN     NaN
# 156         NaN     NaN
# 157         NaN     NaN
# 158         NaN     NaN
#
# [159 rows x 10 columns]

# %%
dropped_cols = ('Repertory Player','Featured Player','Middle Group','"Weekend Update" Anchor','Hosted','Best of...','Writer')
for i in dropped_cols:
    if i in wiki_table.columns:
        print(i)
        wiki_table = wiki_table.drop(columns = i, inplace=False)
# Out:
# Repertory Player
# Featured Player
# Middle Group
# "Weekend Update" Anchor
# Hosted
# Writer

# %%
wiki_table # won't drop 'Best of...'
# Out:
#             Performer   Time on SNL  No. of seasons  Best of...
# 0        Fred Armisen     2002–2013              11         NaN
# 1    Aristotle Athari  2021–present               1         NaN
# 2         Dan Aykroyd     1975–1979               4         NaN
# 3       Peter Aykroyd          1980               1         NaN
# 4      Morwenna Banks          1995               1         NaN
# ..                ...           ...             ...         ...
# 154      Casey Wilson     2008–2009               2         NaN
# 155         Fred Wolf     1996–1996               2         NaN
# 156        Bowen Yang  2019–present               3         NaN
# 157    Sasheer Zamata     2014–2017               4         NaN
# 158      Alan Zweibel          1980               1         NaN
#
# [159 rows x 4 columns]

# %% [markdown]
# ## Edited Table in Excel
# I decided to copy and paste the Wikipedia page into Excel to format it. The 6 columns from the original table that included checkmarks didn't have any data coming through so I went through the table and added "Yes anywhere there was a checkmark. I then imported the resulting csv file and used the df.fillna() function to convert the NaN values to "No" values. I also noticed that there were actors who left for a period and then came back, adding an additional row to the data without a name attached. In excel, I decided to seperate the different periods by semicolon instead of adding a new row.

# %%
wiki_cast_excel = pd.read_csv('wiki_cast_excel.csv')

# %%
wiki_cast_excel.iloc[29]
# Out:
# Performer                  Brian Doyle-Murray
# Time on SNL                    1980;1981–1982
# No. of seasons                              2
# Repertory Player                          Yes
# Featured Player                           Yes
# Middle Group                              NaN
# "Weekend Update" Anchor                   Yes
# Hosted                                    NaN
# Writer                                    Yes
# Name: 29, dtype: object

# %%
wiki_cast = wiki_cast_excel.fillna('No')
wiki_cast
# Out:
#             Performer   Time on SNL  No. of seasons Repertory Player  \
# 0        Fred Armisen     2002–2013              11              Yes
# 1    Aristotle Athari  2021–present               1               No
# 2         Dan Aykroyd     1975–1979               4              Yes
# 3       Peter Aykroyd          1980               1               No
# 4      Morwenna Banks          1995               1              Yes
# ..                ...           ...             ...              ...
# 154      Casey Wilson     2008–2009               2               No
# 155         Fred Wolf     1996–1996               2               No
# 156        Bowen Yang  2019–present               3              Yes
# 157    Sasheer Zamata     2014–2017               4              Yes
# 158      Alan Zweibel          1980               1               No
#
#     Featured Player Middle Group "Weekend Update" Anchor Hosted Writer
# 0               Yes           No                      No    Yes     No
# 1               Yes           No                      No     No     No
# 2                No           No                     Yes    Yes    Yes
# 3               Yes           No                      No     No    Yes
# 4                No           No                      No     No     No
# ..              ...          ...                     ...    ...    ...
# 154             Yes           No                      No     No     No
# 155             Yes           No                      No     No    Yes
# 156             Yes           No                      No     No    Yes
# 157             Yes           No                      No     No     No
# 158             Yes           No                      No     No    Yes
#
# [159 rows x 9 columns]

# %%
plt.style.use('ggplot')
ax = wiki_cast.plot(x= "Performer",y="No. of seasons", figsize = (20,10), kind = 'bar')
ax.set_ylabel('No. of Seasons')
# Out:
# Text(0, 0.5, 'No. of Seasons')

# %%
# def cross_imdb_wiki():
#     for i in names['primaryName']:
#         print(i)
#         if i in wiki_cast['Performer']:
#             cross_imdb_wiki_list.append(i)
#     return cross_imdb_wiki_list

# %%
# cross_imdb_wiki()

# %%
imdb_names_df = imdb_names
imdb_names_df
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 11554305  nm9993714   Romeo del Rosario        \N        \N
# 11554306  nm9993716       Essias Loberg        \N        \N
# 11554307  nm9993717  Harikrishnan Rajan        \N        \N
# 11554308  nm9993718         Aayush Nair        \N        \N
# 11554309  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 11554305  animation_department,art_department
# 11554306                                  NaN
# 11554307                      cinematographer
# 11554308                      cinematographer
# 11554309                                  NaN
#
#                                    knownForTitles
# 0         tt0050419,tt0053137,tt0031983,tt0072308
# 1         tt0071877,tt0037382,tt0117057,tt0038355
# 2         tt0054452,tt0056404,tt0057345,tt0049189
# 3         tt0078723,tt0072562,tt0077975,tt0080455
# 4         tt0069467,tt0083922,tt0060827,tt0050986
# ...                                           ...
# 11554305          tt14069590,tt11657662,tt2455546
# 11554306                                       \N
# 11554307                                tt8736744
# 11554308                                       \N
# 11554309                                       \N
#
# [11554310 rows x 6 columns]

# %%
imdb_name_list = imdb_names_df.values.tolist()
imdb_name_list #with repeats, ALL NAMES
# Out:
# [['nm0000001',
#   'Fred Astaire',
#   '1899',
#   '1987',
#   'soundtrack,actor,miscellaneous',
#   'tt0050419,tt0053137,tt0031983,tt0072308'],
#  ['nm0000002',
#   'Lauren Bacall',
#   '1924',
#   '2014',
#   'actress,soundtrack',
#   'tt0071877,tt0037382,tt0117057,tt0038355'],
#  ['nm0000003',
#   'Brigitte Bardot',
#   '1934',
#   '\\N',
#   'actress,soundtrack,music_department',
#   'tt0054452,tt0056404,tt0057345,tt0049189'],
#  ['nm0000004',
#   'John Belushi',
#   '1949',
#   '1982',
#   'actor,soundtrack,writer',
#   'tt0078723,tt0072562,tt0077975,tt0080455'],
#  ['nm0000005',
#   'Ingmar Bergman',
#   '1918',
#   '2007',
#   'writer,director,actor',
#   'tt0069467,tt0083922,tt0060827,tt0050986'],
#  ['nm0000006',
#   'Ingrid Bergman',
#   '1915',
#   '1982',
#   'actress,soundtrack,producer',
#   'tt0077711,tt0038109,tt0034583,tt0036855'],
#  ['nm0000007',
#   'Humphrey Bogart',
#   '1899',
#   '1957',
#   'actor,soundtrack,producer',
#   'tt0034583,tt0037382,tt0042593,tt0043265'],
#  ['nm0000008',
#   'Marlon Brando',
#   '1924',
#   '2004',
#   'actor,soundtrack,director',
#   'tt0047296,tt0078788,tt0068646,tt0070849'],
#  ['nm0000009',
#   'Richard Burton',
#   '1925',
#   '1984',
#   'actor,soundtrack,producer',
#   'tt0059749,tt0061184,tt0057877,tt0087803'],
#  ['nm0000010',
#   'James Cagney',
#   '1899',
#   '1986',
#   'actor,soundtrack,director',
#   'tt0035575,tt0031867,tt0042041,tt0029870'],
#  ['nm0000011',
#   'Gary Cooper',
#   '1901',
#   '1961',
#   'actor,soundtrack,producer',
#   'tt0035896,tt0044706,tt0034167,tt0027996'],
#  ['nm0000012',
#   'Bette Davis',
#   '1908',
#   '1989',
#   'actress,soundtrack,make_up_department',
#   'tt0035140,tt0031210,tt0042192,tt0056687'],
#  ['nm0000013',
#   'Doris Day',
#   '1922',
#   '2019',
#   'soundtrack,actress,producer',
#   'tt0053172,tt0049470,tt0045591,tt0048317'],
#  ['nm0000014',
#   'Olivia de Havilland',
#   '1916',
#   '2020',
#   'actress,soundtrack',
#   'tt0040806,tt0029843,tt0041452,tt0031381'],
#  ['nm0000015',
#   'James Dean',
#   '1931',
#   '1955',
#   'actor,miscellaneous',
#   'tt0049261,tt0043228,tt0048028,tt0048545'],
#  ['nm0000016',
#   'Georges Delerue',
#   '1925',
#   '1992',
#   'composer,soundtrack,music_department',
#   'tt8847712,tt0096320,tt0091763,tt0069946'],
#  ['nm0000017',
#   'Marlene Dietrich',
#   '1901',
#   '1992',
#   'soundtrack,actress,music_department',
#   'tt0052311,tt0051201,tt0055031,tt0021156'],
#  ['nm0000018',
#   'Kirk Douglas',
#   '1916',
#   '2020',
#   'actor,producer,soundtrack',
#   'tt0080736,tt0054331,tt0043338,tt0049456'],
#  ['nm0000019',
#   'Federico Fellini',
#   '1920',
#   '1993',
#   'writer,director,assistant_director',
#   'tt0071129,tt0056801,tt0053779,tt0050783'],
#  ['nm0000020',
#   'Henry Fonda',
#   '1905',
#   '1982',
#   'actor,producer,soundtrack',
#   'tt0051207,tt0082846,tt0050083,tt0032551'],
#  ['nm0000021',
#   'Joan Fontaine',
#   '1917',
#   '2013',
#   'actress,soundtrack,producer',
#   'tt0035751,tt0032976,tt0040536,tt0034248'],
#  ['nm0000022',
#   'Clark Gable',
#   '1901',
#   '1960',
#   'actor,soundtrack,producer',
#   'tt0023382,tt0026752,tt0031381,tt0025316'],
#  ['nm0000023',
#   'Judy Garland',
#   '1922',
#   '1969',
#   'soundtrack,actress',
#   'tt0037059,tt0047522,tt0055031,tt0032138'],
#  ['nm0000024',
#   'John Gielgud',
#   '1904',
#   '2000',
#   'actor,writer,director',
#   'tt0082031,tt0045943,tt0117631,tt0071877'],
#  ['nm0000025',
#   'Jerry Goldsmith',
#   '1929',
#   '2004',
#   'music_department,soundtrack,composer',
#   'tt0077269,tt0117731,tt0112715,tt0119488'],
#  ['nm0000026',
#   'Cary Grant',
#   '1904',
#   '1986',
#   'actor,soundtrack,producer',
#   'tt0048728,tt0034248,tt0056923,tt0053125'],
#  ['nm0000027',
#   'Alec Guinness',
#   '1914',
#   '2000',
#   'actor,soundtrack,writer',
#   'tt0051739,tt0041546,tt0050212,tt0076759'],
#  ['nm0000028',
#   'Rita Hayworth',
#   '1918',
#   '1987',
#   'actress,soundtrack,producer',
#   'tt0036723,tt0038559,tt0040525,tt0046076'],
#  ['nm0000029',
#   'Margaux Hemingway',
#   '1954',
#   '1996',
#   'actress,miscellaneous',
#   'tt0110138,tt0077800,tt0102122,tt0074802'],
#  ['nm0000030',
#   'Audrey Hepburn',
#   '1929',
#   '1993',
#   'actress,soundtrack',
#   'tt0058385,tt0054698,tt0046250,tt0056923'],
#  ['nm0000031',
#   'Katharine Hepburn',
#   '1907',
#   '2003',
#   'actress,soundtrack,writer',
#   'tt0082846,tt0043265,tt0032904,tt0063227'],
#  ['nm0000032',
#   'Charlton Heston',
#   '1923',
#   '2008',
#   'actor,director,writer',
#   'tt0070723,tt0049833,tt0052618,tt0063442'],
#  ['nm0000033',
#   'Alfred Hitchcock',
#   '1899',
#   '1980',
#   'director,producer,writer',
#   'tt0053125,tt0054215,tt0052357,tt0056869'],
#  ['nm0000034',
#   'William Holden',
#   '1918',
#   '1981',
#   'actor,soundtrack',
#   'tt0046359,tt0074958,tt0047437,tt0043014'],
#  ['nm0000035',
#   'James Horner',
#   '1953',
#   '2015',
#   'music_department,soundtrack,composer',
#   'tt0499549,tt0120338,tt0120746,tt0090633'],
#  ['nm0000036',
#   'Buster Keaton',
#   '1895',
#   '1966',
#   'actor,writer,director',
#   'tt0019421,tt0015324,tt0017925,tt0016332'],
#  ['nm0000037',
#   'Gene Kelly',
#   '1912',
#   '1996',
#   'soundtrack,actor,director',
#   'tt0045152,tt0053946,tt0041716,tt0043278'],
#  ['nm0000038',
#   'Grace Kelly',
#   '1929',
#   '1982',
#   'actress,soundtrack',
#   'tt0047396,tt0048728,tt0046874,tt0046912'],
#  ['nm0000039',
#   'Deborah Kerr',
#   '1921',
#   '2007',
#   'actress,soundtrack',
#   'tt0045793,tt0050105,tt0049408,tt0039192'],
#  ['nm0000040',
#   'Stanley Kubrick',
#   '1928',
#   '1999',
#   'writer,director,producer',
#   'tt0093058,tt0072684,tt0062622,tt0066921'],
#  ['nm0000041',
#   'Akira Kurosawa',
#   '1910',
#   '1998',
#   'writer,director,assistant_director',
#   'tt0051808,tt0089881,tt0047478,tt0080979'],
#  ['nm0000042',
#   'Alan Ladd',
#   '1913',
#   '1964',
#   'actor,producer,camera_department',
#   'tt0039056,tt0038369,tt0046303,tt0035432'],
#  ['nm0000043',
#   'Veronica Lake',
#   '1922',
#   '1973',
#   'actress,soundtrack,producer',
#   'tt0034240,tt0038369,tt0035432,tt0034881'],
#  ['nm0000044',
#   'Burt Lancaster',
#   '1913',
#   '1994',
#   'actor,producer,miscellaneous',
#   'tt0051036,tt0080388,tt0053793,tt0045793'],
#  ['nm0000045',
#   'Bruce Lee',
#   '1940',
#   '1973',
#   'actor,writer,miscellaneous',
#   'tt0067824,tt0068767,tt0070034,tt0068935'],
#  ['nm0000046',
#   'Vivien Leigh',
#   '1913',
#   '1967',
#   'actress,soundtrack,writer',
#   'tt0044081,tt0033238,tt0034272,tt0031381'],
#  ['nm0000047',
#   'Sophia Loren',
#   '1934',
#   '\\N',
#   'actress,soundtrack',
#   'tt0076085,tt0060121,tt0058335,tt0054749'],
#  ['nm0000048',
#   'Peter Lorre',
#   '1904',
#   '1964',
#   'actor,soundtrack,writer',
#   'tt0022100,tt0036613,tt0034583,tt0033870'],
#  ['nm0000049',
#   'Henry Mancini',
#   '1924',
#   '1994',
#   'music_department,soundtrack,composer',
#   'tt0085101,tt0057413,tt0054698,tt0383216'],
#  ['nm0000050',
#   'Groucho Marx',
#   '1890',
#   '1977',
#   'soundtrack,actor,writer',
#   'tt0026778,tt0023027,tt0019777,tt0023969'],
#  ['nm0000051',
#   'James Mason',
#   '1909',
#   '1984',
#   'actor,producer,writer',
#   'tt0047522,tt0053125,tt0056193,tt0084855'],
#  ['nm0000052',
#   'Marcello Mastroianni',
#   '1924',
#   '1996',
#   'actor,producer,soundtrack',
#   'tt0091113,tt0076085,tt0053779,tt0056801'],
#  ['nm0000053',
#   'Robert Mitchum',
#   '1917',
#   '1997',
#   'actor,soundtrack,producer',
#   'tt0039689,tt0055824,tt0056197,tt0048424'],
#  ['nm0000054',
#   'Marilyn Monroe',
#   '1926',
#   '1962',
#   'soundtrack,actress,writer',
#   'tt0048605,tt0045810,tt0053291,tt0050861'],
#  ['nm0000055',
#   'Alfred Newman',
#   '1900',
#   '1970',
#   'music_department,composer,soundtrack',
#   'tt0434409,tt0065377,tt0042192,tt0049408'],
#  ['nm0000056',
#   'Paul Newman',
#   '1925',
#   '2008',
#   'actor,producer,director',
#   'tt0054997,tt0257044,tt0084855,tt0061512'],
#  ['nm0000057',
#   'David Niven',
#   '1910',
#   '1983',
#   'actor,producer,soundtrack',
#   'tt0057413,tt0074937,tt0052182,tt0048960'],
#  ['nm0000058',
#   "Maureen O'Hara",
#   '1920',
#   '2015',
#   'actress,soundtrack',
#   'tt0055277,tt0041149,tt0039628,tt0045061'],
#  ['nm0000059',
#   'Laurence Olivier',
#   '1907',
#   '1989',
#   'actor,producer,director',
#   'tt0069281,tt0074860,tt0032976,tt0077269'],
#  ['nm0000060',
#   'Gregory Peck',
#   '1916',
#   '2003',
#   'actor,producer,soundtrack',
#   'tt0056592,tt0046250,tt0038109,tt0077269'],
#  ['nm0000061',
#   'Tyrone Power',
#   '1914',
#   '1958',
#   'actor,soundtrack,producer',
#   'tt0051201,tt0042256,tt0034405,tt0043959'],
#  ['nm0000062',
#   'Elvis Presley',
#   '1935',
#   '1977',
#   'soundtrack,actor,music_department',
#   'tt0054692,tt0056023,tt0056585,tt0053848'],
#  ['nm0000063',
#   'Anthony Quinn',
#   '1915',
#   '2001',
#   'actor,producer,soundtrack',
#   'tt0064952,tt0057831,tt0056172,tt0049456'],
#  ['nm0000064',
#   'Edward G. Robinson',
#   '1893',
#   '1973',
#   'actor,soundtrack,writer',
#   'tt0049833,tt0038991,tt0040506,tt0036775'],
#  ['nm0000065',
#   'Nino Rota',
#   '1911',
#   '1979',
#   'composer,soundtrack,music_department',
#   'tt0063518,tt0056801,tt0071562,tt0068646'],
#  ['nm0000066',
#   'Jane Russell',
#   '1921',
#   '2011',
#   'actress,soundtrack,producer',
#   'tt0043643,tt0044863,tt0043476,tt0045810'],
#  ['nm0000067',
#   'Miklós Rózsa',
#   '1907',
#   '1995',
#   'music_department,composer,soundtrack',
#   'tt0037884,tt0038109,tt0052618,tt0036775'],
#  ['nm0000068',
#   'Randolph Scott',
#   '1898',
#   '1987',
#   'actor,producer,soundtrack',
#   'tt0029284,tt0056412,tt0026942,tt0051047'],
#  ['nm0000069',
#   'Frank Sinatra',
#   '1915',
#   '1998',
#   'soundtrack,actor,producer',
#   'tt0056218,tt0045793,tt0052218,tt0048347'],
#  ['nm0000070',
#   'Max Steiner',
#   '1888',
#   '1971',
#   'music_department,composer,soundtrack',
#   'tt0031381,tt0036613,tt0040897,tt0034583'],
#  ['nm0000071',
#   'James Stewart',
#   '1908',
#   '1997',
#   'actor,soundtrack,director',
#   'tt0052357,tt0052561,tt0031679,tt0032904'],
#  ['nm0000072',
#   'Elizabeth Taylor',
#   '1932',
#   '2011',
#   'actress,soundtrack,producer',
#   'tt0056937,tt0053318,tt0051459,tt0061184'],
#  ['nm0000073',
#   'Shirley Temple',
#   '1928',
#   '2014',
#   'actress,soundtrack,writer',
#   'tt0031580,tt0030657,tt0016029,tt0028118'],
#  ['nm0000074',
#   'Gene Tierney',
#   '1920',
#   '1991',
#   'actress,soundtrack',
#   'tt0039420,tt0035979,tt0037008,tt0037865'],
#  ['nm0000075',
#   'Spencer Tracy',
#   '1900',
#   '1967',
#   'actor,soundtrack',
#   'tt0061735,tt0047849,tt0053946,tt0055031'],
#  ['nm0000076',
#   'François Truffaut',
#   '1932',
#   '1984',
#   'writer,director,producer',
#   'tt0055032,tt0075860,tt0053198,tt0070460'],
#  ['nm0000077',
#   'Franz Waxman',
#   '1906',
#   '1967',
#   'music_department,composer,soundtrack',
#   'tt0032976,tt0043014,tt0026138,tt0034248'],
#  ['nm0000078',
#   'John Wayne',
#   '1907',
#   '1979',
#   'actor,producer,soundtrack',
#   'tt0065126,tt0031971,tt0056217,tt0053580'],
#  ['nm0000079',
#   'Raquel Welch',
#   '1940',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0070291,tt0061653,tt0072281,tt0066115'],
#  ['nm0000080',
#   'Orson Welles',
#   '1915',
#   '1985',
#   'actor,director,writer',
#   'tt0040525,tt0033467,tt0038991,tt0052311'],
#  ['nm0000081',
#   'Natalie Wood',
#   '1938',
#   '1981',
#   'actress,soundtrack,music_department',
#   'tt0055471,tt0057263,tt0048545,tt0055614'],
#  ['nm0000082',
#   'Victor Young',
#   '1900',
#   '1956',
#   'music_department,soundtrack,composer',
#   'tt0048960,tt0119094,tt3315342,tt0045061'],
#  ['nm0000083',
#   'Alan Miller',
#   '\\N',
#   '\\N',
#   'editor,writer,director',
#   'tt0320978,tt0969216,tt19064180,tt0424773'],
#  ['nm0000084',
#   'Gong Li',
#   '1965',
#   '\\N',
#   'actress,producer',
#   'tt0397535,tt0430357,tt0473444,tt0101640'],
#  ['nm0000085',
#   'Henner Hofmann',
#   '1950',
#   '\\N',
#   'cinematographer,producer,camera_department',
#   'tt0097738,tt0097523,tt1825758,tt0113482'],
#  ['nm0000086',
#   'Louis de Funès',
#   '1914',
#   '1983',
#   'actor,writer,soundtrack',
#   'tt0064425,tt0074103,tt0069747,tt0079200'],
#  ['nm0000087',
#   'Elena Koreneva',
#   '1953',
#   '\\N',
#   'actress,casting_director,soundtrack',
#   'tt0123138,tt5847740,tt7529350,tt0122969'],
#  ['nm0000088',
#   'Aleksey Korenev',
#   '1927',
#   '1995',
#   'director,writer,assistant_director',
#   'tt0100069,tt0191104,tt0068304,tt0149586'],
#  ['nm0000089',
#   'Richard Paul',
#   '1940',
#   '1998',
#   'actor,soundtrack',
#   'tt0088529,tt0075489,tt0086765,tt0117318'],
#  ['nm0000090',
#   'Armin Mueller-Stahl',
#   '1930',
#   '\\N',
#   'actor,director,writer',
#   'tt0139809,tt0765443,tt0963178,tt0117631'],
#  ['nm0000091',
#   'Gérard Pirès',
#   '1942',
#   '\\N',
#   'director,writer,actor',
#   'tt0421974,tt0282552,tt0064297,tt0152930'],
#  ['nm0000092',
#   'John Cleese',
#   '1939',
#   '\\N',
#   'actor,writer,producer',
#   'tt0071853,tt0085959,tt0063929,tt0095159'],
#  ['nm0000093',
#   'Brad Pitt',
#   '1963',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0356910,tt0114746,tt2935510,tt1210166'],
#  ['nm0000094',
#   'J. Reifel',
#   '\\N',
#   '\\N',
#   'writer',
#   'tt0116030,tt0118631,tt0117915,tt0118886'],
#  ['nm0000095',
#   'Woody Allen',
#   '1935',
#   '\\N',
#   'writer,director,actor',
#   'tt0097123,tt0079522,tt0075686,tt0091167'],
#  ['nm0000096',
#   'Gillian Anderson',
#   '1968',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0442632,tt0106179,tt0455590,tt2294189'],
#  ['nm0000097',
#   'Pamela Anderson',
#   '1967',
#   '\\N',
#   'actress,producer,director',
#   'tt0115624,tt0306047,tt0267913,tt0426592'],
#  ['nm0000098',
#   'Jennifer Aniston',
#   '1969',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt1723121,tt3442006,tt0279113,tt0108778'],
#  ['nm0000099',
#   'Patricia Arquette',
#   '1968',
#   '\\N',
#   'actress,soundtrack,director',
#   'tt0412175,tt1065073,tt0145531,tt0108399'],
#  ['nm0000100',
#   'Rowan Atkinson',
#   '1955',
#   '\\N',
#   'actor,writer,producer',
#   'tt0274166,tt0110357,tt0118689,tt1634122'],
#  ['nm0000101',
#   'Dan Aykroyd',
#   '1952',
#   '\\N',
#   'writer,actor,producer',
#   'tt0097428,tt0118747,tt0087332,tt0080455'],
#  ['nm0000102',
#   'Kevin Bacon',
#   '1958',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0087277,tt0164052,tt0327056,tt0361127'],
#  ['nm0000103',
#   'Fairuza Balk',
#   '1974',
#   '\\N',
#   'actress,soundtrack',
#   'tt0120586,tt0181875,tt0089908,tt0115963'],
#  ['nm0000104',
#   'Antonio Banderas',
#   '1960',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0120746,tt0285823,tt0120657,tt1189073'],
#  ['nm0000105',
#   'Adrienne Barbeau',
#   '1945',
#   '\\N',
#   'actress,soundtrack',
#   'tt0080749,tt0082340,tt0083767,tt1024648'],
#  ['nm0000106',
#   'Drew Barrymore',
#   '1975',
#   '\\N',
#   'producer,actress,soundtrack',
#   'tt0151738,tt0160127,tt0343660,tt0120631'],
#  ['nm0000107',
#   'Kim Basinger',
#   '1953',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0096895,tt0108525,tt0119488,tt0337921'],
#  ['nm0000108',
#   'Luc Besson',
#   '1959',
#   '\\N',
#   'writer,producer,director',
#   'tt2872732,tt0100263,tt0119116,tt0110413'],
#  ['nm0000109',
#   'Yasmine Bleeth',
#   '1968',
#   '\\N',
#   'actress',
#   'tt0131857,tt0111892,tt0337851,tt0115285'],
#  ['nm0000110',
#   'Kenneth Branagh',
#   '1960',
#   '\\N',
#   'actor,producer,director',
#   'tt0116477,tt3402236,tt0097499,tt0107616'],
#  ['nm0000111',
#   'Matthew Broderick',
#   '1962',
#   '\\N',
#   'actor,soundtrack,director',
#   'tt0126886,tt0091042,tt0395251,tt0086567'],
#  ['nm0000112',
#   'Pierce Brosnan',
#   '1953',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0155267,tt0120347,tt0143145,tt0795421'],
#  ['nm0000113',
#   'Sandra Bullock',
#   '1964',
#   '\\N',
#   'producer,actress,soundtrack',
#   'tt0212346,tt1454468,tt0111257,tt1041829'],
#  ['nm0000114',
#   'Steve Buscemi',
#   '1957',
#   '\\N',
#   'actor,producer,director',
#   'tt0162346,tt4686844,tt0105236,tt0116282'],
#  ['nm0000115',
#   'Nicolas Cage',
#   '1964',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0435705,tt0119094,tt0117500,tt0113627'],
#  ['nm0000116',
#   'James Cameron',
#   '1954',
#   '\\N',
#   'writer,producer,director',
#   'tt0120338,tt0499549,tt0103064,tt0090605'],
#  ['nm0000117',
#   'Neve Campbell',
#   '1973',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0120890,tt0134084,tt0120082,tt0117571'],
#  ['nm0000118',
#   'John Carpenter',
#   '1948',
#   '\\N',
#   'soundtrack,writer,composer',
#   'tt0082340,tt0077651,tt0080749,tt0096256'],
#  ['nm0000119',
#   'Tia Carrere',
#   '1967',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0111503,tt0207919,tt0275847,tt0105793'],
#  ['nm0000120',
#   'Jim Carrey',
#   '1962',
#   '\\N',
#   'actor,writer,producer',
#   'tt0109040,tt0315327,tt0338013,tt0110475'],
#  ['nm0000121',
#   'Phoebe Cates',
#   '1963',
#   '\\N',
#   'actress,soundtrack',
#   'tt0087363,tt0083929,tt0101775,tt0086143'],
#  ['nm0000122',
#   'Charles Chaplin',
#   '1889',
#   '1977',
#   'writer,soundtrack,actor',
#   'tt0027977,tt0018773,tt0044837,tt0032553'],
#  ['nm0000123',
#   'George Clooney',
#   '1961',
#   '\\N',
#   'actor,producer,director',
#   'tt0465538,tt0433383,tt1193138,tt1124035'],
#  ['nm0000124',
#   'Jennifer Connelly',
#   '1970',
#   '\\N',
#   'actress',
#   'tt0180093,tt0102803,tt0315983,tt0268978'],
#  ['nm0000125',
#   'Sean Connery',
#   '1930',
#   '2020',
#   'actor,producer,soundtrack',
#   'tt0094226,tt0055928,tt0117500,tt0059800'],
#  ['nm0000126',
#   'Kevin Costner',
#   '1955',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0099348,tt0103855,tt0102798,tt0119925'],
#  ['nm0000127',
#   'Wes Craven',
#   '1939',
#   '2015',
#   'writer,producer,director',
#   'tt0111686,tt0087800,tt0105121,tt0117571'],
#  ['nm0000128',
#   'Russell Crowe',
#   '1964',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0119488,tt1707386,tt0268978,tt0172495'],
#  ['nm0000129',
#   'Tom Cruise',
#   '1962',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0117060,tt0325710,tt0092099,tt0116695'],
#  ['nm0000130',
#   'Jamie Lee Curtis',
#   '1958',
#   '\\N',
#   'actress,producer,director',
#   'tt1502407,tt0086465,tt0120694,tt0111503'],
#  ['nm0000131',
#   'John Cusack',
#   '1966',
#   '\\N',
#   'actor,producer,writer',
#   'tt0119229,tt0450385,tt0146882,tt0098258'],
#  ['nm0000132',
#   'Claire Danes',
#   '1979',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0108872,tt0117509,tt0274558,tt1796960'],
#  ['nm0000133',
#   'Geena Davis',
#   '1956',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0091064,tt0104694,tt0103074,tt0116908'],
#  ['nm0000134',
#   'Robert De Niro',
#   '1943',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0101540,tt0075314,tt0077416,tt0081398'],
#  ['nm0000135',
#   'John Denver',
#   '1943',
#   '1997',
#   'soundtrack,music_department,actor',
#   'tt4649466,tt0299328,tt0120591,tt0076489'],
#  ['nm0000136',
#   'Johnny Depp',
#   '1963',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0449088,tt0383574,tt0325980,tt0408236'],
#  ['nm0000137',
#   'Bo Derek',
#   '1956',
#   '\\N',
#   'actress,producer,miscellaneous',
#   'tt0086987,tt0114694,tt0083170,tt0099656'],
#  ['nm0000138',
#   'Leonardo DiCaprio',
#   '1974',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0407887,tt0993846,tt1375666,tt0120338'],
#  ['nm0000139',
#   'Cameron Diaz',
#   '1972',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0160127,tt0119738,tt0259711,tt0129387'],
#  ['nm0000140',
#   'Michael Douglas',
#   '1944',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0093010,tt0103772,tt0094291,tt1291580'],
#  ['nm0000141',
#   'David Duchovny',
#   '1960',
#   '\\N',
#   'actor,producer,director',
#   'tt0904208,tt0120902,tt0443701,tt0106179'],
#  ['nm0000142',
#   'Clint Eastwood',
#   '1930',
#   '\\N',
#   'actor,producer,director',
#   'tt0105695,tt0112579,tt1205489,tt0405159'],
#  ['nm0000143',
#   'Erika Eleniak',
#   '1969',
#   '\\N',
#   'actress',
#   'tt0105690,tt0106400,tt0083866,tt0094761'],
#  ['nm0000144',
#   'Cary Elwes',
#   '1962',
#   '\\N',
#   'actor,producer,director',
#   'tt0119468,tt0107977,tt0387564,tt0093779'],
#  ['nm0000145',
#   'Sherilyn Fenn',
#   '1965',
#   '\\N',
#   'actress,soundtrack',
#   'tt0092240,tt0098936,tt0105046,tt0100935'],
#  ['nm0000146',
#   'Ralph Fiennes',
#   '1962',
#   '\\N',
#   'actor,director,producer',
#   'tt0108052,tt2278388,tt1201607,tt0387131'],
#  ['nm0000147',
#   'Colin Firth',
#   '1960',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt2802144,tt0243155,tt1504320,tt1315981'],
#  ['nm0000148',
#   'Harrison Ford',
#   '1942',
#   '\\N',
#   'actor,writer,producer',
#   'tt0090329,tt0076759,tt0106977,tt0082971'],
#  ['nm0000149',
#   'Jodie Foster',
#   '1962',
#   '\\N',
#   'actress,director,producer',
#   'tt0102926,tt0476964,tt0118884,tt0075314'],
#  ['nm0000150',
#   'Michael J. Fox',
#   '1961',
#   '\\N',
#   'actor,producer,miscellaneous',
#   'tt0088763,tt0116365,tt0096874,tt0115369'],
#  ['nm0000151',
#   'Morgan Freeman',
#   '1937',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0097239,tt0114369,tt0468569,tt1057500'],
#  ['nm0000152',
#   'Richard Gere',
#   '1949',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0119395,tt0100405,tt0299658,tt0163187'],
#  ['nm0000153',
#   'Gina Gershon',
#   '1962',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0115736,tt0114436,tt0119094,tt1726669'],
#  ['nm0000154',
#   'Mel Gibson',
#   '1956',
#   '\\N',
#   'actor,producer,director',
#   'tt0117438,tt0104714,tt0112573,tt0118883'],
#  ['nm0000155',
#   'Whoopi Goldberg',
#   '1955',
#   '\\N',
#   'actress,producer,writer',
#   'tt0105417,tt0108147,tt0099653,tt0088939'],
#  ['nm0000156',
#   'Jeff Goldblum',
#   '1952',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0091064,tt0116629,tt0107290,tt2278388'],
#  ['nm0000157',
#   'Linda Hamilton',
#   '1956',
#   '\\N',
#   'actress',
#   'tt0103064,tt0118928,tt0088247,tt6450804'],
#  ['nm0000158',
#   'Tom Hanks',
#   '1956',
#   '\\N',
#   'producer,actor,soundtrack',
#   'tt0162222,tt0094737,tt0109830,tt0120815'],
#  ['nm0000159',
#   'Teri Hatcher',
#   '1964',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0227538,tt0106057,tt0410975,tt0120347'],
#  ['nm0000160',
#   'Ethan Hawke',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt2209418,tt0112471,tt0139654,tt1065073'],
#  ['nm0000161',
#   'Salma Hayek',
#   '1966',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0120679,tt0112851,tt0120655,tt1615065'],
#  ['nm0000162',
#   'Anne Heche',
#   '1969',
#   '\\N',
#   'actress,writer,producer',
#   'tt0251160,tt0119008,tt0120828,tt0120885'],
#  ['nm0000163',
#   'Dustin Hoffman',
#   '1937',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0064665,tt0061722,tt0095953,tt0084805'],
#  ['nm0000164',
#   'Anthony Hopkins',
#   '1937',
#   '\\N',
#   'actor,soundtrack,composer',
#   'tt0102926,tt0212985,tt0975645,tt0412080'],
#  ['nm0000165',
#   'Ron Howard',
#   '1954',
#   '\\N',
#   'actor,producer,writer',
#   'tt0367279,tt0088933,tt0112384,tt0268978'],
#  ['nm0000166',
#   'Helen Hunt',
#   '1963',
#   '\\N',
#   'actress,producer,director',
#   'tt0119822,tt0162222,tt0103484,tt0117998'],
#  ['nm0000167',
#   'Elizabeth Hurley',
#   '1965',
#   '\\N',
#   'actress,producer',
#   'tt0118655,tt0230030,tt0105104,tt0145660'],
#  ['nm0000168',
#   'Samuel L. Jackson',
#   '1948',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt3460252,tt0110912,tt2802144,tt4154664'],
#  ['nm0000169',
#   'Tommy Lee Jones',
#   '1946',
#   '\\N',
#   'actor,director,soundtrack',
#   'tt2398231,tt0106977,tt0477348,tt0443272'],
#  ['nm0000170',
#   'Milla Jovovich',
#   '1975',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0119116,tt1220634,tt1220198,tt0432021'],
#  ['nm0000171',
#   'Ashley Judd',
#   '1968',
#   '\\N',
#   'actress,producer,director',
#   'tt0470705,tt0113277,tt0150377,tt0352277'],
#  ['nm0000172',
#   'Harvey Keitel',
#   '1939',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0105236,tt0103759,tt0110912,tt2278388'],
#  ['nm0000173',
#   'Nicole Kidman',
#   '1967',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0274558,tt0203009,tt0276919,tt0935075'],
#  ['nm0000174',
#   'Val Kilmer',
#   '1959',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0373469,tt0101761,tt0113277,tt0120053'],
#  ['nm0000175',
#   'Stephen King',
#   '1947',
#   '\\N',
#   'writer,producer,actor',
#   'tt0111161,tt0083767,tt0091499,tt0324864'],
#  ['nm0000176',
#   'Nastassja Kinski',
#   '1961',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0083722,tt0087884,tt0080009,tt0111400'],
#  ['nm0000177',
#   'Kevin Kline',
#   '1947',
#   '\\N',
#   'actor,soundtrack,music_department',
#   'tt0106673,tt0113117,tt0120891,tt0095159'],
#  ['nm0000178',
#   'Diane Lane',
#   '1965',
#   '\\N',
#   'actress,soundtrack',
#   'tt2096673,tt0250797,tt0086066,tt0328589'],
#  ['nm0000179',
#   'Jude Law',
#   '1972',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt2278388,tt0376541,tt0346156,tt0134119'],
#  ['nm0000180',
#   'David Lean',
#   '1908',
#   '1991',
#   'editor,director,writer',
#   'tt0056172,tt0087892,tt0059113,tt0050212'],
#  ['nm0000181',
#   'Heather Locklear',
#   '1961',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0380623,tt0098193,tt0103491,tt0119695'],
#  ['nm0000182',
#   'Jennifer Lopez',
#   '1969',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0252076,tt2126357,tt0120780,tt5503686'],
#  ['nm0000183',
#   'Traci Lords',
#   '1968',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt1007028,tt1984153,tt0099329,tt0120611'],
#  ['nm0000184',
#   'George Lucas',
#   '1944',
#   '\\N',
#   'writer,producer,director',
#   'tt0082971,tt0066434,tt0076759,tt0069704'],
#  ['nm0000185',
#   'Dolph Lundgren',
#   '1957',
#   '\\N',
#   'actor,producer,director',
#   'tt0105698,tt0113481,tt0089927,tt0093507'],
#  ['nm0000186',
#   'David Lynch',
#   '1946',
#   '\\N',
#   'writer,director,producer',
#   'tt0098936,tt0166924,tt0460829,tt0105665'],
#  ['nm0000187',
#   'Madonna',
#   '1958',
#   '\\N',
#   'soundtrack,composer,music_department',
#   'tt0116250,tt0246460,tt0156841,tt0104694'],
#  ['nm0000188',
#   'Steve Martin',
#   '1945',
#   '\\N',
#   'writer,actor,soundtrack',
#   'tt0383216,tt0102250,tt0079367,tt0093886'],
#  ['nm0000189',
#   'Jenny McCarthy Wahlberg',
#   '1972',
#   '\\N',
#   'actress,producer,writer',
#   'tt0455967,tt0134084,tt0327643,tt0131857'],
#  ['nm0000190',
#   'Matthew McConaughey',
#   '1969',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt1935179,tt0790636,tt1915581,tt1726669'],
#  ['nm0000191',
#   'Ewan McGregor',
#   '1971',
#   '\\N',
#   'actor,writer,producer',
#   'tt2763304,tt0203009,tt0117951,tt1322269'],
#  ['nm0000192',
#   'Alyssa Milano',
#   '1972',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0116287,tt0088944,tt0086827,tt0158552'],
#  ['nm0000193',
#   'Demi Moore',
#   '1962',
#   '\\N',
#   'actress,producer,director',
#   'tt0099653,tt0119173,tt0107211,tt0305357'],
#  ['nm0000194',
#   'Julianne Moore',
#   '1960',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0297884,tt0118749,tt0842926,tt0175880'],
#  ['nm0000195',
#   'Bill Murray',
#   '1950',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt1748122,tt0128445,tt0362270,tt0335266'],
#  ['nm0000196',
#   'Mike Myers',
#   '1963',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0295178,tt0145660,tt0118655,tt0811138'],
#  ['nm0000197',
#   'Jack Nicholson',
#   '1937',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0407887,tt0119822,tt0071315,tt0073486'],
#  ['nm0000198',
#   'Gary Oldman',
#   '1958',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0468569,tt4555426,tt1340800,tt0103874'],
#  ['nm0000199',
#   'Al Pacino',
#   '1940',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0070666,tt0099422,tt0072890,tt0068646'],
#  ['nm0000200',
#   'Bill Paxton',
#   '1955',
#   '2017',
#   'actor,producer,writer',
#   'tt0264616,tt0112384,tt0090605,tt0117998'],
#  ['nm0000201',
#   'Michelle Pfeiffer',
#   '1958',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0427327,tt0117247,tt0161081,tt0097322'],
#  ['nm0000202',
#   'Ryan Phillippe',
#   '1974',
#   '\\N',
#   'actor,producer,director',
#   'tt0139134,tt0280707,tt0375679,tt0120577'],
#  ['nm0000203',
#   'River Phoenix',
#   '1970',
#   '1993',
#   'actor,soundtrack',
#   'tt0091557,tt0096018,tt0092005,tt0102494'],
#  ['nm0000204',
#   'Natalie Portman',
#   '1981',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0376541,tt0947798,tt0434409,tt0110413'],
#  ['nm0000205',
#   'Parker Posey',
#   '1968',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0106677,tt0348150,tt0134084,tt0359013'],
#  ['nm0000206',
#   'Keanu Reeves',
#   '1964',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0234215,tt0102685,tt0133093,tt0111257'],
#  ['nm0000207',
#   'Christina Ricci',
#   '1980',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0112642,tt0118789,tt0462200,tt0811080'],
#  ['nm0000208',
#   'Molly Ringwald',
#   '1968',
#   '\\N',
#   'actress,soundtrack,music_department',
#   'tt0088847,tt0091790,tt0088128,tt0095169'],
#  ['nm0000209',
#   'Tim Robbins',
#   '1958',
#   '\\N',
#   'actor,producer,director',
#   'tt0091225,tt0094812,tt0327056,tt0105151'],
#  ['nm0000210',
#   'Julia Roberts',
#   '1967',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0376541,tt0100405,tt0195685,tt0119738'],
#  ['nm0000211',
#   'Mimi Rogers',
#   '1955',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0118655,tt0120738,tt0210070,tt0488085'],
#  ['nm0000212',
#   'Meg Ryan',
#   '1961',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0128853,tt0108160,tt0120632,tt0098635'],
#  ['nm0000213',
#   'Winona Ryder',
#   '1971',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0100140,tt0172493,tt0110367,tt0097493'],
#  ['nm0000214',
#   'Mia Sara',
#   '1967',
#   '\\N',
#   'actress,soundtrack',
#   'tt0089469,tt0091042,tt0111438,tt0312098'],
#  ['nm0000215',
#   'Susan Sarandon',
#   '1946',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0094812,tt0120686,tt0112818,tt0103074'],
#  ['nm0000216',
#   'Arnold Schwarzenegger',
#   '1947',
#   '\\N',
#   'actor,producer,director',
#   'tt0216216,tt0107362,tt0103064,tt0088247'],
#  ['nm0000217',
#   'Martin Scorsese',
#   '1942',
#   '\\N',
#   'producer,director,actor',
#   'tt0070379,tt0106226,tt0099685,tt0075314'],
#  ['nm0000218',
#   'Kristin Scott Thomas',
#   '1960',
#   '\\N',
#   'actress,soundtrack,director',
#   'tt0116209,tt0280707,tt0109831,tt1602613'],
#  ['nm0000219',
#   'Steven Seagal',
#   '1952',
#   '\\N',
#   'producer,actor,writer',
#   'tt0105690,tt0242445,tt0110725,tt0094602'],
#  ['nm0000220',
#   'Joan Severance',
#   '1958',
#   '\\N',
#   'actress,producer',
#   'tt0112519,tt0099141,tt0115696,tt0098282'],
#  ['nm0000221',
#   'Charlie Sheen',
#   '1965',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0107144,tt0369179,tt0108333,tt0094291'],
#  ['nm0000222',
#   'Brooke Shields',
#   '1965',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0080453,tt0078111,tt0080116,tt0805570'],
#  ['nm0000223',
#   'Elisabeth Shue',
#   '1963',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0120053,tt0092513,tt0087538,tt0113627'],
#  ['nm0000224',
#   'Alicia Silverstone',
#   '1976',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0119086,tt0118688,tt0124298,tt0112697'],
#  ['nm0000225',
#   'Christian Slater',
#   '1969',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0124198,tt0115759,tt0108399,tt0102798'],
#  ['nm0000226',
#   'Will Smith',
#   '1968',
#   '\\N',
#   'producer,actor,soundtrack',
#   'tt0098800,tt0480249,tt0116629,tt0119654'],
#  ['nm0000227',
#   'Mira Sorvino',
#   '1967',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0113819,tt0364343,tt0120008,tt0120032'],
#  ['nm0000228',
#   'Kevin Spacey',
#   '1959',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0169547,tt0114814,tt0119488,tt0114369'],
#  ['nm0000229',
#   'Steven Spielberg',
#   '1946',
#   '\\N',
#   'producer,writer,director',
#   'tt0120815,tt0108052,tt0083866,tt0082971'],
#  ['nm0000230',
#   'Sylvester Stallone',
#   '1946',
#   '\\N',
#   'actor,writer,producer',
#   'tt0084602,tt3076658,tt0089927,tt0075148'],
#  ['nm0000231',
#   'Oliver Stone',
#   '1946',
#   '\\N',
#   'producer,director,writer',
#   'tt0110632,tt0091763,tt0102138,tt0096969'],
#  ['nm0000232',
#   'Sharon Stone',
#   '1958',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0114214,tt0103772,tt0112641,tt0108162'],
#  ['nm0000233',
#   'Quentin Tarantino',
#   '1963',
#   '\\N',
#   'writer,actor,producer',
#   'tt0110912,tt7131622,tt0105236,tt3460252'],
#  ['nm0000234',
#   'Charlize Theron',
#   '1975',
#   '\\N',
#   'producer,actress,soundtrack',
#   'tt0340855,tt5610554,tt1392190,tt1735898'],
#  ['nm0000235',
#   'Uma Thurman',
#   '1970',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0266697,tt0378194,tt0110912,tt0118688'],
#  ['nm0000236',
#   'Jennifer Tilly',
#   '1958',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0144120,tt0387575,tt0109348,tt0115736'],
#  ['nm0000237',
#   'John Travolta',
#   '1954',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0076666,tt0077631,tt0110912,tt0113161'],
#  ['nm0000238',
#   'Shannon Tweed',
#   '1957',
#   '\\N',
#   'actress,producer,miscellaneous',
#   'tt0110675,tt0165710,tt0094834,tt0112942'],
#  ['nm0000239',
#   'Liv Tyler',
#   '1977',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0120591,tt0482606,tt0120737,tt0167260'],
#  ['nm0000240',
#   'Skeet Ulrich',
#   '1970',
#   '\\N',
#   'actor,director,producer',
#   'tt0913354,tt0409572,tt0115963,tt0117571'],
#  ['nm0000241',
#   'Jean-Claude Van Damme',
#   '1960',
#   '\\N',
#   'actor,writer,producer',
#   'tt0097659,tt1130988,tt0119013,tt0101764'],
#  ['nm0000242',
#   'Mark Wahlberg',
#   '1971',
#   '\\N',
#   'producer,actor,soundtrack',
#   'tt0964517,tt0118749,tt0407887,tt1637725'],
#  ['nm0000243',
#   'Denzel Washington',
#   '1954',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt1037705,tt2671706,tt0168786,tt0139654'],
#  ['nm0000244',
#   'Sigourney Weaver',
#   '1949',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0118583,tt0078748,tt0095243,tt0499549'],
#  ['nm0000245',
#   'Robin Williams',
#   '1951',
#   '2014',
#   'actor,soundtrack,writer',
#   'tt0265459,tt0107614,tt0093105,tt0119217'],
#  ['nm0000246',
#   'Bruce Willis',
#   '1955',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0095016,tt0167404,tt0110912,tt0088571'],
#  ['nm0000247',
#   'John Woo',
#   '1946',
#   '\\N',
#   'director,producer,writer',
#   'tt0119094,tt0092263,tt0425637,tt0104684'],
#  ['nm0000248',
#   'Edward D. Wood Jr.',
#   '1924',
#   '1978',
#   'writer,director,actor',
#   'tt0045826,tt0052077,tt0067479,tt0047127'],
#  ['nm0000249',
#   'James Woods',
#   '1947',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0120877,tt0119282,tt0086541,tt0159097'],
#  ['nm0000250',
#   'Renée Zellweger',
#   '1969',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0299658,tt0243155,tt0159365,tt0116695'],
#  ['nm0000251',
#   'Timothy Dowling',
#   '1973',
#   '\\N',
#   'actor,writer,script_department',
#   'tt2120120,tt0181852,tt0430922,tt1596350'],
#  ['nm0000252',
#   'Robert Ellis',
#   '1892',
#   '1974',
#   'actor,director,writer',
#   'tt0010781,tt0006213,tt0030778,tt0028651'],
#  ['nm0000253',
#   'Robert Ellis',
#   '1888',
#   '1935',
#   'art_director,miscellaneous',
#   'tt0010965,tt0014083,tt0014515,tt0026454'],
#  ['nm0000254',
#   'Isabelle Adjani',
#   '1955',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0094828,tt0079641,tt0082933,tt0090095'],
#  ['nm0000255',
#   'Ben Affleck',
#   '1972',
#   '\\N',
#   'producer,actor,writer',
#   'tt2267998,tt0840361,tt0119217,tt1024648'],
#  ['nm0000256',
#   'Jenny Agutter',
#   '1952',
#   '\\N',
#   'actress,soundtrack',
#   'tt0848228,tt0074812,tt0082010,tt0099253'],
#  ['nm0000257',
#   'Alan Alda',
#   '1936',
#   '\\N',
#   'actor,miscellaneous,soundtrack',
#   'tt0097123,tt7653254,tt0068098,tt0082405'],
#  ['nm0000258',
#   'Stephanie Zimbalist',
#   '1956',
#   '\\N',
#   'actress,writer',
#   'tt0080402,tt2224219,tt0083470,tt0076993'],
#  ['nm0000259',
#   'Ginger Lynn',
#   '1962',
#   '\\N',
#   'actress,director,writer',
#   'tt0134898,tt0395584,tt0210365,tt0087562'],
#  ['nm0000260',
#   'Joan Allen',
#   '1956',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt3170832,tt0452608,tt0115988,tt0113987'],
#  ['nm0000261',
#   'Karen Allen',
#   '1951',
#   '\\N',
#   'actress,director,soundtrack',
#   'tt0367882,tt0082971,tt0077975,tt0088172'],
#  ['nm0000262',
#   'Nancy Allen',
#   '1950',
#   '\\N',
#   'actress,soundtrack',
#   'tt0100502,tt0093870,tt0080661,tt0107978'],
#  ['nm0000263',
#   'Kirstie Alley',
#   '1951',
#   '\\N',
#   'actress,producer,writer',
#   'tt0084726,tt0097778,tt0114852,tt0157503'],
#  ['nm0000264',
#   'Pedro Almodóvar',
#   '1949',
#   '\\N',
#   'writer,director,soundtrack',
#   'tt0095675,tt0101026,tt0287467,tt1189073'],
#  ['nm0000265',
#   'Robert Altman',
#   '1925',
#   '2006',
#   'director,producer,writer',
#   'tt0108122,tt0073440,tt0280707,tt0105151'],
#  ['nm0000266',
#   'Ursula Andress',
#   '1936',
#   '\\N',
#   'actress',
#   'tt0082186,tt0061452,tt0055928,tt0060177'],
#  ['nm0000267',
#   'Julie Andrews',
#   '1935',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0059742,tt0058331,tt0084865,tt0247638'],
#  ['nm0000268',
#   'Ann-Margret',
#   '1941',
#   '\\N',
#   'actress,soundtrack',
#   'tt0107050,tt0056891,tt0060646,tt0066892'],
#  ['nm0000269',
#   'Jean-Jacques Annaud',
#   '1943',
#   '\\N',
#   'director,producer,writer',
#   'tt0091605,tt0120102,tt0215750,tt2909116'],
#  ['nm0000270',
#   'Gabrielle Anwar',
#   '1970',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0114660,tt0810788,tt0105323,tt0108333'],
#  ['nm0000271',
#   'Anne Archer',
#   '1947',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0160009,tt0105112,tt0093010,tt0108122'],
#  ['nm0000272',
#   'Fanny Ardant',
#   '1949',
#   '\\N',
#   'actress,director,writer',
#   'tt0401711,tt0127536,tt0283832,tt0086551'],
#  ['nm0000273',
#   'Alan Arkin',
#   '1934',
#   '\\N',
#   'actor,soundtrack,director',
#   'tt1024648,tt0104348,tt0099487,tt0449059'],
#  ['nm0000274',
#   'David Arquette',
#   '1971',
#   '\\N',
#   'producer,actor,director',
#   'tt0151738,tt0271367,tt0134084,tt0120082'],
#  ['nm0000275',
#   'Rosanna Arquette',
#   '1959',
#   '\\N',
#   'actress,director,producer',
#   'tt0110912,tt0088680,tt0190138,tt0089017'],
#  ['nm0000276',
#   'Sean Astin',
#   '1971',
#   '\\N',
#   'actor,producer,director',
#   'tt0167260,tt0120737,tt0089218,tt0167261'],
#  ['nm0000277',
#   'Richard Attenborough',
#   '1923',
#   '2014',
#   'actor,producer,director',
#   'tt0107290,tt0083987,tt0057115,tt0060934'],
#  ['nm0000278',
#   'Pernilla August',
#   '1958',
#   '\\N',
#   'actress,director,writer',
#   'tt0121765,tt0120915,tt0104350,tt1437366'],
#  ['nm0000279',
#   'Hank Azaria',
#   '1964',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0115685,tt0096697,tt0132347,tt1839481'],
#  ['nm0000280',
#   'Catherine Bach',
#   '1954',
#   '\\N',
#   'actress,soundtrack',
#   'tt1414382,tt0072288,tt0078607,tt0119025'],
#  ['nm0000281',
#   'Scott Baio',
#   '1960',
#   '\\N',
#   'actor,director,producer',
#   'tt0281680,tt0270846,tt0070992,tt0367279'],
#  ['nm0000282',
#   'Scott Bairstow',
#   '1970',
#   '\\N',
#   'actor',
#   'tt0119925,tt0182587,tt0283084,tt0120512'],
#  ['nm0000283',
#   'Brenda Bakke',
#   '1963',
#   '\\N',
#   'actress',
#   'tt0114781,tt0114608,tt0119488,tt0107144'],
#  ['nm0000284',
#   'Adam Baldwin',
#   '1962',
#   '\\N',
#   'actor,soundtrack',
#   'tt0116629,tt0093058,tt0379786,tt0187393'],
#  ['nm0000285',
#   'Alec Baldwin',
#   '1958',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0104348,tt0318374,tt0407887,tt1230414'],
#  ['nm0000286',
#   'Stephen Baldwin',
#   '1966',
#   '\\N',
#   'actor,producer,director',
#   'tt0115683,tt0158622,tt0486583,tt0114814'],
#  ['nm0000287',
#   'William Baldwin',
#   '1963',
#   '\\N',
#   'actor,producer,stunts',
#   'tt0101393,tt0113010,tt0108162,tt0367089'],
#  ['nm0000288',
#   'Christian Bale',
#   '1974',
#   '\\N',
#   'actor,editorial_department,producer',
#   'tt0372784,tt0468569,tt0144084,tt0964517'],
#  ['nm0000289',
#   'Ellen Barkin',
#   '1954',
#   '\\N',
#   'actress,producer',
#   'tt0157503,tt0086856,tt0108330,tt0116277'],
#  ['nm0000290',
#   'John Barry',
#   '1933',
#   '2011',
#   'music_department,soundtrack,composer',
#   'tt0081534,tt0093428,tt0099348,tt0089755'],
#  ['nm0000291',
#   'Angela Bassett',
#   '1958',
#   '\\N',
#   'actress,producer,director',
#   'tt1825683,tt2302755,tt0118884,tt0114558'],
#  ['nm0000292',
#   'Michelle Bauer',
#   '1958',
#   '\\N',
#   'actress,miscellaneous,costume_department',
#   'tt0103213,tt0094998,tt0094734,tt0181017'],
#  ['nm0000293',
#   'Sean Bean',
#   '1959',
#   '\\N',
#   'actor,producer,animation_department',
#   'tt0944947,tt1181791,tt0167261,tt0120737'],
#  ['nm0000294',
#   'Amanda Bearse',
#   '1958',
#   '\\N',
#   'actress,director,producer',
#   'tt0247121,tt0092400,tt0089175,tt0255132'],
#  ['nm0000295',
#   'Kate Beckinsale',
#   '1973',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0452702,tt0320691,tt0401855,tt0338526'],
#  ['nm0000296',
#   'Robert Beltran',
#   '1953',
#   '\\N',
#   'actor,soundtrack',
#   'tt0087799,tt0112178,tt0113987,tt0101516'],
#  ['nm0000297',
#   'Tom Berenger',
#   '1949',
#   '\\N',
#   'actor,producer,writer',
#   'tt0097815,tt0091763,tt0085244,tt1375666'],
#  ['nm0000298',
#   'Candice Bergen',
#   '1946',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0901476,tt0094514,tt0212346,tt0256415'],
#  ['nm0000299',
#   'Michael Biehn',
#   '1956',
#   '\\N',
#   'actor,producer,director',
#   'tt0090605,tt0096754,tt0088247,tt1077258'],
#  ['nm0000300',
#   'Juliette Binoche',
#   '1964',
#   '\\N',
#   'actress,art_department,miscellaneous',
#   'tt0241303,tt2452254,tt1219827,tt0116209'],
#  ['nm0000301',
#   'Thora Birch',
#   '1982',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0162346,tt0105112,tt0107120,tt0169547'],
#  ['nm0000302',
#   'Jacqueline Bisset',
#   '1944',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0071877,tt0062765,tt0061452,tt0088322'],
#  ['nm0000303',
#   'Honor Blackman',
#   '1925',
#   '2020',
#   'actress,soundtrack',
#   'tt0058150,tt0057197,tt0054518,tt0243155'],
#  ['nm0000304',
#   'Linda Blair',
#   '1959',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0082511,tt0070047,tt0088044,tt0076009'],
#  ['nm0000305',
#   'Mel Blanc',
#   '1908',
#   '1989',
#   'actor,soundtrack,music_department',
#   'tt0094939,tt0096438,tt0077278,tt0045708'],
#  ['nm0000306',
#   'Brian Blessed',
#   '1936',
#   '\\N',
#   'actor,soundtrack,director',
#   'tt0120855,tt0120915,tt0080745,tt0107616'],
#  ['nm0000307',
#   'Helena Bonham Carter',
#   '1966',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt1707386,tt0408236,tt0137523,tt1504320'],
#  ['nm0000308',
#   'Ernest Borgnine',
#   '1917',
#   '2012',
#   'actor,soundtrack,producer',
#   'tt0069113,tt0082340,tt0048356,tt0086662'],
#  ['nm0000309',
#   'David Bowie',
#   '1947',
#   '2016',
#   'soundtrack,composer,actor',
#   'tt0074851,tt0482571,tt0196229,tt0091369'],
#  ['nm0000310',
#   'Bruce Boxleitner',
#   '1950',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0084827,tt1104001,tt0105946,tt0871427'],
#  ['nm0000311',
#   'Annie Rosar',
#   '1888',
#   '1963',
#   'actress,soundtrack',
#   'tt0034800,tt0140410,tt0041552,tt0052996'],
#  ['nm0000312',
#   'Amy Brenneman',
#   '1964',
#   '\\N',
#   'actress,producer,writer',
#   'tt0113277,tt0209069,tt0866437,tt0116287'],
#  ['nm0000313',
#   'Jeff Bridges',
#   '1949',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0118715,tt2582782,tt0088172,tt1263670'],
#  ['nm0000314',
#   'Charles Bronson',
#   '1921',
#   '2003',
#   'actor',
#   'tt0057115,tt0064116,tt0071402,tt0054047'],
#  ['nm0000315',
#   'Louise Brooks',
#   '1906',
#   '1985',
#   'actress,soundtrack',
#   'tt0021917,tt0020475,tt0018737,tt0017382'],
#  ['nm0000316',
#   'Mel Brooks',
#   '1926',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0071230,tt0082517,tt0094012,tt0395251'],
#  ['nm0000317',
#   'Clancy Brown',
#   '1959',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt2279373,tt1179056,tt0120201,tt0111161'],
#  ['nm0000318',
#   'Tim Burton',
#   '1958',
#   '\\N',
#   'producer,miscellaneous,director',
#   'tt0109707,tt1142977,tt0121164,tt0099487'],
#  ['nm0000319',
#   'Yancy Butler',
#   '1970',
#   '\\N',
#   'actress,director,writer',
#   'tt1250777,tt1650554,tt0274298,tt0107076'],
#  ['nm0000320',
#   'Luis Buñuel',
#   '1900',
#   '1983',
#   'writer,director,actor',
#   'tt0068361,tt0075824,tt0061395,tt0056732'],
#  ['nm0000321',
#   'Gabriel Byrne',
#   '1950',
#   '\\N',
#   'actor,producer,writer',
#   'tt0146675,tt0114814,tt0100150,tt7784604'],
#  ['nm0000322',
#   'Emmanuelle Béart',
#   '1963',
#   '\\N',
#   'actress,soundtrack',
#   'tt0283832,tt0189142,tt0117060,tt0113947'],
#  ['nm0000323',
#   'Michael Caine',
#   '1933',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0124315,tt0468569,tt3312830,tt0258068'],
#  ['nm0000324',
#   'Barbara Carrera',
#   '1945',
#   '\\N',
#   'actress,soundtrack',
#   'tt0076210,tt0084112,tt0085862,tt0086006'],
#  ['nm0000325',
#   'David Caruso',
#   '1956',
#   '\\N',
#   'actor,producer',
#   'tt0228750,tt0261983,tt0083944,tt0113451'],
#  ['nm0000326',
#   'Kim Cattrall',
#   '1956',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0159206,tt1000774,tt0102975,tt1261945'],
#  ['nm0000327',
#   'Lacey Chabert',
#   '1982',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0377092,tt0277371,tt0454082,tt0120738'],
#  ['nm0000328',
#   'Richard Chamberlain',
#   '1934',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0076299,tt0072824,tt0072308,tt0085101'],
#  ['nm0000329',
#   'Jackie Chan',
#   '1954',
#   '\\N',
#   'producer,actor,stunts',
#   'tt0120812,tt0089374,tt0266915,tt0127357'],
#  ['nm0000330',
#   'Stockard Channing',
#   '1944',
#   '\\N',
#   'actress,soundtrack',
#   'tt0077631,tt0120791,tt0198021,tt0108149'],
#  ['nm0000331',
#   'Chevy Chase',
#   '1943',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0085995,tt0097958,tt0080487,tt0092086'],
#  ['nm0000332',
#   'Don Cheadle',
#   '1964',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0375679,tt0181865,tt1540133,tt0395169'],
#  ['nm0000333',
#   'Cher',
#   '1946',
#   '\\N',
#   'soundtrack,actress,composer',
#   'tt0093565,tt0089560,tt1126591,tt0100140'],
#  ['nm0000334',
#   'Chow Yun-Fat',
#   '1955',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt1098327,tt0473444,tt0190332,tt0120008'],
#  ['nm0000335',
#   'Glenn Close',
#   '1947',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0093010,tt2015381,tt0094947,tt3750872'],
#  ['nm0000336',
#   'James Coburn',
#   '1928',
#   '2002',
#   'actor,producer,director',
#   'tt0056923,tt0057115,tt0074695,tt0054047'],
#  ['nm0000337',
#   'Rachael Leigh Cook',
#   '1979',
#   '\\N',
#   'actress,producer',
#   'tt0331811,tt11100856,tt0160862,tt5659816'],
#  ['nm0000338',
#   'Francis Ford Coppola',
#   '1939',
#   '\\N',
#   'producer,director,writer',
#   'tt0078788,tt0071562,tt0071360,tt0068646'],
#  ['nm0000339',
#   'Roger Corman',
#   '1926',
#   '\\N',
#   'producer,director,actor',
#   'tt0102926,tt0061189,tt0099612,tt0091419'],
#  ['nm0000340',
#   'Cindy Crawford',
#   '1966',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt1441109,tt0113010,tt0120577,tt0115082'],
#  ['nm0000341',
#   'Michael Crichton',
#   '1942',
#   '2008',
#   'writer,producer,director',
#   'tt0117998,tt0070909,tt0108757,tt0107290'],
#  ['nm0000342',
#   'James Cromwell',
#   '1940',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0117731,tt0144214,tt0119488,tt0120689'],
#  ['nm0000343',
#   'David Cronenberg',
#   '1943',
#   '\\N',
#   'director,actor,writer',
#   'tt0115964,tt0094964,tt0091064,tt0120907'],
#  ['nm0000344',
#   'Denise Crosby',
#   '1957',
#   '\\N',
#   'actress,producer',
#   'tt0098084,tt0120647,tt0097889,tt0104119'],
#  ['nm0000345',
#   'Billy Crystal',
#   '1948',
#   '\\N',
#   'actor,writer,producer',
#   'tt0101587,tt0098635,tt0113097,tt0122933'],
#  ['nm0000346',
#   'Macaulay Culkin',
#   '1980',
#   '\\N',
#   'actor,producer,director',
#   'tt0104431,tt0107034,tt0099785,tt0102492'],
#  ['nm0000347',
#   'Tim Curry',
#   '1946',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0073629,tt0112715,tt0099810,tt0088930'],
#  ['nm0000348',
#   'Tony Curtis',
#   '1925',
#   '2010',
#   'actor,soundtrack,producer',
#   'tt0054331,tt0051036,tt0053291,tt0066701'],
#  ['nm0000349',
#   'Joan Cusack',
#   '1962',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0119229,tt1659337,tt0119360,tt0096463'],
#  ['nm0000350',
#   "Beverly D'Angelo",
#   '1951',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0120434,tt0085995,tt0097958,tt0120586'],
#  ['nm0000351',
#   "Donna D'Errico",
#   '1968',
#   '\\N',
#   'actress,director,producer',
#   'tt12861508,tt4270458,tt4459134,tt7235466'],
#  ['nm0000352',
#   "Vincent D'Onofrio",
#   '1959',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0109707,tt0209958,tt0093058,tt0119654'],
#  ['nm0000353',
#   'Willem Dafoe',
#   '1955',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0145487,tt6938828,tt7984734,tt5649144'],
#  ['nm0000354',
#   'Matt Damon',
#   '1970',
#   '\\N',
#   'producer,actor,soundtrack',
#   'tt3659388,tt0134119,tt0119217,tt0407887'],
#  ['nm0000355',
#   'Anthony Daniels',
#   '1946',
#   '\\N',
#   'actor,producer,writer',
#   'tt2488496,tt0076759,tt0080684,tt2527336'],
#  ['nm0000356',
#   'Sybil Danning',
#   '1952',
#   '\\N',
#   'actress,producer,writer',
#   'tt0085672,tt0080421,tt0092546,tt0373883'],
#  ['nm0000357',
#   'Lolita Davidovich',
#   '1961',
#   '\\N',
#   'actress',
#   'tt0096943,tt0092513,tt0329717,tt2726560'],
#  ['nm0000358',
#   'Daniel Day-Lewis',
#   '1957',
#   '\\N',
#   'actor,music_department,soundtrack',
#   'tt0217505,tt0104691,tt0469494,tt0443272'],
#  ['nm0000359',
#   'Olivier De Funès',
#   '1949',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0060475,tt0250077,tt0065848,tt0064425'],
#  ['nm0000360',
#   'Rebecca De Mornay',
#   '1959',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0104389,tt0089941,tt0086200,tt0396269'],
#  ['nm0000361',
#   'Brian De Palma',
#   '1940',
#   '\\N',
#   'director,writer,producer',
#   'tt0094226,tt0086984,tt0120832,tt0080661'],
#  ['nm0000362',
#   'Danny DeVito',
#   '1944',
#   '\\N',
#   'actor,producer,director',
#   'tt0117008,tt0094142,tt0098621,tt0103776'],
#  ['nm0000363',
#   'Loren Dean',
#   '1969',
#   '\\N',
#   'actor,soundtrack',
#   'tt0186566,tt0120660,tt0112384,tt0098258'],
#  ['nm0000364',
#   'Sandra Dee',
#   '1942',
#   '2005',
#   'actress,soundtrack',
#   'tt0053320,tt0052847,tt0052918,tt0056093'],
#  ['nm0000365',
#   'Julie Delpy',
#   '1969',
#   '\\N',
#   'actress,writer,director',
#   'tt0381681,tt0841044,tt0112471,tt0111507'],
#  ['nm0000366',
#   'Catherine Deneuve',
#   '1943',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0168629,tt0061395,tt0283832,tt0059646'],
#  ['nm0000367',
#   'Gérard Depardieu',
#   '1948',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0120744,tt0103594,tt0099334,tt0099699'],
#  ['nm0000368',
#   'Laura Dern',
#   '1967',
#   '\\N',
#   'actress,producer,writer',
#   'tt0090756,tt0107290,tt7653254,tt2305051'],
#  ['nm0000369',
#   'Matt Dillon',
#   '1964',
#   '\\N',
#   'actor,art_department,director',
#   'tt0129387,tt4003440,tt0097240,tt0375679'],
#  ['nm0000370',
#   'Walt Disney',
#   '1901',
#   '1966',
#   'producer,actor,director',
#   'tt0058331,tt0034492,tt0048280,tt0029583'],
#  ['nm0000371',
#   'Ami Dolenz',
#   '1969',
# ...
#   'director,assistant_director,producer',
#   'tt0101493,tt0089013,tt0090930,tt0088100'],
#  ['nm0000878',
#   'Mario Bava',
#   '1914',
#   '1980',
#   'cinematographer,special_effects,director',
#   'tt0067656,tt0059792,tt0068863,tt0055022'],
#  ['nm0000879',
#   'Anne Baxter',
#   '1923',
#   '1985',
#   'actress,soundtrack,producer',
#   'tt0049833,tt0035015,tt0038873,tt0042192'],
#  ['nm0000880',
#   'Meredith Baxter',
#   '1947',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0074119,tt0073992,tt0083413,tt0105833'],
#  ['nm0000881',
#   'Michael Bay',
#   '1965',
#   '\\N',
#   'producer,director,actor',
#   'tt0120591,tt2109248,tt1055369,tt0418279'],
#  ['nm0000882',
#   'Nathalie Baye',
#   '1948',
#   '\\N',
#   'actress,soundtrack',
#   'tt0204709,tt1650048,tt0264464,tt0174330'],
#  ['nm0000883',
#   'Stephanie Beacham',
#   '1947',
#   '\\N',
#   'actress,soundtrack',
#   'tt0452643,tt0081856,tt0096698,tt0088496'],
#  ['nm0000884',
#   'Jennifer Beals',
#   '1963',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt1037705,tt0085549,tt0113101,tt0088851'],
#  ['nm0000885',
#   'Ned Beatty',
#   '1937',
#   '2021',
#   'actor,soundtrack',
#   'tt0078346,tt0068473,tt0074958,tt0822854'],
#  ['nm0000886',
#   'Warren Beatty',
#   '1937',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0082979,tt0118798,tt0061418,tt0077663'],
#  ['nm0000887',
#   'Harold Becker',
#   '1928',
#   '\\N',
#   'director,producer,cinematographer',
#   'tt0107497,tt0249478,tt0120749,tt0098273'],
#  ['nm0000888',
#   'Meret Becker',
#   '1969',
#   '\\N',
#   'actress,composer,soundtrack',
#   'tt0128133,tt0111183,tt0408306,tt0111613'],
#  ['nm0000889',
#   'Bonnie Bedelia',
#   '1948',
#   '\\N',
#   'actress,soundtrack',
#   'tt0100404,tt0085656,tt0095016,tt0099423'],
#  ['nm0000890',
#   'Noah Beery Jr.',
#   '1913',
#   '1994',
#   'actor,soundtrack',
#   'tt0031762,tt0040724,tt0070895,tt0071042'],
#  ['nm0000891',
#   'Wallace Beery',
#   '1885',
#   '1949',
#   'actor,director,soundtrack',
#   'tt0022958,tt0023948,tt0040271,tt0025948'],
#  ['nm0000892',
#   'Jason Beghe',
#   '1960',
#   '\\N',
#   'actor,producer',
#   'tt0095652,tt0103074,tt0119173,tt1458175'],
#  ['nm0000893',
#   'Ed Begley Jr.',
#   '1949',
#   '\\N',
#   'actor,producer,director',
#   'tt0910936,tt1289401,tt1178663,tt0310281'],
#  ['nm0000894',
#   'Jean-Jacques Beineix',
#   '1946',
#   '2022',
#   'assistant_director,producer,director',
#   'tt0090563,tt0082269,tt0104473,tt0098226'],
#  ['nm0000895',
#   'Barbara Bel Geddes',
#   '1922',
#   '2005',
#   'actress,soundtrack',
#   'tt0077000,tt0040221,tt0052357,tt0042832'],
#  ['nm0000896',
#   'Harry Belafonte',
#   '1927',
#   '\\N',
#   'soundtrack,actor,producer',
#   'tt0116745,tt0053454,tt7349662,tt0308055'],
#  ['nm0000897',
#   'Ralph Bellamy',
#   '1904',
#   '1991',
#   'actor,soundtrack',
#   'tt0034398,tt0032599,tt0086465,tt0028597'],
#  ['nm0000898',
#   'Kathleen Beller',
#   '1956',
#   '\\N',
#   'actress',
#   'tt0071562,tt0077952,tt0081856,tt0084749'],
#  ['nm0000899',
#   'Monica Bellucci',
#   '1964',
#   '\\N',
#   'actress,soundtrack',
#   'tt0465602,tt0213847,tt0242653,tt0234215'],
#  ['nm0000900',
#   'Pamela Bellwood',
#   '1944',
#   '\\N',
#   'actress',
#   'tt0075359,tt0081856,tt0081485,tt0075648'],
#  ['nm0000901',
#   'Jean-Paul Belmondo',
#   '1933',
#   '2021',
#   'actor,producer,stunts',
#   'tt0059592,tt0053472,tt0061452,tt0095386'],
#  ['nm0000902',
#   'Jim Belushi',
#   '1954',
#   '\\N',
#   'actor,music_department,producer',
#   'tt0097637,tt0072562,tt0117468,tt0095963'],
#  ['nm0000903',
#   'Brian Benben',
#   '1956',
#   '\\N',
#   'actor,producer,writer',
#   'tt0099817,tt0167547,tt0110939,tt0098780'],
#  ['nm0000904',
#   'William Bendix',
#   '1906',
#   '1964',
#   'actor,soundtrack,writer',
#   'tt0044863,tt0038369,tt0037017,tt0034798'],
#  ['nm0000905',
#   'Roberto Benigni',
#   '1952',
#   '\\N',
#   'actor,writer,director',
#   'tt0118799,tt0102164,tt0419198,tt0090967'],
#  ['nm0000906',
#   'Annette Bening',
#   '1958',
#   '\\N',
#   'actress,soundtrack,executive',
#   'tt0842926,tt4385888,tt0169547,tt0099703'],
#  ['nm0000907',
#   'Richard Benjamin',
#   '1938',
#   '\\N',
#   'actor,director,producer',
#   'tt0070291,tt0070909,tt0073766,tt0118954'],
#  ['nm0000908',
#   'David Bennent',
#   '1966',
#   '\\N',
#   'actor',
#   'tt0078875,tt0089469,tt0303457,tt0085289'],
#  ['nm0000909',
#   'Constance Bennett',
#   '1904',
#   '1965',
#   'actress,soundtrack,producer',
#   'tt0030442,tt0024506,tt0023786,tt0029682'],
#  ['nm0000910',
#   'Joan Bennett',
#   '1910',
#   '1990',
#   'actress,soundtrack',
#   'tt0059978,tt0048801,tt0076786,tt0033873'],
#  ['nm0000911',
#   'Nigel Bennett',
#   '1949',
#   '\\N',
#   'actor,director,soundtrack',
#   'tt0115243,tt5580390,tt0284978,tt0103417'],
#  ['nm0000912',
#   'Jack Benny',
#   '1894',
#   '1974',
#   'actor,soundtrack,producer',
#   'tt0033457,tt0042116,tt0035446,tt0034780'],
#  ['nm0000913',
#   'Robby Benson',
#   '1956',
#   '\\N',
#   'actor,director,soundtrack',
#   'tt0101414,tt0108778,tt0040053,tt0076500'],
#  ['nm0000914',
#   'Robert Benton',
#   '1932',
#   '\\N',
#   'writer,director,producer',
#   'tt0087921,tt0078346,tt0079417,tt0061418'],
#  ['nm0000915',
#   'Bruce Beresford',
#   '1940',
#   '\\N',
#   'director,producer,writer',
#   'tt4196848,tt0091081,tt0097239,tt0080310'],
#  ['nm0000916',
#   'Peter Berg',
#   '1964',
#   '\\N',
#   'producer,actor,writer',
#   'tt0369339,tt0124198,tt0108724,tt1091191'],
#  ['nm0000917',
#   'Polly Bergen',
#   '1930',
#   '2014',
#   'actress,soundtrack,miscellaneous',
#   'tt0099329,tt0058266,tt0055824,tt0048893'],
#  ['nm0000918',
#   'Helmut Berger',
#   '1944',
#   '\\N',
#   'actor,soundtrack',
#   'tt0073634,tt0064118,tt0099674,tt0068883'],
#  ['nm0000919',
#   'Senta Berger',
#   '1941',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0090465,tt0061568,tt0062657,tt0896680'],
#  ['nm0000920',
#   'Patrick Bergin',
#   '1951',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0102797,tt0105112,tt0102945,tt0102340'],
#  ['nm0000921',
#   'Andrew Bergman',
#   '1945',
#   '\\N',
#   'writer,director,producer',
#   'tt0071230,tt0089155,tt0110167,tt0117765'],
#  ['nm0000922',
#   'Sandahl Bergman',
#   '1951',
#   '\\N',
#   'actress,soundtrack',
#   'tt0093171,tt0082198,tt0090009,tt0089893'],
#  ['nm0000923',
#   'Busby Berkeley',
#   '1895',
#   '1976',
#   'miscellaneous,director,music_department',
#   'tt0025028,tt0026421,tt0027686,tt0029725'],
#  ['nm0000924',
#   'Elizabeth Berkley',
#   '1972',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0114436,tt0116313,tt0256524,tt1231277'],
#  ['nm0000925',
#   'Steven Berkoff',
#   '1937',
#   '\\N',
#   'actor,writer,director',
#   'tt0086960,tt0086034,tt0066921,tt1243957'],
#  ['nm0000926',
#   'Milton Berle',
#   '1908',
#   '2002',
#   'actor,producer,soundtrack',
#   'tt0079588,tt0060801,tt0040041,tt0057193'],
#  ['nm0000927',
#   'Irving Berlin',
#   '1888',
#   '1989',
#   'soundtrack,music_department,writer',
#   'tt0029852,tt0036430,tt0038370,tt0034862'],
#  ['nm0000928',
#   'Sandra Bernhard',
#   '1955',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0102070,tt0138967,tt0085794,tt0120901'],
#  ['nm0000929',
#   'Corbin Bernsen',
#   '1954',
#   '\\N',
#   'actor,producer,director',
#   'tt0491738,tt0097815,tt0110442,tt0373469'],
#  ['nm0000930',
#   'Elmer Bernstein',
#   '1922',
#   '2004',
#   'music_department,composer,soundtrack',
#   'tt0054047,tt0297884,tt0120891,tt0056592'],
#  ['nm0000931',
#   'Elizabeth Berridge',
#   '1962',
#   '\\N',
#   'actress',
#   'tt0106039,tt0082427,tt0317648,tt0086879'],
#  ['nm0000932',
#   'Halle Berry',
#   '1966',
#   '\\N',
#   'actress,producer,executive',
#   'tt0246460,tt0285742,tt0348836,tt0327554'],
#  ['nm0000933',
#   'Valerie Bertinelli',
#   '1960',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0093658,tt0072554,tt0095816,tt0078924'],
#  ['nm0000934',
#   'Bernardo Bertolucci',
#   '1941',
#   '2018',
#   'writer,director,producer',
#   'tt0065571,tt0070849,tt0117737,tt0093389'],
#  ['nm0000935',
#   'Bibi Besch',
#   '1942',
#   '1996',
#   'actress',
#   'tt0100814,tt0098384,tt0104118,tt0084726'],
#  ['nm0000936',
#   'Martine Beswick',
#   '1941',
#   '\\N',
#   'actress,soundtrack',
#   'tt0059800,tt0061429,tt0068502,tt0057076'],
#  ['nm0000937',
#   'Richard Beymer',
#   '1939',
#   '\\N',
#   'actor,cinematographer,editor',
#   'tt0098936,tt0055614,tt0056197,tt0226836'],
#  ['nm0000938',
#   'Daniela Bianchi',
#   '1942',
#   '\\N',
#   'actress',
#   'tt0062397,tt0057076,tt0062078,tt0060704'],
#  ['nm0000939',
#   'Adrian Biddle',
#   '1952',
#   '2005',
#   'cinematographer,camera_department',
#   'tt0103594,tt0090605,tt0103074,tt0434409'],
#  ['nm0000940',
#   'Bigas Luna',
#   '1946',
#   '2013',
#   'writer,director,producer',
#   'tt0104545,tt0090644,tt0078934,tt0129923'],
#  ['nm0000941',
#   'Kathryn Bigelow',
#   '1951',
#   '\\N',
#   'director,producer,actress',
#   'tt1790885,tt0093605,tt0887912,tt0114558'],
#  ['nm0000942',
#   'Theodore Bikel',
#   '1924',
#   '2015',
#   'actor,soundtrack,director',
#   'tt0051525,tt0058385,tt0043265,tt0050356'],
#  ['nm0000943',
#   'Traci Bingham',
#   '1968',
#   '\\N',
#   'actress',
#   'tt0096542,tt0373163,tt0114608,tt3572718'],
#  ['nm0000944',
#   'Antonia Bird',
#   '1951',
#   '2013',
#   'director,producer',
#   'tt0263181,tt0110889,tt0129332,tt0119092'],
#  ['nm0000945',
#   'Jane Birkin',
#   '1946',
#   '\\N',
#   'actress,soundtrack,director',
#   'tt0083908,tt0901473,tt0060176,tt0077413'],
#  ['nm0000946',
#   'Whit Bissell',
#   '1909',
#   '1996',
#   'actor,soundtrack',
#   'tt0054387,tt0070723,tt0054047,tt0046876'],
#  ['nm0000947',
#   'Karen Black',
#   '1939',
#   '2013',
#   'actress,soundtrack,writer',
#   'tt0065724,tt0073440,tt0071577,tt0251736'],
#  ['nm0000948',
#   'Shane Black',
#   '1961',
#   '\\N',
#   'writer,actor,director',
#   'tt0373469,tt0093773,tt3799694,tt1300854'],
#  ['nm0000949',
#   'Cate Blanchett',
#   '1969',
#   '\\N',
#   'actress,producer,writer',
#   'tt0120737,tt2402927,tt2334873,tt0338751'],
#  ['nm0000950',
#   'Brenda Blethyn',
#   '1946',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0117589,tt0414387,tt0195234,tt0147004'],
#  ['nm0000951',
#   'Joan Blondell',
#   '1906',
#   '1979',
#   'actress,soundtrack',
#   'tt0050307,tt0077631,tt0022676,tt0079672'],
#  ['nm0000952',
#   'Hart Bochner',
#   '1956',
#   '\\N',
#   'actor,director,writer',
#   'tt0088206,tt0095016,tt0078902,tt0106364'],
#  ['nm0000953',
#   'Peter Bogdanovich',
#   '1939',
#   '2022',
#   'actor,director,writer',
#   'tt0063671,tt0070510,tt0067328,tt0079843'],
#  ['nm0000954',
#   'Jon Bon Jovi',
#   '1962',
#   '\\N',
#   'soundtrack,actor,writer',
#   'tt0100994,tt0141926,tt0384286,tt1389096'],
#  ['nm0000955',
#   'Ward Bond',
#   '1903',
#   '1960',
#   'actor,soundtrack',
#   'tt0033870,tt0045061,tt0049730,tt0038650'],
#  ['nm0000956',
#   'Lisa Bonet',
#   '1967',
#   '\\N',
#   'actress,director,soundtrack',
#   'tt0086687,tt0092563,tt0146882,tt0120660'],
#  ['nm0000957',
#   'Jan de Bont',
#   '1943',
#   '\\N',
#   'cinematographer,camera_department,producer',
#   'tt0171363,tt0117998,tt0181689,tt0111257'],
#  ['nm0000958',
#   'John Boorman',
#   '1933',
#   '\\N',
#   'producer,director,writer',
#   'tt0082348,tt0068473,tt0093209,tt0120706'],
#  ['nm0000959',
#   'Powers Boothe',
#   '1948',
#   '2017',
#   'actor,soundtrack',
#   'tt0114576,tt0848228,tt0108358,tt0401792'],
#  ['nm0000960',
#   'Barry Bostwick',
#   '1945',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0073629,tt0117723,tt1811315,tt0084316'],
#  ['nm0000961',
#   'Timothy Bottoms',
#   '1951',
#   '\\N',
#   'actor,producer',
#   'tt0067328,tt0363589,tt0070509,tt0067277'],
#  ['nm0000962',
#   'Carole Bouquet',
#   '1957',
#   '\\N',
#   'actress,director',
#   'tt0082398,tt0398664,tt0075824,tt0281364'],
#  ['nm0000963',
#   'Stephen Boyd',
#   '1931',
#   '1977',
#   'actor,soundtrack',
#   'tt0059219,tt0060397,tt0060801,tt0052618'],
#  ['nm0000964',
#   'Charles Boyer',
#   '1899',
#   '1978',
#   'actor,producer,soundtrack',
#   'tt0028739,tt0036855,tt0029855,tt0033722'],
#  ['nm0000965',
#   'Danny Boyle',
#   '1956',
#   '\\N',
#   'director,producer,writer',
#   'tt0289043,tt1010048,tt1542344,tt0111149'],
#  ['nm0000966',
#   'Lorraine Bracco',
#   '1954',
#   '\\N',
#   'actress,producer,director',
#   'tt0141842,tt0099685,tt0112461,tt0104839'],
#  ['nm0000967',
#   'Eric Braeden',
#   '1941',
#   '\\N',
#   'actor,producer',
#   'tt0067065,tt0069658,tt0064177,tt0120338'],
#  ['nm0000968',
#   'Sônia Braga',
#   '1950',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0095654,tt0089424,tt0077452'],
#  ['nm0000969',
#   'Lillo Brancato',
#   '1976',
#   '\\N',
#   'actor,producer',
#   'tt0110971,tt0180052,tt0112740,tt0106489'],
#  ['nm0000970',
#   'Jonathan Brandis',
#   '1976',
#   '2003',
#   'actor,miscellaneous,director',
#   'tt0106126,tt0100240,tt0104670,tt0099864'],
#  ['nm0000971',
#   'Nicoletta Braschi',
#   '1960',
#   '\\N',
#   'actress,producer',
#   'tt6752992,tt0090967,tt0102164,tt0118799'],
#  ['nm0000972',
#   'Tinto Brass',
#   '1933',
#   '\\N',
#   'actor,director,writer',
#   'tt0061493,tt0065161,tt0080491,tt0057942'],
#  ['nm0000973',
#   'Benjamin Bratt',
#   '1963',
#   '\\N',
#   'actor,producer,director',
#   'tt0181865,tt0212346,tt2380307,tt0098844'],
#  ['nm0000974',
#   'Walter Brennan',
#   '1894',
#   '1974',
#   'actor,soundtrack',
#   'tt0037382,tt0033253,tt0040724,tt0053221'],
#  ['nm0000975',
#   'Robert Bresson',
#   '1901',
#   '1999',
#   'writer,director,editor',
#   'tt0060138,tt0061996,tt0042619,tt0049902'],
#  ['nm0000976',
#   'Martin Brest',
#   '1951',
#   '\\N',
#   'director,actor,producer',
#   'tt0105323,tt0095631,tt0086960,tt0119643'],
#  ['nm0000977',
#   'Beau Bridges',
#   '1941',
#   '\\N',
#   'actor,director,producer',
#   'tt0097322,tt1033575,tt0413895,tt0467197'],
#  ['nm0000978',
#   'Lloyd Bridges',
#   '1913',
#   '1998',
#   'actor,soundtrack,director',
#   'tt0083530,tt0080339,tt0107144,tt0102059'],
#  ['nm0000979',
#   'Wilford Brimley',
#   '1934',
#   '2020',
#   'actor,stunts',
#   'tt0084787,tt0087781,tt0088933,tt0119360'],
#  ['nm0000980',
#   'Jim Broadbent',
#   '1949',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0203009,tt0217505,tt1431181,tt1007029'],
#  ['nm0000981',
#   'James Brolin',
#   '1940',
#   '\\N',
#   'actor,producer,director',
#   'tt0070909,tt0077294,tt0078767,tt0181865'],
#  ['nm0000982',
#   'Josh Brolin',
#   '1968',
#   '\\N',
#   'actor,producer,writer',
#   'tt4154796,tt1791528,tt0477348,tt4154756'],
#  ['nm0000983',
#   'Albert Brooks',
#   '1947',
#   '\\N',
#   'actor,writer,director',
#   'tt0092699,tt0089504,tt0101698,tt0780504'],
#  ['nm0000984',
#   'Avery Brooks',
#   '1948',
#   '\\N',
#   'actor,director,music_department',
#   'tt0120609,tt0179626,tt0106145,tt0120586'],
#  ['nm0000985',
#   'James L. Brooks',
#   '1940',
#   '\\N',
#   'writer,producer,miscellaneous',
#   'tt0371246,tt0086425,tt0092699,tt0119822'],
#  ['nm0000986',
#   'Bryan Brown',
#   '1947',
#   '\\N',
#   'actor,producer,writer',
#   'tt0094889,tt0145547,tt2404233,tt0080310'],
#  ['nm0000987',
#   'Jim Brown',
#   '1936',
#   '\\N',
#   'actor,producer,director',
#   'tt0061578,tt0116996,tt0093894,tt0146838'],
#  ['nm0000988',
#   'Jerry Bruckheimer',
#   '1943',
#   '\\N',
#   'producer,music_department,actor',
#   'tt0120591,tt0210945,tt0383574,tt0449088'],
#  ['nm0000989',
#   'Yul Brynner',
#   '1920',
#   '1985',
#   'actor,director,producer',
#   'tt0054047,tt0049833,tt0049408,tt0070909'],
#  ['nm0000990',
#   'Betty Buckley',
#   '1947',
#   '\\N',
#   'actress,soundtrack,composer',
#   'tt0074285,tt4972582,tt0949731,tt0095174'],
#  ['nm0000991',
#   'Geneviève Bujold',
#   '1942',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0064030,tt0094964,tt0079592,tt0077355'],
#  ['nm0000992',
#   'Billie Burke',
#   '1884',
#   '1970',
#   'actress,soundtrack',
#   'tt0030442,tt0032138,tt0029682,tt0023948'],
#  ['nm0000993',
#   'Carol Burnett',
#   '1933',
#   '\\N',
#   'soundtrack,actress,producer',
#   'tt0105017,tt0061240,tt0451079,tt0083564'],
#  ['nm0000994',
#   'Raymond Burr',
#   '1917',
#   '1993',
#   'actor,production_manager,director',
#   'tt0047396,tt0197521,tt0087344,tt0061266'],
#  ['nm0000995',
#   'Ellen Burstyn',
#   '1932',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0071115,tt0067328,tt0070047,tt0180093'],
#  ['nm0000996',
#   'LeVar Burton',
#   '1957',
#   '\\N',
#   'actor,director,producer',
#   'tt0111280,tt0253754,tt0120844,tt0117731'],
#  ['nm0000997',
#   'Gary Busey',
#   '1944',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0105690,tt0077280,tt0093409,tt0102685'],
#  ['nm0000998',
#   'Jake Busey',
#   '1971',
#   '\\N',
#   'actor,producer,music_department',
#   'tt7555294,tt4574334,tt0120201,tt0116365'],
#  ['nm0000999',
#   'Red Buttons',
#   '1919',
#   '2006',
#   'actor,soundtrack,miscellaneous',
#   'tt0069113,tt0056197,tt0050933,tt0076538'],
#  ['nm0001000',
#   'Tom Byron',
#   '1961',
#   '\\N',
#   'actor,director,producer',
#   'tt2059288,tt0151056,tt0097039,tt0178845'],
#  ['nm0001001',
#   'James Caan',
#   '1940',
#   '\\N',
#   'actor,soundtrack,director',
#   'tt0068646,tt0073631,tt0100157,tt0083190'],
#  ...]

# %%
imdb_names_df.columns.tolist()
# Out:
# ['nconst',
#  'primaryName',
#  'birthYear',
#  'deathYear',
#  'primaryProfession',
#  'knownForTitles']

# %%
cross_imdb_wiki_list = []
for person in imdb_name_list:
    if person[1] in wiki_cast['Performer'].values:
        cross_imdb_wiki_list.append(person)

# %%
cross_name_list = (set([r[1] for r in cross_imdb_wiki_list]))
len(cross_name_list) # <- Missing 2 cast members
# Out:
# 157

# %%
# MAKING CSV FOR CROSS IMDb LIST
# import csv
# with open('imdb_wiki_filter.csv', 'w', encoding = 'utf-8') as outfile:
#     csvout = csv.writer(outfile)
#     csvout.writerow(names.columns.tolist())
#     csvout.writerows(cross_imdb_wiki_list)

# %%
from collections import Counter

Counter([r[1] for r in cross_imdb_wiki_list]).most_common(10)
# Out:
# [('Tom Davis', 56),
#  ("Mike O'Brien", 56),
#  ('Bill Murray', 35),
#  ('Tim Robinson', 32),
#  ('Leslie Jones', 26),
#  ('Chris Elliott', 24),
#  ('Mike Myers', 23),
#  ('Jeff Richards', 23),
#  ('Dennis Miller', 21),
#  ('Victoria Jackson', 18)]

# %%
cross_imdb_wiki_list
# Out:
# [['nm0000004',
#   'John Belushi',
#   '1949',
#   '1982',
#   'actor,soundtrack,writer',
#   'tt0078723,tt0072562,tt0077975,tt0080455'],
#  ['nm0000101',
#   'Dan Aykroyd',
#   '1952',
#   '\\N',
#   'writer,actor,producer',
#   'tt0097428,tt0118747,tt0087332,tt0080455'],
#  ['nm0000195',
#   'Bill Murray',
#   '1950',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt1748122,tt0128445,tt0362270,tt0335266'],
#  ['nm0000196',
#   'Mike Myers',
#   '1963',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0295178,tt0145660,tt0118655,tt0811138'],
#  ['nm0000331',
#   'Chevy Chase',
#   '1943',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0085995,tt0097958,tt0080487,tt0092086'],
#  ['nm0000345',
#   'Billy Crystal',
#   '1948',
#   '\\N',
#   'actor,writer,producer',
#   'tt0101587,tt0098635,tt0113097,tt0122933'],
#  ['nm0000349',
#   'Joan Cusack',
#   '1962',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0119229,tt1659337,tt0119360,tt0096463'],
#  ['nm0000375',
#   'Robert Downey Jr.',
#   '1965',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt1300854,tt0371746,tt4154796,tt0988045'],
#  ['nm0000394',
#   'Chris Farley',
#   '1964',
#   '1997',
#   'actor,soundtrack,stunts',
#   'tt0118708,tt0115697,tt0114694,tt0106598'],
#  ['nm0000413',
#   'Janeane Garofalo',
#   '1964',
#   '\\N',
#   'actress,writer,producer',
#   'tt0382932,tt0132347,tt0117979,tt0243655'],
#  ['nm0000506',
#   'Julia Louis-Dreyfus',
#   '1961',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0462128,tt1759761,tt2390361,tt0098904'],
#  ['nm0000552',
#   'Eddie Murphy',
#   '1961',
#   '\\N',
#   'actor,writer,producer',
#   'tt0117218,tt0443489,tt0094898,tt0126029'],
#  ['nm0000902',
#   'Jim Belushi',
#   '1954',
#   '\\N',
#   'actor,music_department,producer',
#   'tt0097637,tt0072562,tt0117468,tt0095963'],
#  ['nm0001022',
#   'Dana Carvey',
#   '1955',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0072562,tt0108525,tt0105793,tt0295427'],
#  ['nm0001191',
#   'Adam Sandler',
#   '1966',
#   '\\N',
#   'actor,producer,writer',
#   'tt0120484,tt0120888,tt0142342,tt0185431'],
#  ['nm0001302',
#   'Christopher Guest',
#   '1948',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0218839,tt0310281,tt0088258,tt0118111'],
#  ['nm0001309',
#   'Anthony Michael Hall',
#   '1968',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0468569,tt2361317,tt4758646,tt1100089'],
#  ['nm0001484',
#   'Jon Lovitz',
#   '1957',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0104694,tt0107659,tt0147612,tt0437863'],
#  ['nm0001542',
#   'Jay Mohr',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt0116695,tt0120241,tt0139239,tt0180052'],
#  ['nm0001642',
#   'Randy Quaid',
#   '1950',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0097958,tt0116629,tt0116778,tt0388795'],
#  ['nm0001674',
#   'Chris Rock',
#   '1965',
#   '\\N',
#   'producer,actor,writer',
#   'tt2784678,tt0325537,tt0398165,tt0351283'],
#  ['nm0001705',
#   'Rob Schneider',
#   '1963',
#   '\\N',
#   'actor,writer,producer',
#   'tt0255798,tt0302640,tt0367652,tt0205000'],
#  ['nm0001737',
#   'Martin Short',
#   '1950',
#   '\\N',
#   'actor,writer,producer',
#   'tt0093260,tt0452681,tt0092086,tt1791528'],
#  ['nm0001774',
#   'Ben Stiller',
#   '1965',
#   '\\N',
#   'producer,actor,director',
#   'tt0196229,tt0359950,tt0942385,tt1608290'],
#  ['nm0001834',
#   'Damon Wayans',
#   '1960',
#   '\\N',
#   'actor,writer,producer',
#   'tt0110443,tt0104897,tt0273855,tt0102266'],
#  ['nm0002056',
#   'Christine Ebersole',
#   '1953',
#   '\\N',
#   'actress,soundtrack',
#   'tt0115697,tt0993846,tt0086879,tt0110989'],
#  ['nm0002071',
#   'Will Ferrell',
#   '1967',
#   '\\N',
#   'producer,actor,soundtrack',
#   'tt0357413,tt0445934,tt1229340,tt0415306'],
#  ['nm0004852',
#   'Jane Curtin',
#   '1947',
#   '\\N',
#   'actress,soundtrack',
#   'tt0106598,tt0115082,tt0086742,tt1155056'],
#  ['nm0004887',
#   'Nora Dunn',
#   '1952',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0405336,tt0910936,tt0157503,tt0120188'],
#  ['nm0005218',
#   'Tim Meadows',
#   '1961',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0841046,tt0377092,tt3960412,tt0213790'],
#  ['nm0005265',
#   'Kevin Nealon',
#   '1953',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0072562,tt0116483,tt0439100,tt0120888'],
#  ['nm0005450',
#   'David Spade',
#   '1964',
#   '\\N',
#   'actor,writer,producer',
#   'tt0245686,tt0120917,tt0437863,tt0114694'],
#  ['nm0035488',
#   'Fred Armisen',
#   '1966',
#   '\\N',
#   'music_department,actor,writer',
#   'tt0357413,tt1282140,tt0072562,tt1780441'],
#  ['nm0043839',
#   'Peter Aykroyd',
#   '1955',
#   '2021',
#   'writer,producer,actor',
#   'tt0106598,tt0095687,tt0090056,tt0102558'],
#  ['nm0052218',
#   'Morwenna Banks',
#   '1961',
#   '\\N',
#   'actress,writer,producer',
#   'tt0760141,tt0466664,tt2245003,tt5839960'],
#  ['nm0108028',
#   'Jim Breuer',
#   '1967',
#   '\\N',
#   'actor,producer,writer',
#   'tt1222817,tt0120693,tt0120913,tt0144168'],
#  ['nm0112944',
#   'A. Whitney Brown',
#   '1952',
#   '\\N',
#   'writer,actor',
#   'tt0096708,tt0072562,tt0166039,tt1094991'],
#  ['nm0128639',
#   'Beth Cahill',
#   '\\N',
#   '\\N',
#   'actress,costume_designer,miscellaneous',
#   'tt0155764,tt0262411,tt0164930,tt0072562'],
#  ['nm0165971',
#   'Ellen Cleghorne',
#   '1965',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0120591,tt0200550,tt2126357,tt0185431'],
#  ['nm0168642',
#   'George Coe',
#   '1929',
#   '2015',
#   'actor,producer,director',
#   'tt1399103,tt0089901,tt0073747,tt0092666'],
#  ['nm0203457',
#   'Pete Davidson',
#   '1993',
#   '\\N',
#   'actor,producer,writer',
#   'tt9686708,tt5304992,tt0800325,tt6334354'],
#  ['nm0205569',
#   'Tom Davis',
#   '1952',
#   '2012',
#   'writer,actor,producer',
#   'tt0086465,tt0251075,tt0106598,tt0072562'],
#  ['nm0205570',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'sound_department,music_department',
#   'tt0120241,tt0100613,tt0803033,tt0087998'],
#  ['nm0205571', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0124718,tt0463970'],
#  ['nm0205572', 'Tom Davis', '\\N', '\\N', 'art_department', 'tt0118632'],
#  ['nm0226986',
#   'Denny Dillon',
#   '1951',
#   '\\N',
#   'actress,soundtrack',
#   'tt0475276,tt0098780,tt0268380,tt0076666'],
#  ['nm0236519',
#   'Brian Doyle-Murray',
#   '1945',
#   '\\N',
#   'actor,writer,producer',
#   'tt0105793,tt0102138,tt0080487,tt0097958'],
#  ['nm0237222',
#   'Rachel Dratch',
#   '1966',
#   '\\N',
#   'actress,soundtrack,miscellaneous',
#   'tt1564367,tt0389860,tt0814331,tt8169446'],
#  ['nm0241208',
#   'Robin Duke',
#   '1954',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0075578,tt0117108,tt0107048,tt0072562'],
#  ['nm0249931',
#   'Dean Edwards',
#   '1970',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0910898,tt2784678,tt0421143,tt0413300'],
#  ['nm0254402',
#   'Chris Elliott',
#   '1960',
#   '\\N',
#   'actor,writer,producer',
#   'tt0107048,tt0109361,tt0129387,tt0096754'],
#  ['nm0254403',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'production_designer,set_decorator,art_department',
#   'tt0103873,tt0834001,tt0110311,tt0107822'],
#  ['nm0254404', 'Chris Elliott', '\\N', '\\N', 'director', 'tt0222820'],
#  ['nm0266422',
#   'Jimmy Fallon',
#   '1974',
#   '\\N',
#   'writer,soundtrack,producer',
#   'tt3444938,tt1231460,tt0332047,tt0316732'],
#  ['nm0275486',
#   'Tina Fey',
#   '1970',
#   '\\N',
#   'writer,actress,producer',
#   'tt1850457,tt0377092,tt1279935,tt0496424'],
#  ['nm0287182',
#   'Will Forte',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt3230454,tt1490017,tt1470023,tt1821549'],
#  ['nm0291253',
#   'Al Franken',
#   '1951',
#   '\\N',
#   'writer,producer,actor',
#   'tt0114571,tt0368008,tt0086465,tt0072562'],
#  ['nm0309430',
#   'Ana Gasteyer',
#   '1967',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0207201,tt1232200,tt4366830,tt0377092'],
#  ['nm0331906',
#   'Gilbert Gottfried',
#   '1955',
#   '2022',
#   'actor,writer,soundtrack',
#   'tt0103639,tt0092644,tt0098987,tt0100419'],
#  ['nm0343444',
#   'Mary Gross',
#   '1953',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0120791,tt0243736,tt0094846,tt0072562'],
#  ['nm0352778',
#   'Bill Hader',
#   '1978',
#   '\\N',
#   'actor,writer,producer',
#   'tt1571249,tt3152624,tt7349950,tt2096673'],
#  ['nm0355357',
#   'Brad Hall',
#   '1958',
#   '\\N',
#   'writer,producer,actor',
#   'tt0120623,tt2080359,tt6388738,tt0101055'],
#  ['nm0355358',
#   'Brad Hall',
#   '1968',
#   '\\N',
#   'miscellaneous,producer,assistant_director',
#   'tt0109830,tt0120399,tt0120829'],
#  ['nm0355360',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'producer,director,miscellaneous',
#   'tt2468756,tt0800142,tt8793210,tt2953706'],
#  ['nm0356025',
#   'Rich Hall',
#   '1954',
#   '\\N',
#   'writer,actor,producer',
#   'tt0072562,tt0325939,tt0085065,tt1430607'],
#  ['nm0358669',
#   'Darrell Hammond',
#   '1955',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0799949,tt0118747,tt0306047,tt0072562'],
#  ['nm0367005',
#   'Phil Hartman',
#   '1948',
#   '1998',
#   'actor,writer,soundtrack',
#   'tt0122718,tt0108174,tt0116705,tt0112095'],
#  ['nm0393660',
#   'Jan Hooks',
#   '1957',
#   '2014',
#   'actress,soundtrack',
#   'tt0103776,tt0115082,tt0106598,tt0089791'],
#  ['nm0399994',
#   'Yvonne Hudson',
#   '\\N',
#   '\\N',
#   'actress,miscellaneous',
#   'tt0277167,tt0072562'],
#  ['nm0404525',
#   'Melanie Hutsell',
#   '\\N',
#   '\\N',
#   'actress,soundtrack',
#   'tt4789300,tt1478338,tt0072562,tt2191701'],
#  ['nm0414130',
#   'Victoria Jackson',
#   '1959',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt1394227,tt0098546,tt0099819,tt0094846'],
#  ['nm0428655',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'editor,editorial_department',
#   'tt0272338,tt1791528,tt1560747,tt0120863'],
#  ['nm0428656',
#   'Leslie Jones',
#   '1967',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0072562,tt6802400,tt1289401,tt2461150'],
#  ['nm0428658', 'Leslie Jones', '\\N', '\\N', 'music_department', 'tt0116442'],
#  ['nm0428659',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0113492,tt0180073,tt0773756,tt0120738'],
#  ['nm0428660', 'Leslie Jones', '\\N', '\\N', 'script_department', 'tt0094643'],
#  ['nm0441592',
#   'Chris Kattan',
#   '1970',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0120770,tt0279493,tt2479478,tt0185371'],
#  ['nm0443730',
#   'Tim Kazurinsky',
#   '1950',
#   '\\N',
#   'actor,writer,miscellaneous',
#   'tt0090583,tt0089822,tt0082801,tt0072562'],
#  ['nm0452716',
#   'Laura Kightlinger',
#   '1964',
#   '\\N',
#   'producer,actress,writer',
#   'tt4116284,tt8324422,tt0460619,tt0157246'],
#  ['nm0453115',
#   'Taran Killam',
#   '1982',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt2024544,tt0072562,tt5689068,tt4000956'],
#  ['nm0462712',
#   'David Koechner',
#   '1962',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0425061,tt0357413,tt0427944,tt1229340'],
#  ['nm0471856',
#   'Gary Kroeger',
#   '1957',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0200525,tt0072562,tt0046593,tt0086765'],
#  ['nm0491005',
#   'Matthew Laurance',
#   '1950',
#   '\\N',
#   'actor,soundtrack',
#   'tt0112111,tt0085475,tt0098772,tt0090060'],
#  ['nm0560257',
#   'Gail Matthius',
#   '1953',
#   '\\N',
#   'actress,soundtrack',
#   'tt0072562,tt0162796,tt0083530,tt0103373'],
#  ['nm0571106',
#   'Michael McKean',
#   '1947',
#   '\\N',
#   'actor,soundtrack,director',
#   'tt0088258,tt0088930,tt0310281,tt3032476'],
#  ['nm0571897',
#   'Mark McKinney',
#   '1959',
#   '\\N',
#   'actor,writer,producer',
#   'tt0387779,tt0096626,tt0120770,tt1159996'],
#  ['nm0571898',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0277370,tt1212450,tt0107927,tt1731701'],
#  ['nm0571952',
#   'Kate McKinnon',
#   '1984',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt4799050,tt0072562,tt6394270,tt1289401'],
#  ['nm0582418',
#   'Laurie Metcalf',
#   '1955',
#   '\\N',
#   'actress,soundtrack,miscellaneous',
#   'tt0094540,tt0120082,tt0114709,tt4925292'],
#  ['nm0588222',
#   'Dennis Miller',
#   '1953',
#   '\\N',
#   'writer,producer,actor',
#   'tt0113957,tt0245686,tt0119731,tt0117826'],
#  ['nm0588223',
#   'Dennis Miller',
#   '1937',
#   '\\N',
#   'actor',
#   'tt0385463,tt0081561,tt0108709,tt0135848'],
#  ['nm0588224',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department,director',
#   'tt0226416,tt0072792,tt0279429,tt0081563'],
#  ['nm0591576',
#   'Jerry Minor',
#   '1969',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt2463288,tt0817538,tt0323633,tt0357413'],
#  ['nm0605078',
#   'Tracy Morgan',
#   '1943',
#   '\\N',
#   'actress,writer',
#   'tt0074377,tt0074621,tt0069098,tt0068892'],
#  ['nm0605079',
#   'Tracy Morgan',
#   '1968',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0496424,tt0787474,tt1385867,tt0426592'],
#  ['nm0606541',
#   'Garrett Morris',
#   '1937',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0072562,tt0478970,tt0106598,tt0278488'],
#  ['nm0614853', 'Bill Murray', '\\N', '\\N', 'miscellaneous', 'tt0097132'],
#  ['nm0628170',
#   'Laraine Newman',
#   '1952',
#   '\\N',
#   'actress,soundtrack,miscellaneous',
#   'tt0102719,tt0106598,tt0116705,tt0120669'],
#  ['nm0637038',
#   'Don Novello',
#   '1943',
#   '\\N',
#   'actor,writer,producer',
#   'tt0072562,tt0112642,tt0099674,tt0230011'],
#  ['nm0639733',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'sound_department,composer',
#   'tt0159876,tt0340434,tt0127341,tt0153362'],
#  ['nm0639734',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'camera_department,actor,art_department',
#   'tt0094834,tt0117652,tt0110939,tt0109021'],
#  ['nm0639735',
#   "Mike O'Brien",
#   '1964',
#   '2015',
#   'actor',
#   'tt2347497,tt1159996,tt1095174,tt0433400'],
#  ['nm0640874',
#   "Michael O'Donoghue",
#   '1940',
#   '1994',
#   'writer,actor,miscellaneous',
#   'tt0096061,tt0079583,tt0079522,tt0072562'],
#  ['nm0652783',
#   'Cheri Oteri',
#   '1962',
#   '\\N',
#   'actress,writer,producer',
#   'tt0141369,tt0175142,tt0119528,tt0405336'],
#  ['nm0663177',
#   'Chris Parnell',
#   '1967',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0357413,tt2861424,tt0841046,tt1232829'],
#  ['nm0685472',
#   'Joe Piscopo',
#   '1951',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0092226,tt0072562,tt0094961,tt0087507'],
#  ['nm0688132',
#   'Amy Poehler',
#   '1971',
#   '\\N',
#   'actress,producer,writer',
#   'tt2096673,tt0871426,tt1266020,tt0072562'],
#  ['nm0695104',
#   'Emily Prager',
#   '1948',
#   '\\N',
#   'actress,writer,camera_department',
#   'tt0048860,tt0094674,tt0079583,tt0059992'],
#  ['nm0703800',
#   'Colin Quinn',
#   '1959',
#   '\\N',
#   'writer,actor,producer',
#   'tt3152624,tt3314416,tt1375670,tt0120770'],
#  ['nm0705717',
#   'Gilda Radner',
#   '1946',
#   '1989',
#   'actress,soundtrack,writer',
#   'tt0070290,tt0091178,tt0084049,tt0072562'],
#  ['nm0711014',
#   'Tony Rosato',
#   '1954',
#   '2017',
#   'actor,writer',
#   'tt0075578,tt0117593,tt0088582,tt0207701'],
#  ['nm0724143',
#   'Jeff Richards',
#   '1924',
#   '1989',
#   'actor,soundtrack',
#   'tt0049578,tt0052932,tt0047472,tt0050327'],
#  ['nm0724144',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'animation_department,art_department',
#   'tt0104254,tt0120800,tt0111333,tt0094449'],
#  ['nm0724145',
#   'Jeff Richards',
#   '1974',
#   '\\N',
#   'actor,writer,producer',
#   'tt0759475,tt0468999,tt4687632,tt0072562'],
#  ['nm0724146',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0162349,tt0076781,tt0087348,tt0090631'],
#  ['nm0728315',
#   'Ann Risley',
#   '1949',
#   '\\N',
#   'actress',
#   'tt0072562,tt0081554,tt0081518,tt0082525'],
#  ['nm0733146',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0088591,tt0834001,tt4698684,tt0443334'],
#  ['nm0733427',
#   'Harry Shearer',
#   '1943',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0120382,tt0310281,tt0096697,tt0088258'],
#  ['nm0734153',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0284126,tt9372772,tt0142646,tt0286159'],
#  ['nm0734236',
#   'Charles Rocket',
#   '1949',
#   '2005',
#   'actor,soundtrack',
#   'tt0120913,tt0099348,tt0108122,tt0109686'],
#  ['nm0748973',
#   'Maya Rudolph',
#   '1972',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt1727388,tt1176740,tt1478338,tt1791528'],
#  ['nm0764445',
#   'Horatio Sanz',
#   '1969',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0285462,tt1920849,tt0215129,tt1045778'],
#  ['nm0771680',
#   'Tom Schiller',
#   '1949',
#   '\\N',
#   'writer,actor,director',
#   'tt0087817,tt0072562,tt3677742,tt0304046'],
#  ['nm0787238',
#   'Paul Shaffer',
#   '1949',
#   '\\N',
#   'music_department,soundtrack,actor',
#   'tt0088258,tt0119282,tt0118747,tt4537842'],
#  ['nm0788340',
#   'Molly Shannon',
#   '1964',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0362120,tt0167427,tt0151738,tt4158876'],
#  ['nm0798971',
#   'Sarah Silverman',
#   '1970',
#   '\\N',
#   'actress,producer,writer',
#   'tt0332379,tt0821375,tt1772341,tt5848272'],
#  ['nm0806912',
#   'Robert Smigel',
#   '1960',
#   '\\N',
#   'writer,producer,actor',
#   'tt0185431,tt0072562,tt0106052,tt0272338'],
#  ['nm0827298',
#   'Pamela Stephenson',
#   '1949',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0080253,tt0086393,tt0082517,tt0199218'],
#  ['nm0837177',
#   'Jason Sudeikis',
#   '1975',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt1723121,tt10986410,tt4680182,tt1499658'],
#  ['nm0842140',
#   'Julia Sweeney',
#   '1959',
#   '\\N',
#   'actress,producer,writer',
#   'tt2467372,tt0498994,tt8962130,tt10417836'],
#  ['nm0842202',
#   'Terry Sweeney',
#   '1950',
#   '\\N',
#   'writer,actor,miscellaneous',
#   'tt0240596,tt0098300,tt0342139,tt0093443'],
#  ['nm0860380',
#   'Kenan Thompson',
#   '1978',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0417148,tt0072562,tt0115231,tt0119215'],
#  ['nm0888503',
#   'Danitra Vance',
#   '1954',
#   '1994',
#   'actress,soundtrack',
#   'tt0098621,tt0102316,tt0102174,tt0086759'],
#  ['nm0899865',
#   'Dan Vitale',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0088804,tt0086768,tt1744760,tt0072562'],
#  ['nm0915778',
#   'Patrick Weathers',
#   '1954',
#   '\\N',
#   'actor,music_department',
#   'tt1741243,tt1790886,tt1996346,tt0094291'],
#  ['nm0933146',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'visual_effects',
#   'tt0102034,tt0120611,tt0107415,tt0274164'],
#  ['nm0937747',
#   'Fred Wolf',
#   '1932',
#   '\\N',
#   'producer,writer,miscellaneous',
#   'tt0061421,tt0092345,tt0131613,tt0067595'],
#  ['nm0937748',
#   'Fred Wolf',
#   '1964',
#   '\\N',
#   'writer,actor,director',
#   'tt0115697,tt0120654,tt2191701,tt0185431'],
#  ['nm0937750', 'Fred Wolf', '1910', '2000', 'actor', 'tt2157952,tt0154574'],
#  ['nm0958993',
#   'Alan Zweibel',
#   '1950',
#   '\\N',
#   'writer,producer,actor',
#   'tt0090459,tt0072562,tt0092925,tt0110687'],
#  ['nm0971596',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'composer,music_department,editor',
#   'tt1167638,tt0120662,tt0118661,tt0203009'],
#  ['nm1008747', 'Rich Hall', '\\N', '\\N', 'writer', 'tt0861361'],
#  ['nm10124289', 'Jeff Richards', '\\N', '\\N', 'miscellaneous', 'tt0076598'],
#  ['nm10179693', 'Tom Davis', '\\N', '\\N', nan, 'tt8948614'],
#  ['nm10184827', "Mike O'Brien", '\\N', '\\N', nan, 'tt3562462'],
#  ['nm10230310', 'Colin Quinn', '\\N', '\\N', 'cinematographer', 'tt8819940'],
#  ['nm1024878',
#   'Seth Meyers',
#   '1973',
#   '\\N',
#   'writer,actor,producer',
#   'tt1598822,tt4677934,tt0072562,tt3513388'],
#  ['nm10254000', 'Pete Davidson', '\\N', '\\N', 'producer', '\\N'],
#  ['nm10271496', 'Chris Elliott', '\\N', '\\N', nan, '\\N'],
#  ['nm1027256', 'Chris Parnell', '\\N', '\\N', 'actor', 'tt0265736'],
#  ['nm1034017',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0450852,tt0258476,tt1165357,tt1111291'],
#  ['nm10343807', 'Bill Murray', '\\N', '\\N', 'actor', 'tt6384192,tt13998382'],
#  ['nm10365967', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm10417023', 'Tom Davis', '\\N', '\\N', 'actor', 'tt9639868'],
#  ['nm10437112', 'Dean Edwards', '\\N', '\\N', nan, 'tt3644198'],
#  ['nm10440389', 'Chris Rock', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10452456', 'Mark McKinney', '\\N', '\\N', nan, '\\N'],
#  ['nm10455749', "Mike O'Brien", '\\N', '\\N', 'editor', 'tt9734382,tt9883024'],
#  ['nm10455801',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'assistant_director',
#   'tt0123965'],
#  ['nm1047319', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0295476'],
#  ['nm1047581', 'Brad Hall', '\\N', '\\N', 'miscellaneous', 'tt0294941'],
#  ['nm10513107', 'Lauren Holt', '\\N', '\\N', 'camera_department', '\\N'],
#  ['nm10521259', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm10614185', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm10639792', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm10661678', 'Eddie Murphy', '\\N', '\\N', nan, '\\N'],
#  ['nm10666508', 'Tim Robinson', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10697087', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm10765303', 'Tom Davis', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10793005', "Mike O'Brien", '\\N', '\\N', 'actor', '\\N'],
#  ['nm1083889',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'miscellaneous,producer,director',
#   'tt1716744,tt1448500,tt7498020,tt0217061'],
#  ['nm10871329', 'Victoria Jackson', '\\N', '\\N', 'actress', '\\N'],
#  ['nm10879663', 'Terry Sweeney', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10937994',
#   'Tim Meadows',
#   '\\N',
#   '\\N',
#   nan,
#   'tt10740136,tt13743066,tt10863916,tt14016930'],
#  ['nm11060621',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'composer,sound_department',
#   'tt12649418'],
#  ['nm11079865', 'Tom Davis', '\\N', '\\N', 'miscellaneous', '\\N'],
#  ['nm11155585', 'Dennis Miller', '\\N', '\\N', 'actor', 'tt10974848'],
#  ['nm11162204', "Mike O'Brien", '\\N', '\\N', 'writer,producer', 'tt11348726'],
#  ['nm11185833', 'Tom Davis', '\\N', '\\N', 'composer', 'tt11137268'],
#  ['nm11217821',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'camera_department,production_manager,script_department',
#   'tt11475900'],
#  ['nm11222962', 'Will Ferrell', '\\N', '\\N', 'producer', 'tt11462908'],
#  ['nm11270045', "Mike O'Brien", '\\N', '\\N', nan, 'tt11599804'],
#  ['nm11279790',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt11394180'],
#  ['nm11291807', 'Chris Farley', '\\N', '\\N', 'stunts', 'tt1972591'],
#  ['nm11297717', 'Tom Davis', '\\N', '\\N', 'actor', '\\N'],
#  ['nm11322159', 'Fred Wolf', '\\N', '\\N', nan, '\\N'],
#  ['nm11331059', 'Chris Elliott', '\\N', '\\N', 'special_effects', '\\N'],
#  ['nm11436906',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'visual_effects',
#   'tt12003714'],
#  ['nm1143861',
#   'Michaela Watkins',
#   '1971',
#   '\\N',
#   'actress,writer,producer',
#   'tt1932718,tt1655460,tt2294677,tt1212436'],
#  ['nm11486610', 'Tom Davis', '\\N', '\\N', nan, 'tt1020913'],
#  ['nm1154288', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt0116783'],
#  ['nm11555653', 'Jerry Minor', '\\N', '\\N', nan, 'tt0401003'],
#  ['nm11573043', 'Dan Vitale', '\\N', '\\N', nan, '\\N'],
#  ['nm11610626', 'Leslie Jones', '\\N', '\\N', 'actress', '\\N'],
#  ['nm1162741',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0288154,tt0189500'],
#  ['nm11707153', 'Jeff Richards', '\\N', '\\N', nan, 'tt11011652'],
#  ['nm11718692', "Mike O'Brien", '\\N', '\\N', 'set_decorator', 'tt12661304'],
#  ['nm11728273', 'Heidi Gardner', '\\N', '\\N', 'actress', '\\N'],
#  ['nm11765333', 'Casey Wilson', '\\N', '\\N', nan, '\\N'],
#  ['nm11768616', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt3783812'],
#  ['nm11775788', 'Martin Short', '\\N', '\\N', nan, 'tt12800308'],
#  ['nm11885823', 'Tom Davis', '\\N', '\\N', 'actor', 'tt5295032'],
#  ['nm11936425', 'Victoria Jackson', '\\N', '\\N', 'actress', '\\N'],
#  ['nm11950689', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm11950691', 'Victoria Jackson', '\\N', '\\N', nan, '\\N'],
#  ['nm11971632', "Mike O'Brien", '\\N', '\\N', 'actor', '\\N'],
#  ['nm11972013', 'Tim Robinson', '\\N', '\\N', 'set_decorator', 'tt10505762'],
#  ['nm11992562', 'Sarah Sherman', '\\N', '\\N', 'director', '\\N'],
#  ['nm1201491', 'Dennis Miller', '\\N', '\\N', 'casting_director', 'tt0325502'],
#  ['nm12033473', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt14643040'],
#  ['nm1219950',
#   'Eddie Murphy',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0830515,tt10539608,tt2802144,tt2527336'],
#  ['nm12244326', 'Tom Davis', '\\N', '\\N', 'cinematographer', '\\N'],
#  ['nm12246661',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt13026762'],
#  ['nm12251094', 'Brad Hall', '\\N', '\\N', nan, 'tt1442550'],
#  ['nm12286233', 'Leslie Jones', '\\N', '\\N', 'script_department', '\\N'],
#  ['nm12293622', 'Dean Edwards', '\\N', '\\N', 'actor', '\\N'],
#  ['nm12383124', 'Tom Davis', '\\N', '\\N', nan, 'tt0262152,tt13471320'],
#  ['nm12400603', 'Dan Vitale', '\\N', '\\N', 'actor', 'tt14236360'],
#  ['nm12406972', 'Victoria Jackson', '\\N', '\\N', nan, '\\N'],
#  ['nm12488967', 'Tim Meadows', '\\N', '\\N', 'actor', 'tt11394158'],
#  ['nm12577961', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt14643040'],
#  ['nm12624642', 'Tom Davis', '\\N', '\\N', nan, 'tt13682176'],
#  ['nm12695477', 'Rob Schneider', '\\N', '\\N', 'producer', 'tt4829936'],
#  ['nm12705773', 'Victoria Jackson', '\\N', '\\N', 'actress', 'tt6932494'],
#  ['nm12744425',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'miscellaneous',
#   'tt14855722'],
#  ['nm12748185', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm12750797', 'Mike Myers', '\\N', '\\N', nan, '\\N'],
#  ['nm12750908', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0124718'],
#  ['nm12785038', 'Victoria Jackson', '\\N', '\\N', nan, '\\N'],
#  ['nm12785675', 'Jimmy Fallon', '\\N', '\\N', 'art_department', 'tt6133466'],
#  ['nm12815517', 'Victoria Jackson', '\\N', '\\N', 'producer', 'tt14894996'],
#  ['nm1282073', 'Leslie Jones', '\\N', '\\N', nan, 'tt0341708'],
#  ['nm12840270',
#   'Chris Farley',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department,editor',
#   'tt14779558,tt16589596'],
#  ['nm12851138', 'Colin Quinn', '\\N', '\\N', nan, '\\N'],
#  ['nm12890222', 'Christopher Guest', '\\N', '\\N', nan, '\\N'],
#  ['nm12931864', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm1293885',
#   'Bobby Moynihan',
#   '1977',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt13622982,tt10662034,tt0072562'],
#  ['nm12980144', 'Leslie Jones', '\\N', '\\N', 'art_department', 'tt8579674'],
#  ['nm12981476',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt15488832'],
#  ['nm13013859', "Michael O'Donoghue", '\\N', '\\N', 'sound_department', '\\N'],
#  ['nm13032378',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'music_department',
#   'tt15669416'],
#  ['nm13042925', 'Mike Myers', '\\N', '\\N', 'camera_department', 'tt15714650'],
#  ['nm13153060', 'Eddie Murphy', '\\N', '\\N', 'actor,miscellaneous', '\\N'],
#  ['nm13186344',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'assistant_director,script_department',
#   '\\N'],
#  ['nm1325419',
#   'Kristen Wiig',
#   '1973',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt1478338,tt1608290,tt0359950,tt1571249'],
#  ['nm13266366', 'Jeff Richards', '\\N', '\\N', 'actor', '\\N'],
#  ['nm13281524', "Mike O'Brien", '\\N', '\\N', 'producer', '\\N'],
#  ['nm13281861', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm13308038', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm13337965', 'Leslie Jones', '\\N', '\\N', 'executive', '\\N'],
#  ['nm13349009', 'Brad Hall', '\\N', '\\N', nan, 'tt13639450,tt12747694'],
#  ['nm13349549', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm13353192', 'Chris Parnell', '\\N', '\\N', nan, '\\N'],
#  ['nm1338203',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'costume_department,make_up_department',
#   'tt0444631,tt0357577'],
#  ['nm13382765', 'Tim Meadows', '\\N', '\\N', nan, '\\N'],
#  ['nm13405263', 'Rich Hall', '\\N', '\\N', nan, '\\N'],
#  ['nm13467885',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'costume_department',
#   'tt15659704'],
#  ['nm13479010', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt18546600'],
#  ['nm13488570',
#   'Kyle Mooney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt18764878'],
#  ['nm1349208', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt6168110'],
#  ['nm13569869', 'Mike Myers', '\\N', '\\N', nan, '\\N'],
#  ['nm1386521', 'Bill Murray', '\\N', '\\N', 'actor', 'tt0351810'],
#  ['nm1396935',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'producer,director',
#   'tt0968732,tt0775402,tt3558296,tt1715425'],
#  ['nm1401295', 'Martin Short', '\\N', '\\N', nan, '\\N'],
#  ['nm1427969', 'Tracy Morgan', '\\N', '\\N', nan, 'tt1173421'],
#  ['nm1443527',
#   'Rob Riggle',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt2096672,tt1119646,tt0115147,tt1232829'],
#  ['nm1459509',
#   'Finesse Mitchell',
#   '1972',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0785077,tt0072562,tt0951216,tt0790804'],
#  ['nm1480256',
#   'Rich Hall',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1517640,tt1330618,tt0108709'],
#  ['nm1510062',
#   'Mikey Day',
#   '1980',
#   '\\N',
#   'actor,writer,producer',
#   'tt0072562,tt2076347,tt1217217,tt4000956'],
#  ['nm1558206',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1387418,tt1730767,tt0398291'],
#  ['nm1578488',
#   'Adam Sandler',
#   '\\N',
#   '\\N',
#   'director,producer,editorial_department',
#   'tt13689618,tt10428498,tt0068120,tt12116598'],
#  ['nm1654181',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'miscellaneous,sound_department',
#   'tt0399977,tt0412109,tt6261554,tt0338616'],
#  ['nm1676221',
#   'Andy Samberg',
#   '1978',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0072562,tt3960412,tt2467372,tt9484998'],
#  ['nm1687172', 'Paul Brittain', '\\N', '\\N', 'actor', 'tt0413660'],
#  ['nm1737885',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'visual_effects',
#   'tt0382992,tt0317705,tt0198781'],
#  ['nm1746994', 'Christopher Guest', '\\N', '\\N', nan, 'tt0040053'],
#  ['nm1752760',
#   'Mike Myers',
#   '1969',
#   '\\N',
#   nan,
#   'tt0476931,tt1020929,tt2140691,tt1045847'],
#  ['nm1771830', 'Chris Rock', '\\N', '\\N', 'actor', 'tt0434026'],
#  ['nm1807732', 'Tom Davis', '\\N', '\\N', 'miscellaneous', 'tt0439911'],
#  ['nm1829094', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt0083731'],
#  ['nm1831668', 'Bill Murray', '\\N', '\\N', 'cinematographer', 'tt0448004'],
#  ['nm1840659',
#   'Nasim Pedrad',
#   '1981',
#   '\\N',
#   'actress,producer,writer',
#   'tt6139732,tt1690953,tt10338160,tt2490326'],
#  ['nm1843779',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'writer,director,producer',
#   'tt1877853,tt0904115'],
#  ['nm1877197',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'make_up_department',
#   'tt6769236,tt5941780,tt10483744,tt0455841'],
#  ['nm1906042',
#   'Colin Jost',
#   '1982',
#   '\\N',
#   'writer,actor,miscellaneous',
#   'tt0072562,tt1292566,tt1361336,tt6802400'],
#  ['nm1907457',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'actor,writer',
#   'tt0457251,tt0961721'],
#  ['nm1934954', "Mike O'Brien", '\\N', '\\N', 'visual_effects', 'tt0120841'],
#  ['nm1942080',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'producer,director,writer',
#   'tt4276112,tt2062966,tt1215983,tt0789775'],
#  ['nm1962331', 'Casey Wilson', '1987', '\\N', 'actor', 'tt0457394'],
#  ['nm1971084', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt0105986'],
#  ['nm1978226',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor,producer',
#   'tt0483776,tt5786442,tt1309181,tt0484257'],
#  ['nm1981812', 'Bill Murray', '\\N', '\\N', 'actor', 'tt0122145'],
#  ['nm1988111',
#   'Casey Wilson',
#   '1980',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0901476,tt1509788,tt1103153,tt2267998'],
#  ['nm2018971', 'Bill Murray', '\\N', '\\N', nan, 'tt0281438'],
#  ['nm2019506', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm2062929',
#   'Christopher Guest',
#   '1975',
#   '\\N',
#   'producer,visual_effects,miscellaneous',
#   'tt12716280,tt10538562,tt1822842,tt8022434'],
#  ['nm2076868',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'actress',
#   'tt0106179,tt0120901,tt0242733,tt0204993'],
#  ['nm2095085',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt1334555'],
#  ['nm2114510', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt0497043'],
#  ['nm2141165',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   'editorial_department,visual_effects,art_department',
#   'tt0482481,tt2551436,tt0354333,tt1529670'],
#  ['nm2159521',
#   'Phil Hartman',
#   '\\N',
#   '\\N',
#   'visual_effects,special_effects',
#   'tt2417108,tt0844479,tt0409182'],
#  ['nm2163846', 'Mike Myers', '\\N', '\\N', 'visual_effects', 'tt0079945'],
#  ['nm2193928',
#   'Tom Davis',
#   '1949',
#   '\\N',
#   nan,
#   'tt0787424,tt0496360,tt9822404,tt0123338'],
#  ['nm2212031',
#   'Abby Elliott',
#   '1987',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0072562,tt1291150,tt1663143,tt1411238'],
#  ['nm2213674',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'editorial_department,sound_department',
#   'tt0458339,tt3748528,tt0816711,tt1446714'],
#  ['nm2221621',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1474200,tt0770745,tt0882741'],
#  ['nm2251356', 'Chris Elliott', '\\N', '\\N', 'miscellaneous', 'tt0861343'],
#  ['nm2264620',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0803030,tt0818620,tt0758745,tt0427848'],
#  ['nm2269751', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0494235'],
#  ['nm2275887',
#   'John Milhiser',
#   '\\N',
#   '\\N',
#   'actor,writer,editor',
#   'tt0072562,tt5990096,tt1289401,tt4061080'],
#  ['nm2323596',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   nan,
#   'tt4397866,tt1636189,tt1636331,tt0181269'],
#  ['nm2354000',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt1642373,tt1811323,tt0840371'],
#  ['nm2379655', 'Dennis Miller', '\\N', '\\N', 'editor', 'tt0119277'],
#  ['nm2385054', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt0972846'],
#  ['nm2396934',
#   'Michael McKean',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0129910'],
#  ['nm2460645',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor,music_department',
#   'tt0382382'],
#  ['nm2511320', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt0368257'],
#  ['nm2522357',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'location_management',
#   'tt0238304,tt0238305,tt0238303,tt0104512'],
#  ['nm2529548',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   nan,
#   'tt14773254,tt13645690,tt12058768,tt0298674'],
#  ['nm2544987', 'Mike Myers', '\\N', '\\N', 'camera_department', 'tt0115279'],
#  ['nm2572052',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt6306064,tt0095408'],
#  ['nm2597086',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0457433,tt0470023,tt1107855,tt0464041'],
#  ['nm2605900',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department',
#   'tt3765728,tt1242542'],
#  ['nm2610385',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'actress,director,writer',
#   'tt1006983,tt3773358,tt14945492,tt9170758'],
#  ['nm2620120',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'transportation_department,miscellaneous',
#   'tt1272878,tt0765010,tt0452625,tt0457572'],
#  ['nm2641016', "Mike O'Brien", '\\N', '\\N', 'editor', 'tt0949671'],
#  ['nm2642562',
#   'Lauren Holt',
#   '\\N',
#   '\\N',
#   'animation_department,editorial_department,miscellaneous',
#   'tt1022605,tt3449322,tt0815250'],
#  ['nm2660474',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'miscellaneous',
#   'tt0846694,tt0416779'],
#  ['nm2672552', 'Tom Davis', '\\N', '\\N', 'visual_effects', 'tt0349903'],
#  ['nm2675038', 'Rob Schneider', '\\N', '\\N', 'actor', 'tt1039621'],
#  ['nm2682875', 'Fred Wolf', '\\N', '\\N', 'actor', 'tt1032874'],
#  ['nm2720332', 'Alex Moffat', '\\N', '\\N', 'actor', 'tt0112230,tt0111999'],
#  ['nm2722633',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'animation_department,art_department',
#   'tt0874300,tt1751105,tt3529198,tt8651594'],
#  ['nm2761469', 'Chris Parnell', '\\N', '\\N', nan, 'tt1020109,tt0343316'],
#  ['nm2767460',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt0099566'],
#  ['nm2776607',
#   'Aristotle Athari',
#   '\\N',
#   '\\N',
#   'actor,director,cinematographer',
#   'tt9173436,tt5918784,tt5917146,tt7322648'],
#  ['nm2790436',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'writer,producer,actor',
#   'tt2421910,tt1112661'],
#  ['nm2809577',
#   'Jenny Slate',
#   '1982',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt2709768,tt2948356,tt4481414,tt2910274'],
#  ['nm2825937', 'Tom Davis', '\\N', '\\N', nan, 'tt1136478,tt2787132'],
#  ['nm2846691', 'Fred Wolf', '\\N', '\\N', nan, '\\N'],
#  ['nm2846739',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'miscellaneous,camera_department',
#   'tt2719804,tt1357005,tt1100051'],
#  ['nm2870034', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0106137'],
#  ['nm2881085', 'Tom Davis', '\\N', '\\N', 'location_management', 'tt0086192'],
#  ['nm2945828',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0133302,tt1626811,tt0115355,tt0120801'],
#  ['nm2966932',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'editor,editorial_department',
#   'tt1732762,tt1210095'],
#  ['nm2968461',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'producer,camera_department',
#   'tt0400410,tt0939564'],
#  ['nm2997086', 'Martin Short', '\\N', '\\N', 'actor', 'tt0079687'],
#  ['nm3009952', 'Kate McKinnon', '\\N', '\\N', 'actress', 'tt0092225'],
#  ['nm3025851', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt0051297'],
#  ['nm3054255', 'Tom Davis', '\\N', '\\N', 'actor', 'tt1250756'],
#  ['nm3076354',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt4229954,tt0775529,tt0494864'],
#  ['nm3080722',
#   'Beck Bennett',
#   '\\N',
#   '\\N',
#   'actor,writer,producer',
#   'tt3470600,tt7979580,tt5531466,tt1086064'],
#  ['nm3085792', 'Leslie Jones', '\\N', '\\N', 'actor', 'tt0031055'],
#  ['nm3089340',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1366945,tt1107855,tt2182211,tt0313038'],
#  ['nm3174251', 'Jeff Richards', '\\N', '\\N', 'cinematographer', 'tt0393274'],
#  ['nm3174274',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'producer,miscellaneous',
#   'tt1584933,tt0401759,tt9248866,tt0368107'],
#  ['nm3199973', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1326172'],
#  ['nm3213154',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'animation_department',
#   'tt0174392'],
#  ['nm3291792', 'Mike Myers', '\\N', '\\N', 'camera_department', 'tt1362049'],
#  ['nm3324982',
#   'Kyle Mooney',
#   '1984',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt15977708,tt2139555,tt1608290,tt5805752'],
#  ['nm3364779',
#   'Vanessa Bayer',
#   '1981',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0072562,tt2989524,tt1711525,tt3152624'],
#  ['nm3448959', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt1279966'],
#  ['nm3483071', 'Tom Davis', '\\N', '\\N', 'camera_department', 'tt0128707'],
#  ['nm3510834',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'camera_department,director,actor',
#   'tt1462862,tt1507979,tt1462856'],
#  ['nm3550886',
#   'Sasheer Zamata',
#   '1986',
#   '\\N',
#   'actress,writer,producer',
#   'tt4018068,tt11394332,tt4018066,tt6791096'],
#  ['nm3578809', 'Bill Murray', '\\N', '\\N', 'producer', 'tt1490534'],
#  ['nm3600806', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt1587314,tt1505388'],
#  ['nm3625945', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1493558'],
#  ['nm3644706',
#   'Noël Wells',
#   '1986',
#   '\\N',
#   'actress,editor,miscellaneous',
#   'tt0072562,tt7713450,tt6212496,tt9184820'],
#  ['nm3673242',
#   'Bill Murray',
#   '1908',
#   '1986',
#   nan,
#   'tt1687207,tt1600694,tt1538443'],
#  ['nm3677317', 'Jeff Richards', '\\N', '\\N', 'miscellaneous', 'tt0072265'],
#  ['nm3678497', 'Rich Hall', '\\N', '\\N', 'director,writer', 'tt1542770'],
#  ['nm3697626',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'writer,composer,music_department',
#   'tt1551638'],
#  ['nm3710139', 'Tom Davis', '\\N', '\\N', 'miscellaneous', 'tt1517228'],
#  ['nm3743306',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'actor,producer,director',
#   'tt2265215,tt1982864,tt1565981,tt2382015'],
#  ['nm3758883', 'Leslie Jones', '\\N', '\\N', 'director,producer', 'tt1575557'],
#  ['nm3760937',
#   'Luke Null',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1545490,tt0072562,tt9881938,tt3146066'],
#  ['nm3830257',
#   'Melissa Villaseñor',
#   '1987',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt1809001,tt0072562,tt5848272,tt10682266'],
#  ['nm3846408',
#   'Michael Che',
#   '\\N',
#   '\\N',
#   'writer,actor,camera_department',
#   'tt0072562,tt12762460,tt0499556,tt2784678'],
#  ['nm3890281', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm3895112', 'Tom Davis', '\\N', '\\N', 'art_department', 'tt1326139'],
#  ['nm3910307', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt0380060'],
#  ['nm3911007', 'Chris Rock', '\\N', '\\N', 'actor', 'tt1556078'],
#  ['nm3915439', "Mike O'Brien", '\\N', '\\N', 'miscellaneous', 'tt1193138'],
#  ['nm3920709',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'camera_department,cinematographer,director',
#   'tt6091368,tt2445666,tt6083648,tt9748306'],
#  ['nm3930873',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department,editor',
#   'tt0389911,tt1663232,tt4502270,tt4504130'],
#  ['nm3933527', 'Tim Robinson', '\\N', '\\N', 'camera_department', 'tt1664843'],
#  ['nm3941693',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt0829176'],
#  ['nm3950870', 'Chris Elliott', '\\N', '\\N', nan, '\\N'],
#  ['nm3981127', 'Casey Wilson', '\\N', '\\N', 'camera_department', 'tt1687906'],
#  ['nm3982894',
#   'Jay Pharoah',
#   '1987',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0072562,tt5774044,tt1408253,tt7153766'],
#  ['nm3997014',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt2790032,tt2790152,tt2798906'],
#  ['nm4013649', 'Mike Myers', '\\N', '\\N', nan, 'tt0096563'],
#  ['nm4028688', 'Mike Myers', '\\N', '\\N', 'writer', 'tt1708468'],
#  ['nm4039470', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm4100863', 'Emily Prager', '\\N', '\\N', nan, '\\N'],
#  ['nm4104448',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'make_up_department',
#   'tt1518327'],
#  ['nm4142075', 'Chris Elliott', '\\N', '\\N', nan, 'tt0262152'],
#  ['nm4180892', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt1777032'],
#  ['nm4200503',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'writer,actor,producer',
#   'tt10050772,tt6343706,tt4779762,tt0072562'],
#  ['nm4204968',
#   'Paul Brittain',
#   '1977',
#   '\\N',
#   'actor,soundtrack',
#   'tt0837562,tt0072562,tt2176287,tt2510894'],
#  ['nm4215887',
#   'Martin Short',
#   '1943',
#   '2020',
#   'writer,producer,miscellaneous',
#   'tt1791798,tt0938980,tt5747320,tt1297329'],
#  ['nm4256972', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt1493151,tt1813516'],
#  ['nm4257796', 'Bill Murray', '\\N', '\\N', 'actor', 'tt1810727'],
#  ['nm4269084',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'actor,writer,producer',
#   'tt4468740,tt4158096,tt4673856,tt8096690'],
#  ['nm4289813', 'Bill Murray', '\\N', '\\N', nan, 'tt1740656'],
#  ['nm4310690',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'sound_department,art_department,camera_department',
#   'tt2147467,tt1837678'],
#  ['nm4326982',
#   'Eddie Murphy',
#   '\\N',
#   '\\N',
#   'animation_department',
#   'tt0492509'],
#  ['nm4339544',
#   'Jon Rudnitsky',
#   '\\N',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0072562,tt5719700'],
#  ['nm4343157', 'Tom Davis', '1945', '\\N', 'actor', 'tt1850339'],
#  ['nm4359305', 'Tim Robinson', '\\N', '\\N', 'camera_department', 'tt1857742'],
#  ['nm4380769',
#   'Mike Myers',
#   '\\N',
#   '\\N',
#   'special_effects',
#   'tt5657856,tt1817273,tt6133466,tt1219289'],
#  ['nm4408208', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1885305'],
#  ['nm4435047',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1911645,tt2450652,tt2282941'],
#  ['nm4473273', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1434435'],
#  ['nm4481414', 'Bill Murray', '\\N', '\\N', 'actor', 'tt1884251'],
#  ['nm4489897', 'Casey Wilson', '\\N', '\\N', 'actress', 'tt1951191'],
#  ['nm4520392',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department',
#   'tt1972582'],
#  ['nm4536114', 'Casey Wilson', '\\N', '\\N', 'editor', 'tt1982864'],
#  ['nm4539981', 'Mike Myers', '\\N', '\\N', 'costume_department', 'tt1984991'],
#  ['nm4562498',
#   'James Austin Johnson',
#   '\\N',
#   '\\N',
#   'actor,writer,miscellaneous',
#   'tt0072562,tt8036272,tt3032476,tt0475290'],
#  ['nm4573109', 'Tracy Morgan', '\\N', '\\N', nan, '\\N'],
#  ['nm4583865', 'Sarah Sherman', '\\N', '\\N', 'actress', 'tt1999871'],
#  ['nm4592210',
#   'Yvonne Hudson',
#   '\\N',
#   '\\N',
#   'miscellaneous,actress,casting_director',
#   'tt2033480,tt3526474,tt2142935,tt2156935'],
#  ['nm4603998', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm4633705',
#   'Tracy Morgan',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt1887882'],
#  ['nm4657360', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2043951'],
#  ['nm4658374', 'Mike Myers', '\\N', '\\N', 'special_effects', 'tt2004334'],
#  ['nm4702231',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt0321473'],
#  ['nm4800774', "Mike O'Brien", '\\N', '\\N', nan, 'tt1170243'],
#  ['nm4806887',
#   'Chloe Fineman',
#   '1988',
#   '\\N',
#   'actress,location_management',
#   'tt0072562,tt8577458,tt6527474,tt5460226'],
#  ['nm4826405', 'Bill Murray', '\\N', '\\N', 'art_department', 'tt2147467'],
#  ['nm4828992', 'Tracy Morgan', '\\N', '\\N', nan, '\\N'],
#  ['nm4832730',
#   'Tom Davis',
#   '1967',
#   '\\N',
#   'miscellaneous',
#   'tt2288153,tt0189246,tt0081857,tt2161907'],
#  ['nm4857388', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm4895587', 'Rich Hall', '\\N', '\\N', nan, 'tt0146386'],
#  ['nm4906505', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2247021'],
#  ['nm4926467', 'Bill Murray', '\\N', '\\N', 'actor', 'tt2202391'],
#  ['nm4929014', 'Tim Robinson', '\\N', '\\N', nan, 'tt2275949'],
#  ['nm4930586', 'Chris Farley', '\\N', '\\N', 'writer', 'tt2275913'],
#  ['nm4945455',
#   'Ego Nwodim',
#   '\\N',
#   '\\N',
#   'actress,soundtrack,costume_department',
#   'tt6110318,tt3598030,tt0072562,tt7379494'],
#  ['nm4949478', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2300919'],
#  ['nm4977915', 'Leslie Jones', '\\N', '\\N', 'miscellaneous', 'tt0104423'],
#  ['nm4997878', 'Yvonne Hudson', '\\N', '\\N', nan, 'tt2355949'],
#  ['nm5073476', 'Tracy Morgan', '\\N', '\\N', nan, 'tt0063892'],
#  ['nm5120390',
#   'Brooks Wheelan',
#   '1986',
#   '\\N',
#   'actor,writer,producer',
#   'tt10050772,tt0072562,tt1600194,tt5244974'],
#  ['nm5122180',
#   'Terry Sweeney',
#   '\\N',
#   '\\N',
#   'actor,soundtrack',
#   'tt2386353,tt2576688,tt3313760,tt3517306'],
#  ['nm5127148', 'Kyle Mooney', '\\N', '\\N', nan, '\\N'],
#  ['nm5139377', 'Bill Murray', '\\N', '\\N', 'sound_department', 'tt2243836'],
#  ['nm5163268', 'Dennis Miller', '\\N', '\\N', nan, 'tt1275472'],
#  ['nm5198446',
#   'Cecily Strong',
#   '1984',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0072562,tt11808942,tt2702724,tt1289401'],
#  ['nm5206346', 'Chris Farley', '\\N', '\\N', 'actor', 'tt2328612'],
#  ['nm5230632', 'Bill Murray', '\\N', '\\N', 'sound_department', 'tt2356940'],
#  ['nm5255287',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'casting_department',
#   'tt3218622,tt5648234,tt2378652,tt11940818'],
#  ['nm5262775',
#   'Aidy Bryant',
#   '1987',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt5462602,tt11092142,tt8962130,tt0072562'],
#  ['nm5268180',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'costume_department,actress',
#   'tt0297607,tt0360255,tt0358809,tt4568496'],
#  ['nm5296555', 'Terry Sweeney', '\\N', '\\N', nan, '\\N'],
#  ['nm5298712', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm5311105', "Mike O'Brien", '\\N', '\\N', 'actor,producer', 'tt2423776'],
#  ['nm5358702', 'Chris Elliott', '\\N', '\\N', nan, '\\N'],
#  ['nm5368653', 'Tom Schiller', '\\N', '\\N', 'actor', 'tt9068272'],
#  ['nm5374987', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt1957867'],
#  ['nm5381865', 'Terry Sweeney', '\\N', '\\N', 'actor', 'tt2474812'],
#  ['nm5398255', 'Rich Hall', '\\N', '\\N', 'art_department', 'tt1650554'],
#  ['nm5412083',
#   'Chris Redd',
#   '\\N',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt3960412,tt5884792,tt7286456,tt0072562'],
#  ['nm5415866', 'Phil Hartman', '\\N', '\\N', nan, '\\N'],
#  ['nm5428992', 'Tim Robinson', '1935', '2020', 'writer', 'tt2582038'],
#  ['nm5460097', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2625536'],
#  ['nm5462850', 'Rich Hall', '\\N', '\\N', 'camera_department', 'tt2369573'],
#  ['nm5465769', 'Seth Meyers', '\\N', '\\N', nan, 'tt0124932'],
#  ['nm5479432', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm5500570', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt2671586'],
#  ['nm5518479', 'Victoria Jackson', '\\N', '\\N', nan, 'tt2307673'],
#  ['nm5539698', 'Tom Davis', '\\N', '\\N', nan, 'tt2728770'],
#  ['nm5575320', 'Mike Myers', '\\N', '\\N', 'art_department', 'tt0299712'],
#  ['nm5601269', 'Leslie Jones', '\\N', '\\N', nan, 'tt2803888'],
#  ['nm5602633', 'Sarah Sherman', '\\N', '\\N', 'actress', 'tt2803096'],
#  ['nm5609314', 'Sarah Sherman', '\\N', '\\N', 'producer,actress', 'tt2261238'],
#  ['nm5628268',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'producer,writer',
#   'tt4742812,tt2828570,tt3503754,tt5774598'],
#  ['nm5629957', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm5633884', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm5642597', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm5643945', 'Dennis Miller', '\\N', '\\N', 'producer', 'tt2866916'],
#  ['nm5648732', 'Brad Hall', '\\N', '\\N', 'actor', 'tt0122827'],
#  ['nm5659941', 'Dennis Miller', '\\N', '\\N', nan, 'tt0123338'],
#  ['nm5666584',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt3856408,tt3972208,tt1535977'],
#  ['nm5692847', 'Leslie Jones', '\\N', '\\N', nan, '\\N'],
#  ['nm5695760', 'Mike Myers', '\\N', '\\N', 'art_director', 'tt2916548'],
#  ['nm5706361', 'Mark McKinney', '\\N', '\\N', 'cinematographer', 'tt2954994'],
#  ['nm5708457', 'Brad Hall', '\\N', '\\N', 'director,producer', 'tt2953902'],
#  ['nm5770787',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor,producer,writer',
#   'tt7525600,tt2826134,tt7525638,tt6227116'],
#  ['nm5803981',
#   'Alex Moffat',
#   '1982',
#   '\\N',
#   'actor,director',
#   'tt9866072,tt1217217,tt5848272,tt3219194'],
#  ['nm5838946', 'Tracy Morgan', '\\N', '\\N', 'miscellaneous', 'tt0100332'],
#  ['nm5848694', 'Chris Rock', '\\N', '\\N', 'producer', 'tt2357748'],
#  ['nm5872054', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm5894755', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3091734'],
#  ['nm5905712', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3147486'],
#  ['nm5906920',
#   'Heidi Gardner',
#   '1983',
#   '\\N',
#   'actress,writer',
#   'tt4180560,tt5101204,tt10324166,tt5619332'],
#  ['nm5907222', 'Tom Davis', '\\N', '\\N', nan, 'tt0133302'],
#  ['nm5922353',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'director,actor,writer',
#   'tt3162968'],
#  ['nm5946351', 'Mike Myers', '\\N', '\\N', 'composer', 'tt3185956'],
#  ['nm5960919', 'Molly Shannon', '\\N', '\\N', 'actress', 'tt0362542'],
#  ['nm5977544', 'Alex Moffat', '\\N', '\\N', nan, '\\N'],
#  ['nm5987491', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3231836'],
#  ['nm6036494', 'Jim Downey', '\\N', '\\N', 'producer', 'tt3281976'],
#  ['nm6133039', 'Christopher Guest', '\\N', '\\N', 'actor', 'tt3384430'],
#  ['nm6151446', 'Chris Parnell', '\\N', '\\N', 'cinematographer', 'tt3402362'],
#  ['nm6158455',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'animation_department',
#   'tt2510894,tt4624424,tt4633694,tt5220122'],
#  ['nm6255561', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt3449744'],
#  ['nm6267657', 'Tom Davis', '\\N', '\\N', 'actor', 'tt3512322'],
#  ['nm6283130', 'Dennis Miller', '\\N', '\\N', 'miscellaneous', 'tt3458560'],
#  ['nm6286141', 'Jeff Richards', '\\N', '\\N', nan, '\\N'],
#  ['nm6291555',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt1179069'],
#  ['nm6299248',
#   'Bowen Yang',
#   '1990',
#   '\\N',
#   'actor,writer,producer',
#   'tt2587452,tt6078096,tt2452244'],
#  ['nm6299629', 'Victoria Jackson', '\\N', '\\N', 'actress', 'tt3172618'],
#  ['nm6310930',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'producer,director,camera_department',
#   'tt8909686,tt14435296,tt0199257,tt8909538'],
#  ['nm6344885', 'Bill Murray', '\\N', '\\N', 'editor', 'tt0115367'],
#  ['nm6350126', 'Chris Parnell', '\\N', '\\N', 'executive', '\\N'],
#  ['nm6365877', 'Bill Murray', '\\N', '\\N', 'director', 'tt3603706'],
#  ['nm6366128',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'producer,production_manager,miscellaneous',
#   'tt4575056,tt2630898,tt3548962,tt3562626'],
#  ['nm6375565', "Michael O'Donoghue", '\\N', '\\N', 'actor', 'tt0084264'],
#  ['nm6407619', 'Lauren Holt', '\\N', '\\N', 'art_department', 'tt3597448'],
#  ['nm6481103', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt3650844'],
#  ['nm6557993', 'Tom Davis', '\\N', '\\N', 'actor', 'tt3793204'],
#  ['nm6566424', 'Leslie Jones', '\\N', '\\N', 'actor', 'tt3800692,tt4056158'],
#  ['nm6580781', 'Sarah Sherman', '\\N', '\\N', 'actor', 'tt3815734'],
#  ['nm6588479',
#   'Kyle Mooney',
#   '\\N',
#   '\\N',
#   'special_effects,visual_effects',
#   'tt3823130'],
#  ['nm6638078', 'Jeff Richards', '\\N', '\\N', 'composer', 'tt3872944'],
#  ['nm6695372', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm6729562',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'editorial_department',
#   'tt3263490'],
#  ['nm6758873', 'Tom Davis', '\\N', '\\N', 'art_department', 'tt3970482'],
#  ['nm6880758', 'Sarah Sherman', '\\N', '\\N', nan, '\\N'],
#  ['nm6888296', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt8386350'],
#  ['nm6908017', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3790306'],
#  ['nm6934104', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm7041822', 'Sarah Sherman', '\\N', '\\N', nan, '\\N'],
#  ['nm7043228', 'Rich Hall', '\\N', '\\N', nan, '\\N'],
#  ['nm7096883',
#   'Will Ferrell',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0061240,tt0058797,tt0061296,tt0062994'],
#  ['nm7109497', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt4203440'],
#  ['nm7147777', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt4475006'],
#  ['nm7171988',
#   'Alex Moffat',
#   '\\N',
#   '\\N',
#   'assistant_director,miscellaneous',
#   'tt3381008,tt5104604,tt2652092,tt5628302'],
#  ['nm7205497', 'Tim Robinson', '\\N', '\\N', nan, 'tt4049528'],
#  ['nm7234377', 'Bill Murray', '\\N', '\\N', 'writer', 'tt4571940'],
#  ['nm7250185', 'Jeff Richards', '\\N', '\\N', nan, 'tt3696804'],
#  ['nm7286360',
#   'Christopher Guest',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt4334642,tt1024855'],
#  ['nm7296040', 'Rob Schneider', '\\N', '\\N', 'miscellaneous', 'tt4432798'],
#  ['nm7301044',
#   'Dan Vitale',
#   '\\N',
#   '\\N',
#   'director,writer,producer',
#   'tt4656450,tt5903450'],
#  ['nm7307139', 'Phil Hartman', '\\N', '\\N', 'actor', 'tt4662448'],
#  ['nm7314528', 'Mike Myers', '\\N', '\\N', 'actor', 'tt4670472'],
#  ['nm7324531', 'Heidi Gardner', '\\N', '\\N', nan, '\\N'],
#  ['nm7341228', 'Mike Myers', '\\N', '\\N', 'actor', 'tt4497152'],
#  ['nm7390947', 'Dean Edwards', '\\N', '\\N', 'actor', 'tt0122905'],
#  ['nm7397944',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'production_designer',
#   'tt4780202'],
#  ['nm7414652', 'Brad Hall', '\\N', '\\N', nan, 'tt1554356'],
#  ['nm7427133', 'Mark McKinney', '\\N', '\\N', nan, 'tt6225166'],
#  ['nm7427142', 'Mark McKinney', '\\N', '\\N', 'editor', 'tt5441646,tt4823678'],
#  ['nm7429938', 'Phil Hartman', '\\N', '\\N', 'actor', 'tt4828104'],
#  ['nm7440291',
#   'Fred Wolf',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt3910602,tt10222674,tt0072562'],
#  ['nm7451606', 'Phil Hartman', '\\N', '\\N', 'miscellaneous', 'tt4701488'],
#  ['nm7452649', 'Mike Myers', '\\N', '\\N', nan, 'tt4853866'],
#  ['nm7479270', 'Chris Farley', '\\N', '\\N', nan, '\\N'],
#  ['nm7491272', 'Victoria Jackson', '\\N', '\\N', 'actress', 'tt4906964'],
#  ['nm7567645',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'actress,writer,miscellaneous',
#   'tt9534540,tt15467926,tt8425308,tt14601874'],
#  ['nm7576527',
#   'Lauren Holt',
#   '1991',
#   '\\N',
#   'actress',
#   'tt8394996,tt8937092,tt0072562,tt7546290'],
#  ['nm7585524', 'Tim Robinson', '\\N', '\\N', nan, 'tt4661598'],
#  ['nm7641022', 'Molly Shannon', '\\N', '\\N', nan, 'tt3675186'],
#  ['nm7681772', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt5124078'],
#  ['nm7683464', 'Chris Farley', '\\N', '\\N', 'sound_department', 'tt0142235'],
#  ['nm7705657',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'editor,camera_department',
#   'tt5173520,tt6738058'],
#  ['nm7706610', "Mike O'Brien", '\\N', '\\N', 'visual_effects', 'tt3906560'],
#  ['nm7726543', 'Rich Hall', '\\N', '\\N', nan, '\\N'],
#  ['nm7791059',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt3739110'],
#  ['nm7815008', 'Phil Hartman', '\\N', '\\N', 'actor', 'tt5298646'],
#  ['nm7855877',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'director,writer,editor',
#   'tt5346900'],
#  ['nm7860904',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'editor,cinematographer',
#   'tt7119506,tt5352578'],
#  ['nm7906225',
#   'Mike Myers',
#   '\\N',
#   '\\N',
#   'camera_department,cinematographer',
#   'tt5442834,tt6137590'],
#  ['nm7941065', "Michael O'Donoghue", '\\N', '\\N', nan, '\\N'],
#  ['nm7966111', 'Mike Myers', '\\N', '\\N', nan, 'tt3109150'],
#  ['nm7992474', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt5542640'],
#  ['nm8052762', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt3859146'],
#  ['nm8054746',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt1216491,tt0795461,tt6285944'],
#  ['nm8067225', 'Tom Davis', '\\N', '\\N', 'actor', 'tt5631362,tt5631298'],
#  ['nm8093483', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt0093204'],
#  ['nm8096206', 'Mark McKinney', '\\N', '\\N', 'miscellaneous', 'tt2954994'],
#  ['nm8155395', 'Dennis Miller', '\\N', '\\N', 'actor', 'tt2114006'],
#  ['nm8157375', 'Dennis Miller', '\\N', '\\N', 'actor', 'tt2114006'],
#  ['nm8175223', "Mike O'Brien", '\\N', '\\N', 'sound_department', 'tt4977374'],
#  ['nm8191764', 'Will Ferrell', '\\N', '\\N', 'actor', 'tt5779664'],
#  ['nm8271258', 'Bill Murray', '\\N', '\\N', nan, 'tt5156614'],
#  ['nm8285155', "Michael O'Donoghue", '\\N', '\\N', 'actor', 'tt5880050'],
#  ['nm8300566', 'Dean Edwards', '\\N', '\\N', 'actor', 'tt5896628'],
#  ['nm8326174',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt5924202'],
#  ['nm8329835', 'Sarah Sherman', '\\N', '\\N', 'actress', 'tt5924202'],
#  ['nm8378315',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'camera_department,make_up_department',
#   'tt5941780'],
#  ['nm8439510',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt7689318,tt6074820,tt6063510'],
#  ['nm8467312', 'Sarah Sherman', '\\N', '\\N', nan, '\\N'],
#  ['nm8489283', 'Tom Davis', '\\N', '\\N', nan, 'tt5993092'],
#  ['nm8505163',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'director,cinematographer,editor',
#   'tt7252334,tt6142826,tt5870978,tt10607616'],
#  ['nm8517416', "Mike O'Brien", '\\N', '\\N', 'composer', 'tt6157660'],
#  ['nm8523579', 'Dean Edwards', '\\N', '\\N', 'composer', 'tt6166222'],
#  ['nm8537351', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt6185624'],
#  ['nm8595385', 'Dennis Miller', '\\N', '\\N', 'visual_effects', 'tt11993098'],
#  ['nm8605638', 'Dean Edwards', '\\N', '\\N', nan, '\\N'],
#  ['nm8608160',
#   'Andrew Dismukes',
#   '\\N',
#   '\\N',
#   'writer,actor',
#   'tt14508698,tt0072562,tt13858722,tt6279022'],
#  ['nm8645930', 'Chris Farley', '\\N', '\\N', 'actor', 'tt6329792'],
#  ['nm8734124', 'Siobhan Fallon', '\\N', '\\N', 'writer', 'tt6463510'],
#  ['nm8739883', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt6464314'],
#  ['nm8766863', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt6512646'],
#  ['nm8783853', "Mike O'Brien", '\\N', '\\N', 'soundtrack', 'tt2998406'],
#  ['nm8815884', 'Chris Elliott', '\\N', '\\N', 'miscellaneous', 'tt6264596'],
#  ['nm8854251', 'Tim Robinson', '\\N', '\\N', 'miscellaneous', 'tt6391108'],
#  ['nm8912973',
#   'Seth Meyers',
#   '\\N',
#   '\\N',
#   'miscellaneous',
#   'tt6528132,tt0496571'],
#  ['nm8938826', 'Pete Davidson', '\\N', '\\N', 'actor', 'tt6806604'],
#  ['nm8978375', 'Alex Moffat', '\\N', '\\N', 'actor', 'tt6851750'],
#  ['nm9030399', 'Colin Quinn', '\\N', '\\N', 'art_department', 'tt3948764'],
#  ['nm9189163',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'make_up_department',
#   'tt7233816'],
#  ['nm9201551',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   'editorial_department',
#   'tt6186672,tt0354333,tt1565436'],
#  ['nm9216626', 'Leslie Jones', '\\N', '\\N', 'actress', '\\N'],
#  ['nm9222500',
#   'Rich Hall',
#   '\\N',
#   '\\N',
#   'cinematographer,producer',
#   'tt8364112,tt7286604'],
#  ['nm9247139', 'Mike Myers', '\\N', '\\N', 'actor', 'tt1302137,tt0460843'],
#  ['nm9253219', 'Tom Davis', '\\N', '\\N', 'actor', 'tt7309462'],
#  ['nm9301955', 'Chris Parnell', '\\N', '\\N', nan, '\\N'],
#  ['nm9321275',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt7465694,tt8526284,tt7615118'],
#  ['nm9335986', 'Victoria Jackson', '\\N', '\\N', 'miscellaneous', 'tt0383760'],
#  ['nm9339453', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt7493170'],
#  ['nm9354190', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt7528072'],
#  ['nm9384729', 'Tracy Morgan', '\\N', '\\N', nan, '\\N'],
#  ['nm9390534', 'Tracy Morgan', '\\N', '\\N', 'editor', 'tt7587656'],
#  ['nm9395047', 'Colin Quinn', '\\N', '\\N', 'cinematographer', '\\N'],
#  ['nm9400036', 'Leslie Jones', '\\N', '\\N', 'actor', 'tt7604526'],
#  ['nm9401379', 'Joe Piscopo', '\\N', '\\N', nan, '\\N'],
#  ['nm9424876', 'Tom Davis', '\\N', '\\N', 'actor', 'tt7638698'],
#  ['nm9433183', 'Brad Hall', '\\N', '\\N', 'actor', 'tt0121946'],
#  ['nm9456219', 'Rob Schneider', '\\N', '\\N', 'actor', 'tt2642912'],
#  ['nm9502973', 'Mike Myers', '\\N', '\\N', 'camera_department', '\\N'],
#  ['nm9531701',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   nan,
#   'tt0112193,tt0396362,tt0335620,tt9090184'],
#  ['nm9546078', "Mike O'Brien", '\\N', '\\N', 'animation_department', '\\N'],
#  ['nm9573578', 'Tracy Morgan', '\\N', '\\N', nan, 'tt11833964,tt3644198'],
#  ['nm9652008', 'Dennis Miller', '\\N', '\\N', 'actor,assistant', 'tt3471592'],
#  ['nm9656009', 'Chris Elliott', '\\N', '\\N', 'writer,producer', '\\N'],
#  ['nm9681546', 'Brad Hall', '\\N', '\\N', 'director,producer', 'tt8106790'],
#  ['nm9737448', 'Julia Sweeney', '\\N', '\\N', 'miscellaneous', '\\N'],
#  ['nm9751499', 'Chris Rock', '\\N', '\\N', nan, '\\N'],
#  ['nm9772677',
#   'Rob Schneider',
#   '\\N',
#   '\\N',
#   'cinematographer,editor,producer',
#   'tt11239422,tt8280446'],
#  ['nm9790618',
#   'Punkie Johnson',
#   '\\N',
#   '\\N',
#   'actress,writer,producer',
#   'tt7242698,tt5821764,tt5117666,tt7778796'],
#  ['nm9825187', 'Sarah Sherman', '\\N', '\\N', 'art_director', 'tt8218988'],
#  ['nm9902053',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt1715425'],
#  ['nm9948379', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt8554874'],
#  ['nm9974827', 'Chris Parnell', '\\N', '\\N', nan, 'tt7396544'],
#  ['nm9978675', 'Jim Downey', '\\N', '\\N', 'director', '\\N'],
#  ['nm9982772', 'Chris Farley', '\\N', '\\N', nan, '\\N'],
#  ['nm9992272', 'Mary Gross', '\\N', '\\N', nan, 'tt0423652']]

# %%
def check_names(name):
    cross_name_list = (set([r[1] for r in cross_imdb_wiki_list]))
    result = False
    
    if name in cross_name_list:
        result = True
    return result

# %%
def check_creds(works):
    SNL_IDs = ['tt0715791', 'tt0715791', 'tt0971348', 'tt10809086', 'tt0072562', 'tt1372614', 'tt2173702']
    result = False
    for work in works.split(','):
        if work in SNL_IDs:
            result = True
    return result

# %%
check_creds('tt0460619,tt0157246,tt4116284,tt8324422')
# Out:
# False

# %%
SNL_name_check = [r for r in cross_imdb_wiki_list if check_names(r[1])]
(SNL_name_check)
# Out:
# [['nm0000004',
#   'John Belushi',
#   '1949',
#   '1982',
#   'actor,soundtrack,writer',
#   'tt0078723,tt0072562,tt0077975,tt0080455'],
#  ['nm0000101',
#   'Dan Aykroyd',
#   '1952',
#   '\\N',
#   'writer,actor,producer',
#   'tt0097428,tt0118747,tt0087332,tt0080455'],
#  ['nm0000195',
#   'Bill Murray',
#   '1950',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt1748122,tt0128445,tt0362270,tt0335266'],
#  ['nm0000196',
#   'Mike Myers',
#   '1963',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0295178,tt0145660,tt0118655,tt0811138'],
#  ['nm0000331',
#   'Chevy Chase',
#   '1943',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0085995,tt0097958,tt0080487,tt0092086'],
#  ['nm0000345',
#   'Billy Crystal',
#   '1948',
#   '\\N',
#   'actor,writer,producer',
#   'tt0101587,tt0098635,tt0113097,tt0122933'],
#  ['nm0000349',
#   'Joan Cusack',
#   '1962',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0119229,tt1659337,tt0119360,tt0096463'],
#  ['nm0000375',
#   'Robert Downey Jr.',
#   '1965',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt1300854,tt0371746,tt4154796,tt0988045'],
#  ['nm0000394',
#   'Chris Farley',
#   '1964',
#   '1997',
#   'actor,soundtrack,stunts',
#   'tt0118708,tt0115697,tt0114694,tt0106598'],
#  ['nm0000413',
#   'Janeane Garofalo',
#   '1964',
#   '\\N',
#   'actress,writer,producer',
#   'tt0382932,tt0132347,tt0117979,tt0243655'],
#  ['nm0000506',
#   'Julia Louis-Dreyfus',
#   '1961',
#   '\\N',
#   'actress,producer,soundtrack',
#   'tt0462128,tt1759761,tt2390361,tt0098904'],
#  ['nm0000552',
#   'Eddie Murphy',
#   '1961',
#   '\\N',
#   'actor,writer,producer',
#   'tt0117218,tt0443489,tt0094898,tt0126029'],
#  ['nm0000902',
#   'Jim Belushi',
#   '1954',
#   '\\N',
#   'actor,music_department,producer',
#   'tt0097637,tt0072562,tt0117468,tt0095963'],
#  ['nm0001022',
#   'Dana Carvey',
#   '1955',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0072562,tt0108525,tt0105793,tt0295427'],
#  ['nm0001191',
#   'Adam Sandler',
#   '1966',
#   '\\N',
#   'actor,producer,writer',
#   'tt0120484,tt0120888,tt0142342,tt0185431'],
#  ['nm0001302',
#   'Christopher Guest',
#   '1948',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0218839,tt0310281,tt0088258,tt0118111'],
#  ['nm0001309',
#   'Anthony Michael Hall',
#   '1968',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0468569,tt2361317,tt4758646,tt1100089'],
#  ['nm0001484',
#   'Jon Lovitz',
#   '1957',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0104694,tt0107659,tt0147612,tt0437863'],
#  ['nm0001542',
#   'Jay Mohr',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt0116695,tt0120241,tt0139239,tt0180052'],
#  ['nm0001642',
#   'Randy Quaid',
#   '1950',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0097958,tt0116629,tt0116778,tt0388795'],
#  ['nm0001674',
#   'Chris Rock',
#   '1965',
#   '\\N',
#   'producer,actor,writer',
#   'tt2784678,tt0325537,tt0398165,tt0351283'],
#  ['nm0001705',
#   'Rob Schneider',
#   '1963',
#   '\\N',
#   'actor,writer,producer',
#   'tt0255798,tt0302640,tt0367652,tt0205000'],
#  ['nm0001737',
#   'Martin Short',
#   '1950',
#   '\\N',
#   'actor,writer,producer',
#   'tt0093260,tt0452681,tt0092086,tt1791528'],
#  ['nm0001774',
#   'Ben Stiller',
#   '1965',
#   '\\N',
#   'producer,actor,director',
#   'tt0196229,tt0359950,tt0942385,tt1608290'],
#  ['nm0001834',
#   'Damon Wayans',
#   '1960',
#   '\\N',
#   'actor,writer,producer',
#   'tt0110443,tt0104897,tt0273855,tt0102266'],
#  ['nm0002056',
#   'Christine Ebersole',
#   '1953',
#   '\\N',
#   'actress,soundtrack',
#   'tt0115697,tt0993846,tt0086879,tt0110989'],
#  ['nm0002071',
#   'Will Ferrell',
#   '1967',
#   '\\N',
#   'producer,actor,soundtrack',
#   'tt0357413,tt0445934,tt1229340,tt0415306'],
#  ['nm0004852',
#   'Jane Curtin',
#   '1947',
#   '\\N',
#   'actress,soundtrack',
#   'tt0106598,tt0115082,tt0086742,tt1155056'],
#  ['nm0004887',
#   'Nora Dunn',
#   '1952',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0405336,tt0910936,tt0157503,tt0120188'],
#  ['nm0005218',
#   'Tim Meadows',
#   '1961',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0841046,tt0377092,tt3960412,tt0213790'],
#  ['nm0005265',
#   'Kevin Nealon',
#   '1953',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0072562,tt0116483,tt0439100,tt0120888'],
#  ['nm0005450',
#   'David Spade',
#   '1964',
#   '\\N',
#   'actor,writer,producer',
#   'tt0245686,tt0120917,tt0437863,tt0114694'],
#  ['nm0035488',
#   'Fred Armisen',
#   '1966',
#   '\\N',
#   'music_department,actor,writer',
#   'tt0357413,tt1282140,tt0072562,tt1780441'],
#  ['nm0043839',
#   'Peter Aykroyd',
#   '1955',
#   '2021',
#   'writer,producer,actor',
#   'tt0106598,tt0095687,tt0090056,tt0102558'],
#  ['nm0052218',
#   'Morwenna Banks',
#   '1961',
#   '\\N',
#   'actress,writer,producer',
#   'tt0760141,tt0466664,tt2245003,tt5839960'],
#  ['nm0108028',
#   'Jim Breuer',
#   '1967',
#   '\\N',
#   'actor,producer,writer',
#   'tt1222817,tt0120693,tt0120913,tt0144168'],
#  ['nm0112944',
#   'A. Whitney Brown',
#   '1952',
#   '\\N',
#   'writer,actor',
#   'tt0096708,tt0072562,tt0166039,tt1094991'],
#  ['nm0128639',
#   'Beth Cahill',
#   '\\N',
#   '\\N',
#   'actress,costume_designer,miscellaneous',
#   'tt0155764,tt0262411,tt0164930,tt0072562'],
#  ['nm0165971',
#   'Ellen Cleghorne',
#   '1965',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0120591,tt0200550,tt2126357,tt0185431'],
#  ['nm0168642',
#   'George Coe',
#   '1929',
#   '2015',
#   'actor,producer,director',
#   'tt1399103,tt0089901,tt0073747,tt0092666'],
#  ['nm0203457',
#   'Pete Davidson',
#   '1993',
#   '\\N',
#   'actor,producer,writer',
#   'tt9686708,tt5304992,tt0800325,tt6334354'],
#  ['nm0205569',
#   'Tom Davis',
#   '1952',
#   '2012',
#   'writer,actor,producer',
#   'tt0086465,tt0251075,tt0106598,tt0072562'],
#  ['nm0205570',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'sound_department,music_department',
#   'tt0120241,tt0100613,tt0803033,tt0087998'],
#  ['nm0205571', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0124718,tt0463970'],
#  ['nm0205572', 'Tom Davis', '\\N', '\\N', 'art_department', 'tt0118632'],
#  ['nm0226986',
#   'Denny Dillon',
#   '1951',
#   '\\N',
#   'actress,soundtrack',
#   'tt0475276,tt0098780,tt0268380,tt0076666'],
#  ['nm0236519',
#   'Brian Doyle-Murray',
#   '1945',
#   '\\N',
#   'actor,writer,producer',
#   'tt0105793,tt0102138,tt0080487,tt0097958'],
#  ['nm0237222',
#   'Rachel Dratch',
#   '1966',
#   '\\N',
#   'actress,soundtrack,miscellaneous',
#   'tt1564367,tt0389860,tt0814331,tt8169446'],
#  ['nm0241208',
#   'Robin Duke',
#   '1954',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0075578,tt0117108,tt0107048,tt0072562'],
#  ['nm0249931',
#   'Dean Edwards',
#   '1970',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0910898,tt2784678,tt0421143,tt0413300'],
#  ['nm0254402',
#   'Chris Elliott',
#   '1960',
#   '\\N',
#   'actor,writer,producer',
#   'tt0107048,tt0109361,tt0129387,tt0096754'],
#  ['nm0254403',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'production_designer,set_decorator,art_department',
#   'tt0103873,tt0834001,tt0110311,tt0107822'],
#  ['nm0254404', 'Chris Elliott', '\\N', '\\N', 'director', 'tt0222820'],
#  ['nm0266422',
#   'Jimmy Fallon',
#   '1974',
#   '\\N',
#   'writer,soundtrack,producer',
#   'tt3444938,tt1231460,tt0332047,tt0316732'],
#  ['nm0275486',
#   'Tina Fey',
#   '1970',
#   '\\N',
#   'writer,actress,producer',
#   'tt1850457,tt0377092,tt1279935,tt0496424'],
#  ['nm0287182',
#   'Will Forte',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt3230454,tt1490017,tt1470023,tt1821549'],
#  ['nm0291253',
#   'Al Franken',
#   '1951',
#   '\\N',
#   'writer,producer,actor',
#   'tt0114571,tt0368008,tt0086465,tt0072562'],
#  ['nm0309430',
#   'Ana Gasteyer',
#   '1967',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0207201,tt1232200,tt4366830,tt0377092'],
#  ['nm0331906',
#   'Gilbert Gottfried',
#   '1955',
#   '2022',
#   'actor,writer,soundtrack',
#   'tt0103639,tt0092644,tt0098987,tt0100419'],
#  ['nm0343444',
#   'Mary Gross',
#   '1953',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0120791,tt0243736,tt0094846,tt0072562'],
#  ['nm0352778',
#   'Bill Hader',
#   '1978',
#   '\\N',
#   'actor,writer,producer',
#   'tt1571249,tt3152624,tt7349950,tt2096673'],
#  ['nm0355357',
#   'Brad Hall',
#   '1958',
#   '\\N',
#   'writer,producer,actor',
#   'tt0120623,tt2080359,tt6388738,tt0101055'],
#  ['nm0355358',
#   'Brad Hall',
#   '1968',
#   '\\N',
#   'miscellaneous,producer,assistant_director',
#   'tt0109830,tt0120399,tt0120829'],
#  ['nm0355360',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'producer,director,miscellaneous',
#   'tt2468756,tt0800142,tt8793210,tt2953706'],
#  ['nm0356025',
#   'Rich Hall',
#   '1954',
#   '\\N',
#   'writer,actor,producer',
#   'tt0072562,tt0325939,tt0085065,tt1430607'],
#  ['nm0358669',
#   'Darrell Hammond',
#   '1955',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0799949,tt0118747,tt0306047,tt0072562'],
#  ['nm0367005',
#   'Phil Hartman',
#   '1948',
#   '1998',
#   'actor,writer,soundtrack',
#   'tt0122718,tt0108174,tt0116705,tt0112095'],
#  ['nm0393660',
#   'Jan Hooks',
#   '1957',
#   '2014',
#   'actress,soundtrack',
#   'tt0103776,tt0115082,tt0106598,tt0089791'],
#  ['nm0399994',
#   'Yvonne Hudson',
#   '\\N',
#   '\\N',
#   'actress,miscellaneous',
#   'tt0277167,tt0072562'],
#  ['nm0404525',
#   'Melanie Hutsell',
#   '\\N',
#   '\\N',
#   'actress,soundtrack',
#   'tt4789300,tt1478338,tt0072562,tt2191701'],
#  ['nm0414130',
#   'Victoria Jackson',
#   '1959',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt1394227,tt0098546,tt0099819,tt0094846'],
#  ['nm0428655',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'editor,editorial_department',
#   'tt0272338,tt1791528,tt1560747,tt0120863'],
#  ['nm0428656',
#   'Leslie Jones',
#   '1967',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0072562,tt6802400,tt1289401,tt2461150'],
#  ['nm0428658', 'Leslie Jones', '\\N', '\\N', 'music_department', 'tt0116442'],
#  ['nm0428659',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0113492,tt0180073,tt0773756,tt0120738'],
#  ['nm0428660', 'Leslie Jones', '\\N', '\\N', 'script_department', 'tt0094643'],
#  ['nm0441592',
#   'Chris Kattan',
#   '1970',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0120770,tt0279493,tt2479478,tt0185371'],
#  ['nm0443730',
#   'Tim Kazurinsky',
#   '1950',
#   '\\N',
#   'actor,writer,miscellaneous',
#   'tt0090583,tt0089822,tt0082801,tt0072562'],
#  ['nm0452716',
#   'Laura Kightlinger',
#   '1964',
#   '\\N',
#   'producer,actress,writer',
#   'tt4116284,tt8324422,tt0460619,tt0157246'],
#  ['nm0453115',
#   'Taran Killam',
#   '1982',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt2024544,tt0072562,tt5689068,tt4000956'],
#  ['nm0462712',
#   'David Koechner',
#   '1962',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0425061,tt0357413,tt0427944,tt1229340'],
#  ['nm0471856',
#   'Gary Kroeger',
#   '1957',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0200525,tt0072562,tt0046593,tt0086765'],
#  ['nm0491005',
#   'Matthew Laurance',
#   '1950',
#   '\\N',
#   'actor,soundtrack',
#   'tt0112111,tt0085475,tt0098772,tt0090060'],
#  ['nm0560257',
#   'Gail Matthius',
#   '1953',
#   '\\N',
#   'actress,soundtrack',
#   'tt0072562,tt0162796,tt0083530,tt0103373'],
#  ['nm0571106',
#   'Michael McKean',
#   '1947',
#   '\\N',
#   'actor,soundtrack,director',
#   'tt0088258,tt0088930,tt0310281,tt3032476'],
#  ['nm0571897',
#   'Mark McKinney',
#   '1959',
#   '\\N',
#   'actor,writer,producer',
#   'tt0387779,tt0096626,tt0120770,tt1159996'],
#  ['nm0571898',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0277370,tt1212450,tt0107927,tt1731701'],
#  ['nm0571952',
#   'Kate McKinnon',
#   '1984',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt4799050,tt0072562,tt6394270,tt1289401'],
#  ['nm0582418',
#   'Laurie Metcalf',
#   '1955',
#   '\\N',
#   'actress,soundtrack,miscellaneous',
#   'tt0094540,tt0120082,tt0114709,tt4925292'],
#  ['nm0588222',
#   'Dennis Miller',
#   '1953',
#   '\\N',
#   'writer,producer,actor',
#   'tt0113957,tt0245686,tt0119731,tt0117826'],
#  ['nm0588223',
#   'Dennis Miller',
#   '1937',
#   '\\N',
#   'actor',
#   'tt0385463,tt0081561,tt0108709,tt0135848'],
#  ['nm0588224',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department,director',
#   'tt0226416,tt0072792,tt0279429,tt0081563'],
#  ['nm0591576',
#   'Jerry Minor',
#   '1969',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt2463288,tt0817538,tt0323633,tt0357413'],
#  ['nm0605078',
#   'Tracy Morgan',
#   '1943',
#   '\\N',
#   'actress,writer',
#   'tt0074377,tt0074621,tt0069098,tt0068892'],
#  ['nm0605079',
#   'Tracy Morgan',
#   '1968',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0496424,tt0787474,tt1385867,tt0426592'],
#  ['nm0606541',
#   'Garrett Morris',
#   '1937',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0072562,tt0478970,tt0106598,tt0278488'],
#  ['nm0614853', 'Bill Murray', '\\N', '\\N', 'miscellaneous', 'tt0097132'],
#  ['nm0628170',
#   'Laraine Newman',
#   '1952',
#   '\\N',
#   'actress,soundtrack,miscellaneous',
#   'tt0102719,tt0106598,tt0116705,tt0120669'],
#  ['nm0637038',
#   'Don Novello',
#   '1943',
#   '\\N',
#   'actor,writer,producer',
#   'tt0072562,tt0112642,tt0099674,tt0230011'],
#  ['nm0639733',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'sound_department,composer',
#   'tt0159876,tt0340434,tt0127341,tt0153362'],
#  ['nm0639734',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'camera_department,actor,art_department',
#   'tt0094834,tt0117652,tt0110939,tt0109021'],
#  ['nm0639735',
#   "Mike O'Brien",
#   '1964',
#   '2015',
#   'actor',
#   'tt2347497,tt1159996,tt1095174,tt0433400'],
#  ['nm0640874',
#   "Michael O'Donoghue",
#   '1940',
#   '1994',
#   'writer,actor,miscellaneous',
#   'tt0096061,tt0079583,tt0079522,tt0072562'],
#  ['nm0652783',
#   'Cheri Oteri',
#   '1962',
#   '\\N',
#   'actress,writer,producer',
#   'tt0141369,tt0175142,tt0119528,tt0405336'],
#  ['nm0663177',
#   'Chris Parnell',
#   '1967',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0357413,tt2861424,tt0841046,tt1232829'],
#  ['nm0685472',
#   'Joe Piscopo',
#   '1951',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0092226,tt0072562,tt0094961,tt0087507'],
#  ['nm0688132',
#   'Amy Poehler',
#   '1971',
#   '\\N',
#   'actress,producer,writer',
#   'tt2096673,tt0871426,tt1266020,tt0072562'],
#  ['nm0695104',
#   'Emily Prager',
#   '1948',
#   '\\N',
#   'actress,writer,camera_department',
#   'tt0048860,tt0094674,tt0079583,tt0059992'],
#  ['nm0703800',
#   'Colin Quinn',
#   '1959',
#   '\\N',
#   'writer,actor,producer',
#   'tt3152624,tt3314416,tt1375670,tt0120770'],
#  ['nm0705717',
#   'Gilda Radner',
#   '1946',
#   '1989',
#   'actress,soundtrack,writer',
#   'tt0070290,tt0091178,tt0084049,tt0072562'],
#  ['nm0711014',
#   'Tony Rosato',
#   '1954',
#   '2017',
#   'actor,writer',
#   'tt0075578,tt0117593,tt0088582,tt0207701'],
#  ['nm0724143',
#   'Jeff Richards',
#   '1924',
#   '1989',
#   'actor,soundtrack',
#   'tt0049578,tt0052932,tt0047472,tt0050327'],
#  ['nm0724144',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'animation_department,art_department',
#   'tt0104254,tt0120800,tt0111333,tt0094449'],
#  ['nm0724145',
#   'Jeff Richards',
#   '1974',
#   '\\N',
#   'actor,writer,producer',
#   'tt0759475,tt0468999,tt4687632,tt0072562'],
#  ['nm0724146',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0162349,tt0076781,tt0087348,tt0090631'],
#  ['nm0728315',
#   'Ann Risley',
#   '1949',
#   '\\N',
#   'actress',
#   'tt0072562,tt0081554,tt0081518,tt0082525'],
#  ['nm0733146',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0088591,tt0834001,tt4698684,tt0443334'],
#  ['nm0733427',
#   'Harry Shearer',
#   '1943',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0120382,tt0310281,tt0096697,tt0088258'],
#  ['nm0734153',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0284126,tt9372772,tt0142646,tt0286159'],
#  ['nm0734236',
#   'Charles Rocket',
#   '1949',
#   '2005',
#   'actor,soundtrack',
#   'tt0120913,tt0099348,tt0108122,tt0109686'],
#  ['nm0748973',
#   'Maya Rudolph',
#   '1972',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt1727388,tt1176740,tt1478338,tt1791528'],
#  ['nm0764445',
#   'Horatio Sanz',
#   '1969',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0285462,tt1920849,tt0215129,tt1045778'],
#  ['nm0771680',
#   'Tom Schiller',
#   '1949',
#   '\\N',
#   'writer,actor,director',
#   'tt0087817,tt0072562,tt3677742,tt0304046'],
#  ['nm0787238',
#   'Paul Shaffer',
#   '1949',
#   '\\N',
#   'music_department,soundtrack,actor',
#   'tt0088258,tt0119282,tt0118747,tt4537842'],
#  ['nm0788340',
#   'Molly Shannon',
#   '1964',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0362120,tt0167427,tt0151738,tt4158876'],
#  ['nm0798971',
#   'Sarah Silverman',
#   '1970',
#   '\\N',
#   'actress,producer,writer',
#   'tt0332379,tt0821375,tt1772341,tt5848272'],
#  ['nm0806912',
#   'Robert Smigel',
#   '1960',
#   '\\N',
#   'writer,producer,actor',
#   'tt0185431,tt0072562,tt0106052,tt0272338'],
#  ['nm0827298',
#   'Pamela Stephenson',
#   '1949',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0080253,tt0086393,tt0082517,tt0199218'],
#  ['nm0837177',
#   'Jason Sudeikis',
#   '1975',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt1723121,tt10986410,tt4680182,tt1499658'],
#  ['nm0842140',
#   'Julia Sweeney',
#   '1959',
#   '\\N',
#   'actress,producer,writer',
#   'tt2467372,tt0498994,tt8962130,tt10417836'],
#  ['nm0842202',
#   'Terry Sweeney',
#   '1950',
#   '\\N',
#   'writer,actor,miscellaneous',
#   'tt0240596,tt0098300,tt0342139,tt0093443'],
#  ['nm0860380',
#   'Kenan Thompson',
#   '1978',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0417148,tt0072562,tt0115231,tt0119215'],
#  ['nm0888503',
#   'Danitra Vance',
#   '1954',
#   '1994',
#   'actress,soundtrack',
#   'tt0098621,tt0102316,tt0102174,tt0086759'],
#  ['nm0899865',
#   'Dan Vitale',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0088804,tt0086768,tt1744760,tt0072562'],
#  ['nm0915778',
#   'Patrick Weathers',
#   '1954',
#   '\\N',
#   'actor,music_department',
#   'tt1741243,tt1790886,tt1996346,tt0094291'],
#  ['nm0933146',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'visual_effects',
#   'tt0102034,tt0120611,tt0107415,tt0274164'],
#  ['nm0937747',
#   'Fred Wolf',
#   '1932',
#   '\\N',
#   'producer,writer,miscellaneous',
#   'tt0061421,tt0092345,tt0131613,tt0067595'],
#  ['nm0937748',
#   'Fred Wolf',
#   '1964',
#   '\\N',
#   'writer,actor,director',
#   'tt0115697,tt0120654,tt2191701,tt0185431'],
#  ['nm0937750', 'Fred Wolf', '1910', '2000', 'actor', 'tt2157952,tt0154574'],
#  ['nm0958993',
#   'Alan Zweibel',
#   '1950',
#   '\\N',
#   'writer,producer,actor',
#   'tt0090459,tt0072562,tt0092925,tt0110687'],
#  ['nm0971596',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'composer,music_department,editor',
#   'tt1167638,tt0120662,tt0118661,tt0203009'],
#  ['nm1008747', 'Rich Hall', '\\N', '\\N', 'writer', 'tt0861361'],
#  ['nm10124289', 'Jeff Richards', '\\N', '\\N', 'miscellaneous', 'tt0076598'],
#  ['nm10179693', 'Tom Davis', '\\N', '\\N', nan, 'tt8948614'],
#  ['nm10184827', "Mike O'Brien", '\\N', '\\N', nan, 'tt3562462'],
#  ['nm10230310', 'Colin Quinn', '\\N', '\\N', 'cinematographer', 'tt8819940'],
#  ['nm1024878',
#   'Seth Meyers',
#   '1973',
#   '\\N',
#   'writer,actor,producer',
#   'tt1598822,tt4677934,tt0072562,tt3513388'],
#  ['nm10254000', 'Pete Davidson', '\\N', '\\N', 'producer', '\\N'],
#  ['nm10271496', 'Chris Elliott', '\\N', '\\N', nan, '\\N'],
#  ['nm1027256', 'Chris Parnell', '\\N', '\\N', 'actor', 'tt0265736'],
#  ['nm1034017',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0450852,tt0258476,tt1165357,tt1111291'],
#  ['nm10343807', 'Bill Murray', '\\N', '\\N', 'actor', 'tt6384192,tt13998382'],
#  ['nm10365967', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm10417023', 'Tom Davis', '\\N', '\\N', 'actor', 'tt9639868'],
#  ['nm10437112', 'Dean Edwards', '\\N', '\\N', nan, 'tt3644198'],
#  ['nm10440389', 'Chris Rock', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10452456', 'Mark McKinney', '\\N', '\\N', nan, '\\N'],
#  ['nm10455749', "Mike O'Brien", '\\N', '\\N', 'editor', 'tt9734382,tt9883024'],
#  ['nm10455801',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'assistant_director',
#   'tt0123965'],
#  ['nm1047319', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0295476'],
#  ['nm1047581', 'Brad Hall', '\\N', '\\N', 'miscellaneous', 'tt0294941'],
#  ['nm10513107', 'Lauren Holt', '\\N', '\\N', 'camera_department', '\\N'],
#  ['nm10521259', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm10614185', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm10639792', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm10661678', 'Eddie Murphy', '\\N', '\\N', nan, '\\N'],
#  ['nm10666508', 'Tim Robinson', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10697087', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm10765303', 'Tom Davis', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10793005', "Mike O'Brien", '\\N', '\\N', 'actor', '\\N'],
#  ['nm1083889',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'miscellaneous,producer,director',
#   'tt1716744,tt1448500,tt7498020,tt0217061'],
#  ['nm10871329', 'Victoria Jackson', '\\N', '\\N', 'actress', '\\N'],
#  ['nm10879663', 'Terry Sweeney', '\\N', '\\N', 'actor', '\\N'],
#  ['nm10937994',
#   'Tim Meadows',
#   '\\N',
#   '\\N',
#   nan,
#   'tt10740136,tt13743066,tt10863916,tt14016930'],
#  ['nm11060621',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'composer,sound_department',
#   'tt12649418'],
#  ['nm11079865', 'Tom Davis', '\\N', '\\N', 'miscellaneous', '\\N'],
#  ['nm11155585', 'Dennis Miller', '\\N', '\\N', 'actor', 'tt10974848'],
#  ['nm11162204', "Mike O'Brien", '\\N', '\\N', 'writer,producer', 'tt11348726'],
#  ['nm11185833', 'Tom Davis', '\\N', '\\N', 'composer', 'tt11137268'],
#  ['nm11217821',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'camera_department,production_manager,script_department',
#   'tt11475900'],
#  ['nm11222962', 'Will Ferrell', '\\N', '\\N', 'producer', 'tt11462908'],
#  ['nm11270045', "Mike O'Brien", '\\N', '\\N', nan, 'tt11599804'],
#  ['nm11279790',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt11394180'],
#  ['nm11291807', 'Chris Farley', '\\N', '\\N', 'stunts', 'tt1972591'],
#  ['nm11297717', 'Tom Davis', '\\N', '\\N', 'actor', '\\N'],
#  ['nm11322159', 'Fred Wolf', '\\N', '\\N', nan, '\\N'],
#  ['nm11331059', 'Chris Elliott', '\\N', '\\N', 'special_effects', '\\N'],
#  ['nm11436906',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'visual_effects',
#   'tt12003714'],
#  ['nm1143861',
#   'Michaela Watkins',
#   '1971',
#   '\\N',
#   'actress,writer,producer',
#   'tt1932718,tt1655460,tt2294677,tt1212436'],
#  ['nm11486610', 'Tom Davis', '\\N', '\\N', nan, 'tt1020913'],
#  ['nm1154288', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt0116783'],
#  ['nm11555653', 'Jerry Minor', '\\N', '\\N', nan, 'tt0401003'],
#  ['nm11573043', 'Dan Vitale', '\\N', '\\N', nan, '\\N'],
#  ['nm11610626', 'Leslie Jones', '\\N', '\\N', 'actress', '\\N'],
#  ['nm1162741',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0288154,tt0189500'],
#  ['nm11707153', 'Jeff Richards', '\\N', '\\N', nan, 'tt11011652'],
#  ['nm11718692', "Mike O'Brien", '\\N', '\\N', 'set_decorator', 'tt12661304'],
#  ['nm11728273', 'Heidi Gardner', '\\N', '\\N', 'actress', '\\N'],
#  ['nm11765333', 'Casey Wilson', '\\N', '\\N', nan, '\\N'],
#  ['nm11768616', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt3783812'],
#  ['nm11775788', 'Martin Short', '\\N', '\\N', nan, 'tt12800308'],
#  ['nm11885823', 'Tom Davis', '\\N', '\\N', 'actor', 'tt5295032'],
#  ['nm11936425', 'Victoria Jackson', '\\N', '\\N', 'actress', '\\N'],
#  ['nm11950689', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm11950691', 'Victoria Jackson', '\\N', '\\N', nan, '\\N'],
#  ['nm11971632', "Mike O'Brien", '\\N', '\\N', 'actor', '\\N'],
#  ['nm11972013', 'Tim Robinson', '\\N', '\\N', 'set_decorator', 'tt10505762'],
#  ['nm11992562', 'Sarah Sherman', '\\N', '\\N', 'director', '\\N'],
#  ['nm1201491', 'Dennis Miller', '\\N', '\\N', 'casting_director', 'tt0325502'],
#  ['nm12033473', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt14643040'],
#  ['nm1219950',
#   'Eddie Murphy',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0830515,tt10539608,tt2802144,tt2527336'],
#  ['nm12244326', 'Tom Davis', '\\N', '\\N', 'cinematographer', '\\N'],
#  ['nm12246661',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt13026762'],
#  ['nm12251094', 'Brad Hall', '\\N', '\\N', nan, 'tt1442550'],
#  ['nm12286233', 'Leslie Jones', '\\N', '\\N', 'script_department', '\\N'],
#  ['nm12293622', 'Dean Edwards', '\\N', '\\N', 'actor', '\\N'],
#  ['nm12383124', 'Tom Davis', '\\N', '\\N', nan, 'tt0262152,tt13471320'],
#  ['nm12400603', 'Dan Vitale', '\\N', '\\N', 'actor', 'tt14236360'],
#  ['nm12406972', 'Victoria Jackson', '\\N', '\\N', nan, '\\N'],
#  ['nm12488967', 'Tim Meadows', '\\N', '\\N', 'actor', 'tt11394158'],
#  ['nm12577961', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt14643040'],
#  ['nm12624642', 'Tom Davis', '\\N', '\\N', nan, 'tt13682176'],
#  ['nm12695477', 'Rob Schneider', '\\N', '\\N', 'producer', 'tt4829936'],
#  ['nm12705773', 'Victoria Jackson', '\\N', '\\N', 'actress', 'tt6932494'],
#  ['nm12744425',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'miscellaneous',
#   'tt14855722'],
#  ['nm12748185', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm12750797', 'Mike Myers', '\\N', '\\N', nan, '\\N'],
#  ['nm12750908', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0124718'],
#  ['nm12785038', 'Victoria Jackson', '\\N', '\\N', nan, '\\N'],
#  ['nm12785675', 'Jimmy Fallon', '\\N', '\\N', 'art_department', 'tt6133466'],
#  ['nm12815517', 'Victoria Jackson', '\\N', '\\N', 'producer', 'tt14894996'],
#  ['nm1282073', 'Leslie Jones', '\\N', '\\N', nan, 'tt0341708'],
#  ['nm12840270',
#   'Chris Farley',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department,editor',
#   'tt14779558,tt16589596'],
#  ['nm12851138', 'Colin Quinn', '\\N', '\\N', nan, '\\N'],
#  ['nm12890222', 'Christopher Guest', '\\N', '\\N', nan, '\\N'],
#  ['nm12931864', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm1293885',
#   'Bobby Moynihan',
#   '1977',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt13622982,tt10662034,tt0072562'],
#  ['nm12980144', 'Leslie Jones', '\\N', '\\N', 'art_department', 'tt8579674'],
#  ['nm12981476',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt15488832'],
#  ['nm13013859', "Michael O'Donoghue", '\\N', '\\N', 'sound_department', '\\N'],
#  ['nm13032378',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'music_department',
#   'tt15669416'],
#  ['nm13042925', 'Mike Myers', '\\N', '\\N', 'camera_department', 'tt15714650'],
#  ['nm13153060', 'Eddie Murphy', '\\N', '\\N', 'actor,miscellaneous', '\\N'],
#  ['nm13186344',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'assistant_director,script_department',
#   '\\N'],
#  ['nm1325419',
#   'Kristen Wiig',
#   '1973',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt1478338,tt1608290,tt0359950,tt1571249'],
#  ['nm13266366', 'Jeff Richards', '\\N', '\\N', 'actor', '\\N'],
#  ['nm13281524', "Mike O'Brien", '\\N', '\\N', 'producer', '\\N'],
#  ['nm13281861', 'Tom Davis', '\\N', '\\N', nan, '\\N'],
#  ['nm13308038', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm13337965', 'Leslie Jones', '\\N', '\\N', 'executive', '\\N'],
#  ['nm13349009', 'Brad Hall', '\\N', '\\N', nan, 'tt13639450,tt12747694'],
#  ['nm13349549', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm13353192', 'Chris Parnell', '\\N', '\\N', nan, '\\N'],
#  ['nm1338203',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'costume_department,make_up_department',
#   'tt0444631,tt0357577'],
#  ['nm13382765', 'Tim Meadows', '\\N', '\\N', nan, '\\N'],
#  ['nm13405263', 'Rich Hall', '\\N', '\\N', nan, '\\N'],
#  ['nm13467885',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'costume_department',
#   'tt15659704'],
#  ['nm13479010', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt18546600'],
#  ['nm13488570',
#   'Kyle Mooney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt18764878'],
#  ['nm1349208', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt6168110'],
#  ['nm13569869', 'Mike Myers', '\\N', '\\N', nan, '\\N'],
#  ['nm1386521', 'Bill Murray', '\\N', '\\N', 'actor', 'tt0351810'],
#  ['nm1396935',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'producer,director',
#   'tt0968732,tt0775402,tt3558296,tt1715425'],
#  ['nm1401295', 'Martin Short', '\\N', '\\N', nan, '\\N'],
#  ['nm1427969', 'Tracy Morgan', '\\N', '\\N', nan, 'tt1173421'],
#  ['nm1443527',
#   'Rob Riggle',
#   '1970',
#   '\\N',
#   'actor,writer,producer',
#   'tt2096672,tt1119646,tt0115147,tt1232829'],
#  ['nm1459509',
#   'Finesse Mitchell',
#   '1972',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0785077,tt0072562,tt0951216,tt0790804'],
#  ['nm1480256',
#   'Rich Hall',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1517640,tt1330618,tt0108709'],
#  ['nm1510062',
#   'Mikey Day',
#   '1980',
#   '\\N',
#   'actor,writer,producer',
#   'tt0072562,tt2076347,tt1217217,tt4000956'],
#  ['nm1558206',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1387418,tt1730767,tt0398291'],
#  ['nm1578488',
#   'Adam Sandler',
#   '\\N',
#   '\\N',
#   'director,producer,editorial_department',
#   'tt13689618,tt10428498,tt0068120,tt12116598'],
#  ['nm1654181',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'miscellaneous,sound_department',
#   'tt0399977,tt0412109,tt6261554,tt0338616'],
#  ['nm1676221',
#   'Andy Samberg',
#   '1978',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0072562,tt3960412,tt2467372,tt9484998'],
#  ['nm1687172', 'Paul Brittain', '\\N', '\\N', 'actor', 'tt0413660'],
#  ['nm1737885',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'visual_effects',
#   'tt0382992,tt0317705,tt0198781'],
#  ['nm1746994', 'Christopher Guest', '\\N', '\\N', nan, 'tt0040053'],
#  ['nm1752760',
#   'Mike Myers',
#   '1969',
#   '\\N',
#   nan,
#   'tt0476931,tt1020929,tt2140691,tt1045847'],
#  ['nm1771830', 'Chris Rock', '\\N', '\\N', 'actor', 'tt0434026'],
#  ['nm1807732', 'Tom Davis', '\\N', '\\N', 'miscellaneous', 'tt0439911'],
#  ['nm1829094', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt0083731'],
#  ['nm1831668', 'Bill Murray', '\\N', '\\N', 'cinematographer', 'tt0448004'],
#  ['nm1840659',
#   'Nasim Pedrad',
#   '1981',
#   '\\N',
#   'actress,producer,writer',
#   'tt6139732,tt1690953,tt10338160,tt2490326'],
#  ['nm1843779',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'writer,director,producer',
#   'tt1877853,tt0904115'],
#  ['nm1877197',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'make_up_department',
#   'tt6769236,tt5941780,tt10483744,tt0455841'],
#  ['nm1906042',
#   'Colin Jost',
#   '1982',
#   '\\N',
#   'writer,actor,miscellaneous',
#   'tt0072562,tt1292566,tt1361336,tt6802400'],
#  ['nm1907457',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'actor,writer',
#   'tt0457251,tt0961721'],
#  ['nm1934954', "Mike O'Brien", '\\N', '\\N', 'visual_effects', 'tt0120841'],
#  ['nm1942080',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'producer,director,writer',
#   'tt4276112,tt2062966,tt1215983,tt0789775'],
#  ['nm1962331', 'Casey Wilson', '1987', '\\N', 'actor', 'tt0457394'],
#  ['nm1971084', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt0105986'],
#  ['nm1978226',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor,producer',
#   'tt0483776,tt5786442,tt1309181,tt0484257'],
#  ['nm1981812', 'Bill Murray', '\\N', '\\N', 'actor', 'tt0122145'],
#  ['nm1988111',
#   'Casey Wilson',
#   '1980',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0901476,tt1509788,tt1103153,tt2267998'],
#  ['nm2018971', 'Bill Murray', '\\N', '\\N', nan, 'tt0281438'],
#  ['nm2019506', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm2062929',
#   'Christopher Guest',
#   '1975',
#   '\\N',
#   'producer,visual_effects,miscellaneous',
#   'tt12716280,tt10538562,tt1822842,tt8022434'],
#  ['nm2076868',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'actress',
#   'tt0106179,tt0120901,tt0242733,tt0204993'],
#  ['nm2095085',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt1334555'],
#  ['nm2114510', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt0497043'],
#  ['nm2141165',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   'editorial_department,visual_effects,art_department',
#   'tt0482481,tt2551436,tt0354333,tt1529670'],
#  ['nm2159521',
#   'Phil Hartman',
#   '\\N',
#   '\\N',
#   'visual_effects,special_effects',
#   'tt2417108,tt0844479,tt0409182'],
#  ['nm2163846', 'Mike Myers', '\\N', '\\N', 'visual_effects', 'tt0079945'],
#  ['nm2193928',
#   'Tom Davis',
#   '1949',
#   '\\N',
#   nan,
#   'tt0787424,tt0496360,tt9822404,tt0123338'],
#  ['nm2212031',
#   'Abby Elliott',
#   '1987',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0072562,tt1291150,tt1663143,tt1411238'],
#  ['nm2213674',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'editorial_department,sound_department',
#   'tt0458339,tt3748528,tt0816711,tt1446714'],
#  ['nm2221621',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1474200,tt0770745,tt0882741'],
#  ['nm2251356', 'Chris Elliott', '\\N', '\\N', 'miscellaneous', 'tt0861343'],
#  ['nm2264620',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0803030,tt0818620,tt0758745,tt0427848'],
#  ['nm2269751', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0494235'],
#  ['nm2275887',
#   'John Milhiser',
#   '\\N',
#   '\\N',
#   'actor,writer,editor',
#   'tt0072562,tt5990096,tt1289401,tt4061080'],
#  ['nm2323596',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   nan,
#   'tt4397866,tt1636189,tt1636331,tt0181269'],
#  ['nm2354000',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt1642373,tt1811323,tt0840371'],
#  ['nm2379655', 'Dennis Miller', '\\N', '\\N', 'editor', 'tt0119277'],
#  ['nm2385054', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt0972846'],
#  ['nm2396934',
#   'Michael McKean',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0129910'],
#  ['nm2460645',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor,music_department',
#   'tt0382382'],
#  ['nm2511320', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt0368257'],
#  ['nm2522357',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'location_management',
#   'tt0238304,tt0238305,tt0238303,tt0104512'],
#  ['nm2529548',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   nan,
#   'tt14773254,tt13645690,tt12058768,tt0298674'],
#  ['nm2544987', 'Mike Myers', '\\N', '\\N', 'camera_department', 'tt0115279'],
#  ['nm2572052',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt6306064,tt0095408'],
#  ['nm2597086',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0457433,tt0470023,tt1107855,tt0464041'],
#  ['nm2605900',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department',
#   'tt3765728,tt1242542'],
#  ['nm2610385',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'actress,director,writer',
#   'tt1006983,tt3773358,tt14945492,tt9170758'],
#  ['nm2620120',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'transportation_department,miscellaneous',
#   'tt1272878,tt0765010,tt0452625,tt0457572'],
#  ['nm2641016', "Mike O'Brien", '\\N', '\\N', 'editor', 'tt0949671'],
#  ['nm2642562',
#   'Lauren Holt',
#   '\\N',
#   '\\N',
#   'animation_department,editorial_department,miscellaneous',
#   'tt1022605,tt3449322,tt0815250'],
#  ['nm2660474',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'miscellaneous',
#   'tt0846694,tt0416779'],
#  ['nm2672552', 'Tom Davis', '\\N', '\\N', 'visual_effects', 'tt0349903'],
#  ['nm2675038', 'Rob Schneider', '\\N', '\\N', 'actor', 'tt1039621'],
#  ['nm2682875', 'Fred Wolf', '\\N', '\\N', 'actor', 'tt1032874'],
#  ['nm2720332', 'Alex Moffat', '\\N', '\\N', 'actor', 'tt0112230,tt0111999'],
#  ['nm2722633',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'animation_department,art_department',
#   'tt0874300,tt1751105,tt3529198,tt8651594'],
#  ['nm2761469', 'Chris Parnell', '\\N', '\\N', nan, 'tt1020109,tt0343316'],
#  ['nm2767460',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt0099566'],
#  ['nm2776607',
#   'Aristotle Athari',
#   '\\N',
#   '\\N',
#   'actor,director,cinematographer',
#   'tt9173436,tt5918784,tt5917146,tt7322648'],
#  ['nm2790436',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'writer,producer,actor',
#   'tt2421910,tt1112661'],
#  ['nm2809577',
#   'Jenny Slate',
#   '1982',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt2709768,tt2948356,tt4481414,tt2910274'],
#  ['nm2825937', 'Tom Davis', '\\N', '\\N', nan, 'tt1136478,tt2787132'],
#  ['nm2846691', 'Fred Wolf', '\\N', '\\N', nan, '\\N'],
#  ['nm2846739',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'miscellaneous,camera_department',
#   'tt2719804,tt1357005,tt1100051'],
#  ['nm2870034', 'Tom Davis', '\\N', '\\N', 'actor', 'tt0106137'],
#  ['nm2881085', 'Tom Davis', '\\N', '\\N', 'location_management', 'tt0086192'],
#  ['nm2945828',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt0133302,tt1626811,tt0115355,tt0120801'],
#  ['nm2966932',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'editor,editorial_department',
#   'tt1732762,tt1210095'],
#  ['nm2968461',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'producer,camera_department',
#   'tt0400410,tt0939564'],
#  ['nm2997086', 'Martin Short', '\\N', '\\N', 'actor', 'tt0079687'],
#  ['nm3009952', 'Kate McKinnon', '\\N', '\\N', 'actress', 'tt0092225'],
#  ['nm3025851', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt0051297'],
#  ['nm3054255', 'Tom Davis', '\\N', '\\N', 'actor', 'tt1250756'],
#  ['nm3076354',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt4229954,tt0775529,tt0494864'],
#  ['nm3080722',
#   'Beck Bennett',
#   '\\N',
#   '\\N',
#   'actor,writer,producer',
#   'tt3470600,tt7979580,tt5531466,tt1086064'],
#  ['nm3085792', 'Leslie Jones', '\\N', '\\N', 'actor', 'tt0031055'],
#  ['nm3089340',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1366945,tt1107855,tt2182211,tt0313038'],
#  ['nm3174251', 'Jeff Richards', '\\N', '\\N', 'cinematographer', 'tt0393274'],
#  ['nm3174274',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'producer,miscellaneous',
#   'tt1584933,tt0401759,tt9248866,tt0368107'],
#  ['nm3199973', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1326172'],
#  ['nm3213154',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'animation_department',
#   'tt0174392'],
#  ['nm3291792', 'Mike Myers', '\\N', '\\N', 'camera_department', 'tt1362049'],
#  ['nm3324982',
#   'Kyle Mooney',
#   '1984',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt15977708,tt2139555,tt1608290,tt5805752'],
#  ['nm3364779',
#   'Vanessa Bayer',
#   '1981',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0072562,tt2989524,tt1711525,tt3152624'],
#  ['nm3448959', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt1279966'],
#  ['nm3483071', 'Tom Davis', '\\N', '\\N', 'camera_department', 'tt0128707'],
#  ['nm3510834',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'camera_department,director,actor',
#   'tt1462862,tt1507979,tt1462856'],
#  ['nm3550886',
#   'Sasheer Zamata',
#   '1986',
#   '\\N',
#   'actress,writer,producer',
#   'tt4018068,tt11394332,tt4018066,tt6791096'],
#  ['nm3578809', 'Bill Murray', '\\N', '\\N', 'producer', 'tt1490534'],
#  ['nm3600806', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt1587314,tt1505388'],
#  ['nm3625945', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1493558'],
#  ['nm3644706',
#   'Noël Wells',
#   '1986',
#   '\\N',
#   'actress,editor,miscellaneous',
#   'tt0072562,tt7713450,tt6212496,tt9184820'],
#  ['nm3673242',
#   'Bill Murray',
#   '1908',
#   '1986',
#   nan,
#   'tt1687207,tt1600694,tt1538443'],
#  ['nm3677317', 'Jeff Richards', '\\N', '\\N', 'miscellaneous', 'tt0072265'],
#  ['nm3678497', 'Rich Hall', '\\N', '\\N', 'director,writer', 'tt1542770'],
#  ['nm3697626',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'writer,composer,music_department',
#   'tt1551638'],
#  ['nm3710139', 'Tom Davis', '\\N', '\\N', 'miscellaneous', 'tt1517228'],
#  ['nm3743306',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'actor,producer,director',
#   'tt2265215,tt1982864,tt1565981,tt2382015'],
#  ['nm3758883', 'Leslie Jones', '\\N', '\\N', 'director,producer', 'tt1575557'],
#  ['nm3760937',
#   'Luke Null',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1545490,tt0072562,tt9881938,tt3146066'],
#  ['nm3830257',
#   'Melissa Villaseñor',
#   '1987',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt1809001,tt0072562,tt5848272,tt10682266'],
#  ['nm3846408',
#   'Michael Che',
#   '\\N',
#   '\\N',
#   'writer,actor,camera_department',
#   'tt0072562,tt12762460,tt0499556,tt2784678'],
#  ['nm3890281', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm3895112', 'Tom Davis', '\\N', '\\N', 'art_department', 'tt1326139'],
#  ['nm3910307', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt0380060'],
#  ['nm3911007', 'Chris Rock', '\\N', '\\N', 'actor', 'tt1556078'],
#  ['nm3915439', "Mike O'Brien", '\\N', '\\N', 'miscellaneous', 'tt1193138'],
#  ['nm3920709',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'camera_department,cinematographer,director',
#   'tt6091368,tt2445666,tt6083648,tt9748306'],
#  ['nm3930873',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department,editor',
#   'tt0389911,tt1663232,tt4502270,tt4504130'],
#  ['nm3933527', 'Tim Robinson', '\\N', '\\N', 'camera_department', 'tt1664843'],
#  ['nm3941693',
#   'Dennis Miller',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt0829176'],
#  ['nm3950870', 'Chris Elliott', '\\N', '\\N', nan, '\\N'],
#  ['nm3981127', 'Casey Wilson', '\\N', '\\N', 'camera_department', 'tt1687906'],
#  ['nm3982894',
#   'Jay Pharoah',
#   '1987',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0072562,tt5774044,tt1408253,tt7153766'],
#  ['nm3997014',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt2790032,tt2790152,tt2798906'],
#  ['nm4013649', 'Mike Myers', '\\N', '\\N', nan, 'tt0096563'],
#  ['nm4028688', 'Mike Myers', '\\N', '\\N', 'writer', 'tt1708468'],
#  ['nm4039470', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm4100863', 'Emily Prager', '\\N', '\\N', nan, '\\N'],
#  ['nm4104448',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'make_up_department',
#   'tt1518327'],
#  ['nm4142075', 'Chris Elliott', '\\N', '\\N', nan, 'tt0262152'],
#  ['nm4180892', 'Tim Robinson', '\\N', '\\N', 'actor', 'tt1777032'],
#  ['nm4200503',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'writer,actor,producer',
#   'tt10050772,tt6343706,tt4779762,tt0072562'],
#  ['nm4204968',
#   'Paul Brittain',
#   '1977',
#   '\\N',
#   'actor,soundtrack',
#   'tt0837562,tt0072562,tt2176287,tt2510894'],
#  ['nm4215887',
#   'Martin Short',
#   '1943',
#   '2020',
#   'writer,producer,miscellaneous',
#   'tt1791798,tt0938980,tt5747320,tt1297329'],
#  ['nm4256972', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt1493151,tt1813516'],
#  ['nm4257796', 'Bill Murray', '\\N', '\\N', 'actor', 'tt1810727'],
#  ['nm4269084',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'actor,writer,producer',
#   'tt4468740,tt4158096,tt4673856,tt8096690'],
#  ['nm4289813', 'Bill Murray', '\\N', '\\N', nan, 'tt1740656'],
#  ['nm4310690',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'sound_department,art_department,camera_department',
#   'tt2147467,tt1837678'],
#  ['nm4326982',
#   'Eddie Murphy',
#   '\\N',
#   '\\N',
#   'animation_department',
#   'tt0492509'],
#  ['nm4339544',
#   'Jon Rudnitsky',
#   '\\N',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0072562,tt5719700'],
#  ['nm4343157', 'Tom Davis', '1945', '\\N', 'actor', 'tt1850339'],
#  ['nm4359305', 'Tim Robinson', '\\N', '\\N', 'camera_department', 'tt1857742'],
#  ['nm4380769',
#   'Mike Myers',
#   '\\N',
#   '\\N',
#   'special_effects',
#   'tt5657856,tt1817273,tt6133466,tt1219289'],
#  ['nm4408208', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1885305'],
#  ['nm4435047',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1911645,tt2450652,tt2282941'],
#  ['nm4473273', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt1434435'],
#  ['nm4481414', 'Bill Murray', '\\N', '\\N', 'actor', 'tt1884251'],
#  ['nm4489897', 'Casey Wilson', '\\N', '\\N', 'actress', 'tt1951191'],
#  ['nm4520392',
#   'Bill Murray',
#   '\\N',
#   '\\N',
#   'cinematographer,camera_department',
#   'tt1972582'],
#  ['nm4536114', 'Casey Wilson', '\\N', '\\N', 'editor', 'tt1982864'],
#  ['nm4539981', 'Mike Myers', '\\N', '\\N', 'costume_department', 'tt1984991'],
#  ['nm4562498',
#   'James Austin Johnson',
#   '\\N',
#   '\\N',
#   'actor,writer,miscellaneous',
#   'tt0072562,tt8036272,tt3032476,tt0475290'],
#  ['nm4573109', 'Tracy Morgan', '\\N', '\\N', nan, '\\N'],
#  ['nm4583865', 'Sarah Sherman', '\\N', '\\N', 'actress', 'tt1999871'],
#  ['nm4592210',
#   'Yvonne Hudson',
#   '\\N',
#   '\\N',
#   'miscellaneous,actress,casting_director',
#   'tt2033480,tt3526474,tt2142935,tt2156935'],
#  ['nm4603998', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm4633705',
#   'Tracy Morgan',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt1887882'],
#  ['nm4657360', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2043951'],
#  ['nm4658374', 'Mike Myers', '\\N', '\\N', 'special_effects', 'tt2004334'],
#  ['nm4702231',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt0321473'],
#  ['nm4800774', "Mike O'Brien", '\\N', '\\N', nan, 'tt1170243'],
#  ['nm4806887',
#   'Chloe Fineman',
#   '1988',
#   '\\N',
#   'actress,location_management',
#   'tt0072562,tt8577458,tt6527474,tt5460226'],
#  ['nm4826405', 'Bill Murray', '\\N', '\\N', 'art_department', 'tt2147467'],
#  ['nm4828992', 'Tracy Morgan', '\\N', '\\N', nan, '\\N'],
#  ['nm4832730',
#   'Tom Davis',
#   '1967',
#   '\\N',
#   'miscellaneous',
#   'tt2288153,tt0189246,tt0081857,tt2161907'],
#  ['nm4857388', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm4895587', 'Rich Hall', '\\N', '\\N', nan, 'tt0146386'],
#  ['nm4906505', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2247021'],
#  ['nm4926467', 'Bill Murray', '\\N', '\\N', 'actor', 'tt2202391'],
#  ['nm4929014', 'Tim Robinson', '\\N', '\\N', nan, 'tt2275949'],
#  ['nm4930586', 'Chris Farley', '\\N', '\\N', 'writer', 'tt2275913'],
#  ['nm4945455',
#   'Ego Nwodim',
#   '\\N',
#   '\\N',
#   'actress,soundtrack,costume_department',
#   'tt6110318,tt3598030,tt0072562,tt7379494'],
#  ['nm4949478', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2300919'],
#  ['nm4977915', 'Leslie Jones', '\\N', '\\N', 'miscellaneous', 'tt0104423'],
#  ['nm4997878', 'Yvonne Hudson', '\\N', '\\N', nan, 'tt2355949'],
#  ['nm5073476', 'Tracy Morgan', '\\N', '\\N', nan, 'tt0063892'],
#  ['nm5120390',
#   'Brooks Wheelan',
#   '1986',
#   '\\N',
#   'actor,writer,producer',
#   'tt10050772,tt0072562,tt1600194,tt5244974'],
#  ['nm5122180',
#   'Terry Sweeney',
#   '\\N',
#   '\\N',
#   'actor,soundtrack',
#   'tt2386353,tt2576688,tt3313760,tt3517306'],
#  ['nm5127148', 'Kyle Mooney', '\\N', '\\N', nan, '\\N'],
#  ['nm5139377', 'Bill Murray', '\\N', '\\N', 'sound_department', 'tt2243836'],
#  ['nm5163268', 'Dennis Miller', '\\N', '\\N', nan, 'tt1275472'],
#  ['nm5198446',
#   'Cecily Strong',
#   '1984',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0072562,tt11808942,tt2702724,tt1289401'],
#  ['nm5206346', 'Chris Farley', '\\N', '\\N', 'actor', 'tt2328612'],
#  ['nm5230632', 'Bill Murray', '\\N', '\\N', 'sound_department', 'tt2356940'],
#  ['nm5255287',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'casting_department',
#   'tt3218622,tt5648234,tt2378652,tt11940818'],
#  ['nm5262775',
#   'Aidy Bryant',
#   '1987',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt5462602,tt11092142,tt8962130,tt0072562'],
#  ['nm5268180',
#   'Leslie Jones',
#   '\\N',
#   '\\N',
#   'costume_department,actress',
#   'tt0297607,tt0360255,tt0358809,tt4568496'],
#  ['nm5296555', 'Terry Sweeney', '\\N', '\\N', nan, '\\N'],
#  ['nm5298712', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm5311105', "Mike O'Brien", '\\N', '\\N', 'actor,producer', 'tt2423776'],
#  ['nm5358702', 'Chris Elliott', '\\N', '\\N', nan, '\\N'],
#  ['nm5368653', 'Tom Schiller', '\\N', '\\N', 'actor', 'tt9068272'],
#  ['nm5374987', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt1957867'],
#  ['nm5381865', 'Terry Sweeney', '\\N', '\\N', 'actor', 'tt2474812'],
#  ['nm5398255', 'Rich Hall', '\\N', '\\N', 'art_department', 'tt1650554'],
#  ['nm5412083',
#   'Chris Redd',
#   '\\N',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt3960412,tt5884792,tt7286456,tt0072562'],
#  ['nm5415866', 'Phil Hartman', '\\N', '\\N', nan, '\\N'],
#  ['nm5428992', 'Tim Robinson', '1935', '2020', 'writer', 'tt2582038'],
#  ['nm5460097', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt2625536'],
#  ['nm5462850', 'Rich Hall', '\\N', '\\N', 'camera_department', 'tt2369573'],
#  ['nm5465769', 'Seth Meyers', '\\N', '\\N', nan, 'tt0124932'],
#  ['nm5479432', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm5500570', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt2671586'],
#  ['nm5518479', 'Victoria Jackson', '\\N', '\\N', nan, 'tt2307673'],
#  ['nm5539698', 'Tom Davis', '\\N', '\\N', nan, 'tt2728770'],
#  ['nm5575320', 'Mike Myers', '\\N', '\\N', 'art_department', 'tt0299712'],
#  ['nm5601269', 'Leslie Jones', '\\N', '\\N', nan, 'tt2803888'],
#  ['nm5602633', 'Sarah Sherman', '\\N', '\\N', 'actress', 'tt2803096'],
#  ['nm5609314', 'Sarah Sherman', '\\N', '\\N', 'producer,actress', 'tt2261238'],
#  ['nm5628268',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'producer,writer',
#   'tt4742812,tt2828570,tt3503754,tt5774598'],
#  ['nm5629957', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm5633884', 'Dennis Miller', '\\N', '\\N', nan, '\\N'],
#  ['nm5642597', "Mike O'Brien", '\\N', '\\N', nan, '\\N'],
#  ['nm5643945', 'Dennis Miller', '\\N', '\\N', 'producer', 'tt2866916'],
#  ['nm5648732', 'Brad Hall', '\\N', '\\N', 'actor', 'tt0122827'],
#  ['nm5659941', 'Dennis Miller', '\\N', '\\N', nan, 'tt0123338'],
#  ['nm5666584',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt3856408,tt3972208,tt1535977'],
#  ['nm5692847', 'Leslie Jones', '\\N', '\\N', nan, '\\N'],
#  ['nm5695760', 'Mike Myers', '\\N', '\\N', 'art_director', 'tt2916548'],
#  ['nm5706361', 'Mark McKinney', '\\N', '\\N', 'cinematographer', 'tt2954994'],
#  ['nm5708457', 'Brad Hall', '\\N', '\\N', 'director,producer', 'tt2953902'],
#  ['nm5770787',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'actor,producer,writer',
#   'tt7525600,tt2826134,tt7525638,tt6227116'],
#  ['nm5803981',
#   'Alex Moffat',
#   '1982',
#   '\\N',
#   'actor,director',
#   'tt9866072,tt1217217,tt5848272,tt3219194'],
#  ['nm5838946', 'Tracy Morgan', '\\N', '\\N', 'miscellaneous', 'tt0100332'],
#  ['nm5848694', 'Chris Rock', '\\N', '\\N', 'producer', 'tt2357748'],
#  ['nm5872054', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm5894755', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3091734'],
#  ['nm5905712', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3147486'],
#  ['nm5906920',
#   'Heidi Gardner',
#   '1983',
#   '\\N',
#   'actress,writer',
#   'tt4180560,tt5101204,tt10324166,tt5619332'],
#  ['nm5907222', 'Tom Davis', '\\N', '\\N', nan, 'tt0133302'],
#  ['nm5922353',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'director,actor,writer',
#   'tt3162968'],
#  ['nm5946351', 'Mike Myers', '\\N', '\\N', 'composer', 'tt3185956'],
#  ['nm5960919', 'Molly Shannon', '\\N', '\\N', 'actress', 'tt0362542'],
#  ['nm5977544', 'Alex Moffat', '\\N', '\\N', nan, '\\N'],
#  ['nm5987491', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3231836'],
#  ['nm6036494', 'Jim Downey', '\\N', '\\N', 'producer', 'tt3281976'],
#  ['nm6133039', 'Christopher Guest', '\\N', '\\N', 'actor', 'tt3384430'],
#  ['nm6151446', 'Chris Parnell', '\\N', '\\N', 'cinematographer', 'tt3402362'],
#  ['nm6158455',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'animation_department',
#   'tt2510894,tt4624424,tt4633694,tt5220122'],
#  ['nm6255561', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt3449744'],
#  ['nm6267657', 'Tom Davis', '\\N', '\\N', 'actor', 'tt3512322'],
#  ['nm6283130', 'Dennis Miller', '\\N', '\\N', 'miscellaneous', 'tt3458560'],
#  ['nm6286141', 'Jeff Richards', '\\N', '\\N', nan, '\\N'],
#  ['nm6291555',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'transportation_department',
#   'tt1179069'],
#  ['nm6299248',
#   'Bowen Yang',
#   '1990',
#   '\\N',
#   'actor,writer,producer',
#   'tt2587452,tt6078096,tt2452244'],
#  ['nm6299629', 'Victoria Jackson', '\\N', '\\N', 'actress', 'tt3172618'],
#  ['nm6310930',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'producer,director,camera_department',
#   'tt8909686,tt14435296,tt0199257,tt8909538'],
#  ['nm6344885', 'Bill Murray', '\\N', '\\N', 'editor', 'tt0115367'],
#  ['nm6350126', 'Chris Parnell', '\\N', '\\N', 'executive', '\\N'],
#  ['nm6365877', 'Bill Murray', '\\N', '\\N', 'director', 'tt3603706'],
#  ['nm6366128',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'producer,production_manager,miscellaneous',
#   'tt4575056,tt2630898,tt3548962,tt3562626'],
#  ['nm6375565', "Michael O'Donoghue", '\\N', '\\N', 'actor', 'tt0084264'],
#  ['nm6407619', 'Lauren Holt', '\\N', '\\N', 'art_department', 'tt3597448'],
#  ['nm6481103', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt3650844'],
#  ['nm6557993', 'Tom Davis', '\\N', '\\N', 'actor', 'tt3793204'],
#  ['nm6566424', 'Leslie Jones', '\\N', '\\N', 'actor', 'tt3800692,tt4056158'],
#  ['nm6580781', 'Sarah Sherman', '\\N', '\\N', 'actor', 'tt3815734'],
#  ['nm6588479',
#   'Kyle Mooney',
#   '\\N',
#   '\\N',
#   'special_effects,visual_effects',
#   'tt3823130'],
#  ['nm6638078', 'Jeff Richards', '\\N', '\\N', 'composer', 'tt3872944'],
#  ['nm6695372', 'Bill Murray', '\\N', '\\N', nan, '\\N'],
#  ['nm6729562',
#   'Casey Wilson',
#   '\\N',
#   '\\N',
#   'editorial_department',
#   'tt3263490'],
#  ['nm6758873', 'Tom Davis', '\\N', '\\N', 'art_department', 'tt3970482'],
#  ['nm6880758', 'Sarah Sherman', '\\N', '\\N', nan, '\\N'],
#  ['nm6888296', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt8386350'],
#  ['nm6908017', 'Bill Murray', '\\N', '\\N', 'actor', 'tt3790306'],
#  ['nm6934104', 'Tim Robinson', '\\N', '\\N', nan, '\\N'],
#  ['nm7041822', 'Sarah Sherman', '\\N', '\\N', nan, '\\N'],
#  ['nm7043228', 'Rich Hall', '\\N', '\\N', nan, '\\N'],
#  ['nm7096883',
#   'Will Ferrell',
#   '\\N',
#   '\\N',
#   'art_department',
#   'tt0061240,tt0058797,tt0061296,tt0062994'],
#  ['nm7109497', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt4203440'],
#  ['nm7147777', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt4475006'],
#  ['nm7171988',
#   'Alex Moffat',
#   '\\N',
#   '\\N',
#   'assistant_director,miscellaneous',
#   'tt3381008,tt5104604,tt2652092,tt5628302'],
#  ['nm7205497', 'Tim Robinson', '\\N', '\\N', nan, 'tt4049528'],
#  ['nm7234377', 'Bill Murray', '\\N', '\\N', 'writer', 'tt4571940'],
#  ['nm7250185', 'Jeff Richards', '\\N', '\\N', nan, 'tt3696804'],
#  ['nm7286360',
#   'Christopher Guest',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt4334642,tt1024855'],
#  ['nm7296040', 'Rob Schneider', '\\N', '\\N', 'miscellaneous', 'tt4432798'],
#  ['nm7301044',
#   'Dan Vitale',
#   '\\N',
#   '\\N',
#   'director,writer,producer',
#   'tt4656450,tt5903450'],
#  ['nm7307139', 'Phil Hartman', '\\N', '\\N', 'actor', 'tt4662448'],
#  ['nm7314528', 'Mike Myers', '\\N', '\\N', 'actor', 'tt4670472'],
#  ['nm7324531', 'Heidi Gardner', '\\N', '\\N', nan, '\\N'],
#  ['nm7341228', 'Mike Myers', '\\N', '\\N', 'actor', 'tt4497152'],
#  ['nm7390947', 'Dean Edwards', '\\N', '\\N', 'actor', 'tt0122905'],
#  ['nm7397944',
#   'Jeff Richards',
#   '\\N',
#   '\\N',
#   'production_designer',
#   'tt4780202'],
#  ['nm7414652', 'Brad Hall', '\\N', '\\N', nan, 'tt1554356'],
#  ['nm7427133', 'Mark McKinney', '\\N', '\\N', nan, 'tt6225166'],
#  ['nm7427142', 'Mark McKinney', '\\N', '\\N', 'editor', 'tt5441646,tt4823678'],
#  ['nm7429938', 'Phil Hartman', '\\N', '\\N', 'actor', 'tt4828104'],
#  ['nm7440291',
#   'Fred Wolf',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt3910602,tt10222674,tt0072562'],
#  ['nm7451606', 'Phil Hartman', '\\N', '\\N', 'miscellaneous', 'tt4701488'],
#  ['nm7452649', 'Mike Myers', '\\N', '\\N', nan, 'tt4853866'],
#  ['nm7479270', 'Chris Farley', '\\N', '\\N', nan, '\\N'],
#  ['nm7491272', 'Victoria Jackson', '\\N', '\\N', 'actress', 'tt4906964'],
#  ['nm7567645',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'actress,writer,miscellaneous',
#   'tt9534540,tt15467926,tt8425308,tt14601874'],
#  ['nm7576527',
#   'Lauren Holt',
#   '1991',
#   '\\N',
#   'actress',
#   'tt8394996,tt8937092,tt0072562,tt7546290'],
#  ['nm7585524', 'Tim Robinson', '\\N', '\\N', nan, 'tt4661598'],
#  ['nm7641022', 'Molly Shannon', '\\N', '\\N', nan, 'tt3675186'],
#  ['nm7681772', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt5124078'],
#  ['nm7683464', 'Chris Farley', '\\N', '\\N', 'sound_department', 'tt0142235'],
#  ['nm7705657',
#   'Brad Hall',
#   '\\N',
#   '\\N',
#   'editor,camera_department',
#   'tt5173520,tt6738058'],
#  ['nm7706610', "Mike O'Brien", '\\N', '\\N', 'visual_effects', 'tt3906560'],
#  ['nm7726543', 'Rich Hall', '\\N', '\\N', nan, '\\N'],
#  ['nm7791059',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt3739110'],
#  ['nm7815008', 'Phil Hartman', '\\N', '\\N', 'actor', 'tt5298646'],
#  ['nm7855877',
#   'Chris Rock',
#   '\\N',
#   '\\N',
#   'director,writer,editor',
#   'tt5346900'],
#  ['nm7860904',
#   "Mike O'Brien",
#   '\\N',
#   '\\N',
#   'editor,cinematographer',
#   'tt7119506,tt5352578'],
#  ['nm7906225',
#   'Mike Myers',
#   '\\N',
#   '\\N',
#   'camera_department,cinematographer',
#   'tt5442834,tt6137590'],
#  ['nm7941065', "Michael O'Donoghue", '\\N', '\\N', nan, '\\N'],
#  ['nm7966111', 'Mike Myers', '\\N', '\\N', nan, 'tt3109150'],
#  ['nm7992474', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt5542640'],
#  ['nm8052762', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt3859146'],
#  ['nm8054746',
#   'Mark McKinney',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt1216491,tt0795461,tt6285944'],
#  ['nm8067225', 'Tom Davis', '\\N', '\\N', 'actor', 'tt5631362,tt5631298'],
#  ['nm8093483', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt0093204'],
#  ['nm8096206', 'Mark McKinney', '\\N', '\\N', 'miscellaneous', 'tt2954994'],
#  ['nm8155395', 'Dennis Miller', '\\N', '\\N', 'actor', 'tt2114006'],
#  ['nm8157375', 'Dennis Miller', '\\N', '\\N', 'actor', 'tt2114006'],
#  ['nm8175223', "Mike O'Brien", '\\N', '\\N', 'sound_department', 'tt4977374'],
#  ['nm8191764', 'Will Ferrell', '\\N', '\\N', 'actor', 'tt5779664'],
#  ['nm8271258', 'Bill Murray', '\\N', '\\N', nan, 'tt5156614'],
#  ['nm8285155', "Michael O'Donoghue", '\\N', '\\N', 'actor', 'tt5880050'],
#  ['nm8300566', 'Dean Edwards', '\\N', '\\N', 'actor', 'tt5896628'],
#  ['nm8326174',
#   'Sarah Sherman',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt5924202'],
#  ['nm8329835', 'Sarah Sherman', '\\N', '\\N', 'actress', 'tt5924202'],
#  ['nm8378315',
#   'Victoria Jackson',
#   '\\N',
#   '\\N',
#   'camera_department,make_up_department',
#   'tt5941780'],
#  ['nm8439510',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'camera_department',
#   'tt7689318,tt6074820,tt6063510'],
#  ['nm8467312', 'Sarah Sherman', '\\N', '\\N', nan, '\\N'],
#  ['nm8489283', 'Tom Davis', '\\N', '\\N', nan, 'tt5993092'],
#  ['nm8505163',
#   'Tom Davis',
#   '\\N',
#   '\\N',
#   'director,cinematographer,editor',
#   'tt7252334,tt6142826,tt5870978,tt10607616'],
#  ['nm8517416', "Mike O'Brien", '\\N', '\\N', 'composer', 'tt6157660'],
#  ['nm8523579', 'Dean Edwards', '\\N', '\\N', 'composer', 'tt6166222'],
#  ['nm8537351', 'Chris Elliott', '\\N', '\\N', 'actor', 'tt6185624'],
#  ['nm8595385', 'Dennis Miller', '\\N', '\\N', 'visual_effects', 'tt11993098'],
#  ['nm8605638', 'Dean Edwards', '\\N', '\\N', nan, '\\N'],
#  ['nm8608160',
#   'Andrew Dismukes',
#   '\\N',
#   '\\N',
#   'writer,actor',
#   'tt14508698,tt0072562,tt13858722,tt6279022'],
#  ['nm8645930', 'Chris Farley', '\\N', '\\N', 'actor', 'tt6329792'],
#  ['nm8734124', 'Siobhan Fallon', '\\N', '\\N', 'writer', 'tt6463510'],
#  ['nm8739883', 'Leslie Jones', '\\N', '\\N', 'actress', 'tt6464314'],
#  ['nm8766863', 'Jeff Richards', '\\N', '\\N', 'actor', 'tt6512646'],
#  ['nm8783853', "Mike O'Brien", '\\N', '\\N', 'soundtrack', 'tt2998406'],
#  ['nm8815884', 'Chris Elliott', '\\N', '\\N', 'miscellaneous', 'tt6264596'],
#  ['nm8854251', 'Tim Robinson', '\\N', '\\N', 'miscellaneous', 'tt6391108'],
#  ['nm8912973',
#   'Seth Meyers',
#   '\\N',
#   '\\N',
#   'miscellaneous',
#   'tt6528132,tt0496571'],
#  ['nm8938826', 'Pete Davidson', '\\N', '\\N', 'actor', 'tt6806604'],
#  ['nm8978375', 'Alex Moffat', '\\N', '\\N', 'actor', 'tt6851750'],
#  ['nm9030399', 'Colin Quinn', '\\N', '\\N', 'art_department', 'tt3948764'],
#  ['nm9189163',
#   'Chris Elliott',
#   '\\N',
#   '\\N',
#   'make_up_department',
#   'tt7233816'],
#  ['nm9201551',
#   'Dean Edwards',
#   '\\N',
#   '\\N',
#   'editorial_department',
#   'tt6186672,tt0354333,tt1565436'],
#  ['nm9216626', 'Leslie Jones', '\\N', '\\N', 'actress', '\\N'],
#  ['nm9222500',
#   'Rich Hall',
#   '\\N',
#   '\\N',
#   'cinematographer,producer',
#   'tt8364112,tt7286604'],
#  ['nm9247139', 'Mike Myers', '\\N', '\\N', 'actor', 'tt1302137,tt0460843'],
#  ['nm9253219', 'Tom Davis', '\\N', '\\N', 'actor', 'tt7309462'],
#  ['nm9301955', 'Chris Parnell', '\\N', '\\N', nan, '\\N'],
#  ['nm9321275',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt7465694,tt8526284,tt7615118'],
#  ['nm9335986', 'Victoria Jackson', '\\N', '\\N', 'miscellaneous', 'tt0383760'],
#  ['nm9339453', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt7493170'],
#  ['nm9354190', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt7528072'],
#  ['nm9384729', 'Tracy Morgan', '\\N', '\\N', nan, '\\N'],
#  ['nm9390534', 'Tracy Morgan', '\\N', '\\N', 'editor', 'tt7587656'],
#  ['nm9395047', 'Colin Quinn', '\\N', '\\N', 'cinematographer', '\\N'],
#  ['nm9400036', 'Leslie Jones', '\\N', '\\N', 'actor', 'tt7604526'],
#  ['nm9401379', 'Joe Piscopo', '\\N', '\\N', nan, '\\N'],
#  ['nm9424876', 'Tom Davis', '\\N', '\\N', 'actor', 'tt7638698'],
#  ['nm9433183', 'Brad Hall', '\\N', '\\N', 'actor', 'tt0121946'],
#  ['nm9456219', 'Rob Schneider', '\\N', '\\N', 'actor', 'tt2642912'],
#  ['nm9502973', 'Mike Myers', '\\N', '\\N', 'camera_department', '\\N'],
#  ['nm9531701',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   nan,
#   'tt0112193,tt0396362,tt0335620,tt9090184'],
#  ['nm9546078', "Mike O'Brien", '\\N', '\\N', 'animation_department', '\\N'],
#  ['nm9573578', 'Tracy Morgan', '\\N', '\\N', nan, 'tt11833964,tt3644198'],
#  ['nm9652008', 'Dennis Miller', '\\N', '\\N', 'actor,assistant', 'tt3471592'],
#  ['nm9656009', 'Chris Elliott', '\\N', '\\N', 'writer,producer', '\\N'],
#  ['nm9681546', 'Brad Hall', '\\N', '\\N', 'director,producer', 'tt8106790'],
#  ['nm9737448', 'Julia Sweeney', '\\N', '\\N', 'miscellaneous', '\\N'],
#  ['nm9751499', 'Chris Rock', '\\N', '\\N', nan, '\\N'],
#  ['nm9772677',
#   'Rob Schneider',
#   '\\N',
#   '\\N',
#   'cinematographer,editor,producer',
#   'tt11239422,tt8280446'],
#  ['nm9790618',
#   'Punkie Johnson',
#   '\\N',
#   '\\N',
#   'actress,writer,producer',
#   'tt7242698,tt5821764,tt5117666,tt7778796'],
#  ['nm9825187', 'Sarah Sherman', '\\N', '\\N', 'art_director', 'tt8218988'],
#  ['nm9902053',
#   "Michael O'Donoghue",
#   '\\N',
#   '\\N',
#   'sound_department',
#   'tt1715425'],
#  ['nm9948379', "Mike O'Brien", '\\N', '\\N', 'actor', 'tt8554874'],
#  ['nm9974827', 'Chris Parnell', '\\N', '\\N', nan, 'tt7396544'],
#  ['nm9978675', 'Jim Downey', '\\N', '\\N', 'director', '\\N'],
#  ['nm9982772', 'Chris Farley', '\\N', '\\N', nan, '\\N'],
#  ['nm9992272', 'Mary Gross', '\\N', '\\N', nan, 'tt0423652']]

# %%
SNL_cred_check = [r for r in cross_imdb_wiki_list if check_creds(r[5])]
(SNL_cred_check)
# Out:
# [['nm0000004',
#   'John Belushi',
#   '1949',
#   '1982',
#   'actor,soundtrack,writer',
#   'tt0078723,tt0072562,tt0077975,tt0080455'],
#  ['nm0000902',
#   'Jim Belushi',
#   '1954',
#   '\\N',
#   'actor,music_department,producer',
#   'tt0097637,tt0072562,tt0117468,tt0095963'],
#  ['nm0001022',
#   'Dana Carvey',
#   '1955',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0072562,tt0108525,tt0105793,tt0295427'],
#  ['nm0005265',
#   'Kevin Nealon',
#   '1953',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0072562,tt0116483,tt0439100,tt0120888'],
#  ['nm0035488',
#   'Fred Armisen',
#   '1966',
#   '\\N',
#   'music_department,actor,writer',
#   'tt0357413,tt1282140,tt0072562,tt1780441'],
#  ['nm0112944',
#   'A. Whitney Brown',
#   '1952',
#   '\\N',
#   'writer,actor',
#   'tt0096708,tt0072562,tt0166039,tt1094991'],
#  ['nm0128639',
#   'Beth Cahill',
#   '\\N',
#   '\\N',
#   'actress,costume_designer,miscellaneous',
#   'tt0155764,tt0262411,tt0164930,tt0072562'],
#  ['nm0205569',
#   'Tom Davis',
#   '1952',
#   '2012',
#   'writer,actor,producer',
#   'tt0086465,tt0251075,tt0106598,tt0072562'],
#  ['nm0241208',
#   'Robin Duke',
#   '1954',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0075578,tt0117108,tt0107048,tt0072562'],
#  ['nm0291253',
#   'Al Franken',
#   '1951',
#   '\\N',
#   'writer,producer,actor',
#   'tt0114571,tt0368008,tt0086465,tt0072562'],
#  ['nm0343444',
#   'Mary Gross',
#   '1953',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0120791,tt0243736,tt0094846,tt0072562'],
#  ['nm0356025',
#   'Rich Hall',
#   '1954',
#   '\\N',
#   'writer,actor,producer',
#   'tt0072562,tt0325939,tt0085065,tt1430607'],
#  ['nm0358669',
#   'Darrell Hammond',
#   '1955',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0799949,tt0118747,tt0306047,tt0072562'],
#  ['nm0399994',
#   'Yvonne Hudson',
#   '\\N',
#   '\\N',
#   'actress,miscellaneous',
#   'tt0277167,tt0072562'],
#  ['nm0404525',
#   'Melanie Hutsell',
#   '\\N',
#   '\\N',
#   'actress,soundtrack',
#   'tt4789300,tt1478338,tt0072562,tt2191701'],
#  ['nm0428656',
#   'Leslie Jones',
#   '1967',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0072562,tt6802400,tt1289401,tt2461150'],
#  ['nm0443730',
#   'Tim Kazurinsky',
#   '1950',
#   '\\N',
#   'actor,writer,miscellaneous',
#   'tt0090583,tt0089822,tt0082801,tt0072562'],
#  ['nm0453115',
#   'Taran Killam',
#   '1982',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt2024544,tt0072562,tt5689068,tt4000956'],
#  ['nm0471856',
#   'Gary Kroeger',
#   '1957',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0200525,tt0072562,tt0046593,tt0086765'],
#  ['nm0560257',
#   'Gail Matthius',
#   '1953',
#   '\\N',
#   'actress,soundtrack',
#   'tt0072562,tt0162796,tt0083530,tt0103373'],
#  ['nm0571952',
#   'Kate McKinnon',
#   '1984',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt4799050,tt0072562,tt6394270,tt1289401'],
#  ['nm0606541',
#   'Garrett Morris',
#   '1937',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt0072562,tt0478970,tt0106598,tt0278488'],
#  ['nm0637038',
#   'Don Novello',
#   '1943',
#   '\\N',
#   'actor,writer,producer',
#   'tt0072562,tt0112642,tt0099674,tt0230011'],
#  ['nm0640874',
#   "Michael O'Donoghue",
#   '1940',
#   '1994',
#   'writer,actor,miscellaneous',
#   'tt0096061,tt0079583,tt0079522,tt0072562'],
#  ['nm0685472',
#   'Joe Piscopo',
#   '1951',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0092226,tt0072562,tt0094961,tt0087507'],
#  ['nm0688132',
#   'Amy Poehler',
#   '1971',
#   '\\N',
#   'actress,producer,writer',
#   'tt2096673,tt0871426,tt1266020,tt0072562'],
#  ['nm0705717',
#   'Gilda Radner',
#   '1946',
#   '1989',
#   'actress,soundtrack,writer',
#   'tt0070290,tt0091178,tt0084049,tt0072562'],
#  ['nm0724145',
#   'Jeff Richards',
#   '1974',
#   '\\N',
#   'actor,writer,producer',
#   'tt0759475,tt0468999,tt4687632,tt0072562'],
#  ['nm0728315',
#   'Ann Risley',
#   '1949',
#   '\\N',
#   'actress',
#   'tt0072562,tt0081554,tt0081518,tt0082525'],
#  ['nm0771680',
#   'Tom Schiller',
#   '1949',
#   '\\N',
#   'writer,actor,director',
#   'tt0087817,tt0072562,tt3677742,tt0304046'],
#  ['nm0806912',
#   'Robert Smigel',
#   '1960',
#   '\\N',
#   'writer,producer,actor',
#   'tt0185431,tt0072562,tt0106052,tt0272338'],
#  ['nm0860380',
#   'Kenan Thompson',
#   '1978',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0417148,tt0072562,tt0115231,tt0119215'],
#  ['nm0899865',
#   'Dan Vitale',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt0088804,tt0086768,tt1744760,tt0072562'],
#  ['nm0958993',
#   'Alan Zweibel',
#   '1950',
#   '\\N',
#   'writer,producer,actor',
#   'tt0090459,tt0072562,tt0092925,tt0110687'],
#  ['nm1024878',
#   'Seth Meyers',
#   '1973',
#   '\\N',
#   'writer,actor,producer',
#   'tt1598822,tt4677934,tt0072562,tt3513388'],
#  ['nm1293885',
#   'Bobby Moynihan',
#   '1977',
#   '\\N',
#   'actor,soundtrack,writer',
#   'tt13622982,tt10662034,tt0072562'],
#  ['nm1459509',
#   'Finesse Mitchell',
#   '1972',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0785077,tt0072562,tt0951216,tt0790804'],
#  ['nm1510062',
#   'Mikey Day',
#   '1980',
#   '\\N',
#   'actor,writer,producer',
#   'tt0072562,tt2076347,tt1217217,tt4000956'],
#  ['nm1676221',
#   'Andy Samberg',
#   '1978',
#   '\\N',
#   'actor,producer,soundtrack',
#   'tt0072562,tt3960412,tt2467372,tt9484998'],
#  ['nm1906042',
#   'Colin Jost',
#   '1982',
#   '\\N',
#   'writer,actor,miscellaneous',
#   'tt0072562,tt1292566,tt1361336,tt6802400'],
#  ['nm2212031',
#   'Abby Elliott',
#   '1987',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt0072562,tt1291150,tt1663143,tt1411238'],
#  ['nm2275887',
#   'John Milhiser',
#   '\\N',
#   '\\N',
#   'actor,writer,editor',
#   'tt0072562,tt5990096,tt1289401,tt4061080'],
#  ['nm3364779',
#   'Vanessa Bayer',
#   '1981',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt0072562,tt2989524,tt1711525,tt3152624'],
#  ['nm3644706',
#   'Noël Wells',
#   '1986',
#   '\\N',
#   'actress,editor,miscellaneous',
#   'tt0072562,tt7713450,tt6212496,tt9184820'],
#  ['nm3760937',
#   'Luke Null',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt1545490,tt0072562,tt9881938,tt3146066'],
#  ['nm3830257',
#   'Melissa Villaseñor',
#   '1987',
#   '\\N',
#   'actress,soundtrack,writer',
#   'tt1809001,tt0072562,tt5848272,tt10682266'],
#  ['nm3846408',
#   'Michael Che',
#   '\\N',
#   '\\N',
#   'writer,actor,camera_department',
#   'tt0072562,tt12762460,tt0499556,tt2784678'],
#  ['nm3982894',
#   'Jay Pharoah',
#   '1987',
#   '\\N',
#   'actor,soundtrack,producer',
#   'tt0072562,tt5774044,tt1408253,tt7153766'],
#  ['nm4200503',
#   'Tim Robinson',
#   '\\N',
#   '\\N',
#   'writer,actor,producer',
#   'tt10050772,tt6343706,tt4779762,tt0072562'],
#  ['nm4204968',
#   'Paul Brittain',
#   '1977',
#   '\\N',
#   'actor,soundtrack',
#   'tt0837562,tt0072562,tt2176287,tt2510894'],
#  ['nm4339544',
#   'Jon Rudnitsky',
#   '\\N',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt0072562,tt5719700'],
#  ['nm4562498',
#   'James Austin Johnson',
#   '\\N',
#   '\\N',
#   'actor,writer,miscellaneous',
#   'tt0072562,tt8036272,tt3032476,tt0475290'],
#  ['nm4806887',
#   'Chloe Fineman',
#   '1988',
#   '\\N',
#   'actress,location_management',
#   'tt0072562,tt8577458,tt6527474,tt5460226'],
#  ['nm4945455',
#   'Ego Nwodim',
#   '\\N',
#   '\\N',
#   'actress,soundtrack,costume_department',
#   'tt6110318,tt3598030,tt0072562,tt7379494'],
#  ['nm5120390',
#   'Brooks Wheelan',
#   '1986',
#   '\\N',
#   'actor,writer,producer',
#   'tt10050772,tt0072562,tt1600194,tt5244974'],
#  ['nm5198446',
#   'Cecily Strong',
#   '1984',
#   '\\N',
#   'actress,soundtrack,producer',
#   'tt0072562,tt11808942,tt2702724,tt1289401'],
#  ['nm5262775',
#   'Aidy Bryant',
#   '1987',
#   '\\N',
#   'actress,writer,soundtrack',
#   'tt5462602,tt11092142,tt8962130,tt0072562'],
#  ['nm5412083',
#   'Chris Redd',
#   '\\N',
#   '\\N',
#   'actor,writer,soundtrack',
#   'tt3960412,tt5884792,tt7286456,tt0072562'],
#  ['nm7440291',
#   'Fred Wolf',
#   '\\N',
#   '\\N',
#   'actor',
#   'tt3910602,tt10222674,tt0072562'],
#  ['nm7576527',
#   'Lauren Holt',
#   '1991',
#   '\\N',
#   'actress',
#   'tt8394996,tt8937092,tt0072562,tt7546290'],
#  ['nm8608160',
#   'Andrew Dismukes',
#   '\\N',
#   '\\N',
#   'writer,actor',
#   'tt14508698,tt0072562,tt13858722,tt6279022']]

# %%
SNL_df = pd.DataFrame(SNL_cred_check, columns = imdb_names.columns.tolist()).set_index('primaryName')

# %%
SNL_df
# Out:
#                     nconst birthYear deathYear  \
# primaryName
# John Belushi     nm0000004      1949      1982
# Jim Belushi      nm0000902      1954        \N
# Dana Carvey      nm0001022      1955        \N
# Kevin Nealon     nm0005265      1953        \N
# Fred Armisen     nm0035488      1966        \N
# ...                    ...       ...       ...
# Aidy Bryant      nm5262775      1987        \N
# Chris Redd       nm5412083        \N        \N
# Fred Wolf        nm7440291        \N        \N
# Lauren Holt      nm7576527      1991        \N
# Andrew Dismukes  nm8608160        \N        \N
#
#                                primaryProfession  \
# primaryName
# John Belushi             actor,soundtrack,writer
# Jim Belushi      actor,music_department,producer
# Dana Carvey              actor,soundtrack,writer
# Kevin Nealon             actor,writer,soundtrack
# Fred Armisen       music_department,actor,writer
# ...                                          ...
# Aidy Bryant            actress,writer,soundtrack
# Chris Redd               actor,writer,soundtrack
# Fred Wolf                                  actor
# Lauren Holt                              actress
# Andrew Dismukes                     writer,actor
#
#                                             knownForTitles
# primaryName
# John Belushi       tt0078723,tt0072562,tt0077975,tt0080455
# Jim Belushi        tt0097637,tt0072562,tt0117468,tt0095963
# Dana Carvey        tt0072562,tt0108525,tt0105793,tt0295427
# Kevin Nealon       tt0072562,tt0116483,tt0439100,tt0120888
# Fred Armisen       tt0357413,tt1282140,tt0072562,tt1780441
# ...                                                    ...
# Aidy Bryant       tt5462602,tt11092142,tt8962130,tt0072562
# Chris Redd         tt3960412,tt5884792,tt7286456,tt0072562
# Fred Wolf                   tt3910602,tt10222674,tt0072562
# Lauren Holt        tt8394996,tt8937092,tt0072562,tt7546290
# Andrew Dismukes  tt14508698,tt0072562,tt13858722,tt6279022
#
# [61 rows x 5 columns]

# %%
wiki_cast = wiki_cast.set_index('Performer')

# %%
imdb_wiki_table = pd.concat([SNL_df, wiki_cast], axis=1, join="outer")

# %% [markdown]
# # IMDb Wiki Table concat
# At this point, I have joined the Wiki and IMDb name tables together based on the cast member name. The joined table now has the unique cast member ID (nconst), birth and death years (where applicable), primary profession (actor dshould be in most, if not all of the cast professsion lists), known for titles (IMDb unique IDs for projects), Time on SNL (Years), No. of seasons, and whether or not they cast member was a: Repertory Player, Featured Player, Middle Group, "Weekend Update" Anchor, Host (after leaving the cast), and/or Writer.
#
# For some reason, there are some cast members (Kristen Wiig, Bowen Yang, Sasheer Zamata, etc.) whose names aren't getting parsed from the IMDb data so I'll need to look into that further.

# %%
imdb_wiki_table
# Out:
#                      nconst birthYear deathYear  \
# John Belushi      nm0000004      1949      1982
# Jim Belushi       nm0000902      1954        \N
# Dana Carvey       nm0001022      1955        \N
# Kevin Nealon      nm0005265      1953        \N
# Fred Armisen      nm0035488      1966        \N
# ...                     ...       ...       ...
# Patrick Weathers        NaN       NaN       NaN
# Kristen Wiig            NaN       NaN       NaN
# Casey Wilson            NaN       NaN       NaN
# Bowen Yang              NaN       NaN       NaN
# Sasheer Zamata          NaN       NaN       NaN
#
#                                 primaryProfession  \
# John Belushi              actor,soundtrack,writer
# Jim Belushi       actor,music_department,producer
# Dana Carvey               actor,soundtrack,writer
# Kevin Nealon              actor,writer,soundtrack
# Fred Armisen        music_department,actor,writer
# ...                                           ...
# Patrick Weathers                              NaN
# Kristen Wiig                                  NaN
# Casey Wilson                                  NaN
# Bowen Yang                                    NaN
# Sasheer Zamata                                NaN
#
#                                            knownForTitles   Time on SNL  \
# John Belushi      tt0078723,tt0072562,tt0077975,tt0080455     1975–1979
# Jim Belushi       tt0097637,tt0072562,tt0117468,tt0095963     1983–1985
# Dana Carvey       tt0072562,tt0108525,tt0105793,tt0295427     1986–1993
# Kevin Nealon      tt0072562,tt0116483,tt0439100,tt0120888     1986–1995
# Fred Armisen      tt0357413,tt1282140,tt0072562,tt1780441     2002–2013
# ...                                                   ...           ...
# Patrick Weathers                                      NaN     1980–1981
# Kristen Wiig                                          NaN     2005–2012
# Casey Wilson                                          NaN     2008–2009
# Bowen Yang                                            NaN  2019–present
# Sasheer Zamata                                        NaN     2014–2017
#
#                   No. of seasons Repertory Player Featured Player  \
# John Belushi                   4              Yes              No
# Jim Belushi                    2              Yes              No
# Dana Carvey                    7              Yes              No
# Kevin Nealon                   9              Yes             Yes
# Fred Armisen                  11              Yes             Yes
# ...                          ...              ...             ...
# Patrick Weathers               1               No             Yes
# Kristen Wiig                   7              Yes             Yes
# Casey Wilson                   2               No             Yes
# Bowen Yang                     3              Yes             Yes
# Sasheer Zamata                 4              Yes             Yes
#
#                  Middle Group "Weekend Update" Anchor Hosted Writer
# John Belushi               No                      No     No    Yes
# Jim Belushi                No                      No     No    Yes
# Dana Carvey                No                      No    Yes    Yes
# Kevin Nealon               No                     Yes     No    Yes
# Fred Armisen               No                      No    Yes     No
# ...                       ...                     ...    ...    ...
# Patrick Weathers           No                      No     No     No
# Kristen Wiig               No                      No    Yes     No
# Casey Wilson               No                      No     No     No
# Bowen Yang                 No                      No     No    Yes
# Sasheer Zamata             No                      No     No     No
#
# [159 rows x 13 columns]

# %% [markdown]
# I am now attempting to create a dictionary of all the cast members and their IMDb "Known For Titles" to create a heatmap to show overlaps. Hopefully that will work but I am still in the process of figuring out how to do this. My plan is the following:
# 1. Use set() to get unique names
# 2. Intialize a dictionary where name is key and value is empty list `(John Belushi:[])` (result.index) LEN==159 values:empty lists
# 3. Loop over imdb data and extract primaryName and use primaryName `human[name].append(row)` where row in imdb
#     - for row in imdb grab primary name -> name variable
#     - `humans[name] += knownForTitles.split(‘,’)`
#     - for human, knownfor in humans.items():
#     - newhumans[human] = set(knownfor)
#     - humans = unique humans with all known for items

# %%
name_titles_dict = {}
keys = cross_name_list
for name in keys:
    name_titles_dict[name] = []

name_titles_dict
# Out:
# {'Brad Hall': [],
#  'Jimmy Fallon': [],
#  'Sarah Sherman': [],
#  'Andy Samberg': [],
#  'Bowen Yang': [],
#  'Lauren Holt': [],
#  "Mike O'Brien": [],
#  'Martin Short': [],
#  'Nora Dunn': [],
#  'Damon Wayans': [],
#  'Ana Gasteyer': [],
#  'Yvonne Hudson': [],
#  "Michael O'Donoghue": [],
#  'Chloe Fineman': [],
#  'Mary Gross': [],
#  'Julia Louis-Dreyfus': [],
#  'Matthew Laurance': [],
#  'Colin Quinn': [],
#  'Jon Lovitz': [],
#  'Christopher Guest': [],
#  'Darrell Hammond': [],
#  'John Milhiser': [],
#  'Will Forte': [],
#  'Molly Shannon': [],
#  'Fred Wolf': [],
#  'Mikey Day': [],
#  'Joe Piscopo': [],
#  'Randy Quaid': [],
#  'Gilbert Gottfried': [],
#  'Don Novello': [],
#  'Mike Myers': [],
#  'Will Ferrell': [],
#  'Paul Shaffer': [],
#  'Dana Carvey': [],
#  'Chris Elliott': [],
#  'Eddie Murphy': [],
#  'Jane Curtin': [],
#  'Seth Meyers': [],
#  'Rob Schneider': [],
#  'Garrett Morris': [],
#  'Ann Risley': [],
#  'Jason Sudeikis': [],
#  'Rich Hall': [],
#  'Cecily Strong': [],
#  'Christine Ebersole': [],
#  'Terry Sweeney': [],
#  'Chris Kattan': [],
#  'Chris Rock': [],
#  'David Koechner': [],
#  'Jerry Minor': [],
#  'Danitra Vance': [],
#  'Al Franken': [],
#  'Jenny Slate': [],
#  'Aristotle Athari': [],
#  'Siobhan Fallon': [],
#  'Jay Pharoah': [],
#  'Finesse Mitchell': [],
#  'Kenan Thompson': [],
#  'Anthony Michael Hall': [],
#  'Fred Armisen': [],
#  'Patrick Weathers': [],
#  'Melissa Villaseñor': [],
#  'Luke Null': [],
#  'Billy Crystal': [],
#  'James Austin Johnson': [],
#  'Dan Vitale': [],
#  'A. Whitney Brown': [],
#  'Kyle Mooney': [],
#  'Laraine Newman': [],
#  'Maya Rudolph': [],
#  'Tom Schiller': [],
#  'Chevy Chase': [],
#  'Kate McKinnon': [],
#  'Cheri Oteri': [],
#  'Dennis Miller': [],
#  'Tim Kazurinsky': [],
#  'David Spade': [],
#  'Noël Wells': [],
#  'Dan Aykroyd': [],
#  'Punkie Johnson': [],
#  'Harry Shearer': [],
#  'Laurie Metcalf': [],
#  'Jim Downey': [],
#  'Chris Parnell': [],
#  'Jim Breuer': [],
#  'Sasheer Zamata': [],
#  'Robert Downey Jr.': [],
#  'Pete Davidson': [],
#  'Jan Hooks': [],
#  'Tina Fey': [],
#  'Janeane Garofalo': [],
#  'Ego Nwodim': [],
#  'Laura Kightlinger': [],
#  'Robert Smigel': [],
#  'Gary Kroeger': [],
#  'Casey Wilson': [],
#  'Sarah Silverman': [],
#  'Beck Bennett': [],
#  'Chris Redd': [],
#  'Joan Cusack': [],
#  'Abby Elliott': [],
#  'Michael McKean': [],
#  'Beth Cahill': [],
#  'Julia Sweeney': [],
#  'Brooks Wheelan': [],
#  'Bobby Moynihan': [],
#  'George Coe': [],
#  'Brian Doyle-Murray': [],
#  'Horatio Sanz': [],
#  'Mark McKinney': [],
#  'Gilda Radner': [],
#  'Kristen Wiig': [],
#  'Tim Meadows': [],
#  'Ellen Cleghorne': [],
#  'Leslie Jones': [],
#  'Rob Riggle': [],
#  'Jim Belushi': [],
#  'Michaela Watkins': [],
#  'Morwenna Banks': [],
#  'Kevin Nealon': [],
#  'Phil Hartman': [],
#  'Adam Sandler': [],
#  'Victoria Jackson': [],
#  'Gail Matthius': [],
#  'Tracy Morgan': [],
#  'Andrew Dismukes': [],
#  'Vanessa Bayer': [],
#  'Tim Robinson': [],
#  'Jon Rudnitsky': [],
#  'Alex Moffat': [],
#  'Charles Rocket': [],
#  'Alan Zweibel': [],
#  'Chris Farley': [],
#  'Jay Mohr': [],
#  'Paul Brittain': [],
#  'Emily Prager': [],
#  'John Belushi': [],
#  'Nasim Pedrad': [],
#  'Aidy Bryant': [],
#  'Denny Dillon': [],
#  'Amy Poehler': [],
#  'Peter Aykroyd': [],
#  'Tom Davis': [],
#  'Tony Rosato': [],
#  'Jeff Richards': [],
#  'Dean Edwards': [],
#  'Ben Stiller': [],
#  'Bill Hader': [],
#  'Bill Murray': [],
#  'Taran Killam': [],
#  'Colin Jost': [],
#  'Rachel Dratch': [],
#  'Melanie Hutsell': [],
#  'Pamela Stephenson': [],
#  'Heidi Gardner': [],
#  'Robin Duke': [],
#  'Michael Che': []}

# %%
names_title_dict = {item[1]:item[5].split(',') for item in SNL_name_check}
names_title_dict
# Out:
# {'John Belushi': ['tt0078723', 'tt0072562', 'tt0077975', 'tt0080455'],
#  'Dan Aykroyd': ['tt0097428', 'tt0118747', 'tt0087332', 'tt0080455'],
#  'Bill Murray': ['tt5156614'],
#  'Mike Myers': ['\\N'],
#  'Chevy Chase': ['tt0085995', 'tt0097958', 'tt0080487', 'tt0092086'],
#  'Billy Crystal': ['tt0101587', 'tt0098635', 'tt0113097', 'tt0122933'],
#  'Joan Cusack': ['tt0119229', 'tt1659337', 'tt0119360', 'tt0096463'],
#  'Robert Downey Jr.': ['tt1300854', 'tt0371746', 'tt4154796', 'tt0988045'],
#  'Chris Farley': ['\\N'],
#  'Janeane Garofalo': ['tt0382932', 'tt0132347', 'tt0117979', 'tt0243655'],
#  'Julia Louis-Dreyfus': ['tt0462128', 'tt1759761', 'tt2390361', 'tt0098904'],
#  'Eddie Murphy': ['tt0492509'],
#  'Jim Belushi': ['tt0097637', 'tt0072562', 'tt0117468', 'tt0095963'],
#  'Dana Carvey': ['tt0072562', 'tt0108525', 'tt0105793', 'tt0295427'],
#  'Adam Sandler': ['tt13689618', 'tt10428498', 'tt0068120', 'tt12116598'],
#  'Christopher Guest': ['tt4334642', 'tt1024855'],
#  'Anthony Michael Hall': ['tt0468569', 'tt2361317', 'tt4758646', 'tt1100089'],
#  'Jon Lovitz': ['tt0104694', 'tt0107659', 'tt0147612', 'tt0437863'],
#  'Jay Mohr': ['tt0116695', 'tt0120241', 'tt0139239', 'tt0180052'],
#  'Randy Quaid': ['tt0097958', 'tt0116629', 'tt0116778', 'tt0388795'],
#  'Chris Rock': ['\\N'],
#  'Rob Schneider': ['tt11239422', 'tt8280446'],
#  'Martin Short': ['tt1791798', 'tt0938980', 'tt5747320', 'tt1297329'],
#  'Ben Stiller': ['tt0196229', 'tt0359950', 'tt0942385', 'tt1608290'],
#  'Damon Wayans': ['tt0110443', 'tt0104897', 'tt0273855', 'tt0102266'],
#  'Christine Ebersole': ['tt0115697', 'tt0993846', 'tt0086879', 'tt0110989'],
#  'Will Ferrell': ['tt5779664'],
#  'Jane Curtin': ['tt0106598', 'tt0115082', 'tt0086742', 'tt1155056'],
#  'Nora Dunn': ['tt0405336', 'tt0910936', 'tt0157503', 'tt0120188'],
#  'Tim Meadows': ['\\N'],
#  'Kevin Nealon': ['tt0072562', 'tt0116483', 'tt0439100', 'tt0120888'],
#  'David Spade': ['tt0245686', 'tt0120917', 'tt0437863', 'tt0114694'],
#  'Fred Armisen': ['tt0357413', 'tt1282140', 'tt0072562', 'tt1780441'],
#  'Peter Aykroyd': ['tt0106598', 'tt0095687', 'tt0090056', 'tt0102558'],
#  'Morwenna Banks': ['tt0760141', 'tt0466664', 'tt2245003', 'tt5839960'],
#  'Jim Breuer': ['tt1222817', 'tt0120693', 'tt0120913', 'tt0144168'],
#  'A. Whitney Brown': ['tt0096708', 'tt0072562', 'tt0166039', 'tt1094991'],
#  'Beth Cahill': ['tt0155764', 'tt0262411', 'tt0164930', 'tt0072562'],
#  'Ellen Cleghorne': ['tt0120591', 'tt0200550', 'tt2126357', 'tt0185431'],
#  'George Coe': ['tt1399103', 'tt0089901', 'tt0073747', 'tt0092666'],
#  'Pete Davidson': ['tt6806604'],
#  'Tom Davis': ['tt7638698'],
#  'Denny Dillon': ['tt0475276', 'tt0098780', 'tt0268380', 'tt0076666'],
#  'Brian Doyle-Murray': ['tt0105793', 'tt0102138', 'tt0080487', 'tt0097958'],
#  'Rachel Dratch': ['tt1564367', 'tt0389860', 'tt0814331', 'tt8169446'],
#  'Robin Duke': ['tt0075578', 'tt0117108', 'tt0107048', 'tt0072562'],
#  'Dean Edwards': ['tt6186672', 'tt0354333', 'tt1565436'],
#  'Chris Elliott': ['\\N'],
#  'Jimmy Fallon': ['tt6133466'],
#  'Tina Fey': ['tt1850457', 'tt0377092', 'tt1279935', 'tt0496424'],
#  'Will Forte': ['tt3230454', 'tt1490017', 'tt1470023', 'tt1821549'],
#  'Al Franken': ['tt0114571', 'tt0368008', 'tt0086465', 'tt0072562'],
#  'Ana Gasteyer': ['tt0207201', 'tt1232200', 'tt4366830', 'tt0377092'],
#  'Gilbert Gottfried': ['tt0103639', 'tt0092644', 'tt0098987', 'tt0100419'],
#  'Mary Gross': ['tt0423652'],
#  'Bill Hader': ['tt1571249', 'tt3152624', 'tt7349950', 'tt2096673'],
#  'Brad Hall': ['tt8106790'],
#  'Rich Hall': ['tt8364112', 'tt7286604'],
#  'Darrell Hammond': ['tt0799949', 'tt0118747', 'tt0306047', 'tt0072562'],
#  'Phil Hartman': ['tt5298646'],
#  'Jan Hooks': ['tt0103776', 'tt0115082', 'tt0106598', 'tt0089791'],
#  'Yvonne Hudson': ['tt2355949'],
#  'Melanie Hutsell': ['tt4789300', 'tt1478338', 'tt0072562', 'tt2191701'],
#  'Victoria Jackson': ['tt0383760'],
#  'Leslie Jones': ['tt7604526'],
#  'Chris Kattan': ['tt0120770', 'tt0279493', 'tt2479478', 'tt0185371'],
#  'Tim Kazurinsky': ['tt0090583', 'tt0089822', 'tt0082801', 'tt0072562'],
#  'Laura Kightlinger': ['tt4116284', 'tt8324422', 'tt0460619', 'tt0157246'],
#  'Taran Killam': ['tt2024544', 'tt0072562', 'tt5689068', 'tt4000956'],
#  'David Koechner': ['tt0425061', 'tt0357413', 'tt0427944', 'tt1229340'],
#  'Gary Kroeger': ['tt0200525', 'tt0072562', 'tt0046593', 'tt0086765'],
#  'Matthew Laurance': ['tt0112111', 'tt0085475', 'tt0098772', 'tt0090060'],
#  'Gail Matthius': ['tt0072562', 'tt0162796', 'tt0083530', 'tt0103373'],
#  'Michael McKean': ['tt0129910'],
#  'Mark McKinney': ['tt2954994'],
#  'Kate McKinnon': ['tt0092225'],
#  'Laurie Metcalf': ['tt0094540', 'tt0120082', 'tt0114709', 'tt4925292'],
#  'Dennis Miller': ['tt3471592'],
#  'Jerry Minor': ['tt0401003'],
#  'Tracy Morgan': ['tt11833964', 'tt3644198'],
#  'Garrett Morris': ['tt0072562', 'tt0478970', 'tt0106598', 'tt0278488'],
#  'Laraine Newman': ['tt0102719', 'tt0106598', 'tt0116705', 'tt0120669'],
#  'Don Novello': ['tt0072562', 'tt0112642', 'tt0099674', 'tt0230011'],
#  "Mike O'Brien": ['tt8554874'],
#  "Michael O'Donoghue": ['tt1715425'],
#  'Cheri Oteri': ['tt0141369', 'tt0175142', 'tt0119528', 'tt0405336'],
#  'Chris Parnell': ['tt7396544'],
#  'Joe Piscopo': ['\\N'],
#  'Amy Poehler': ['tt2096673', 'tt0871426', 'tt1266020', 'tt0072562'],
#  'Emily Prager': ['\\N'],
#  'Colin Quinn': ['\\N'],
#  'Gilda Radner': ['tt0070290', 'tt0091178', 'tt0084049', 'tt0072562'],
#  'Tony Rosato': ['tt0075578', 'tt0117593', 'tt0088582', 'tt0207701'],
#  'Jeff Richards': ['tt6512646'],
#  'Ann Risley': ['tt0072562', 'tt0081554', 'tt0081518', 'tt0082525'],
#  'Tim Robinson': ['tt0112193', 'tt0396362', 'tt0335620', 'tt9090184'],
#  'Harry Shearer': ['tt0120382', 'tt0310281', 'tt0096697', 'tt0088258'],
#  'Charles Rocket': ['tt0120913', 'tt0099348', 'tt0108122', 'tt0109686'],
#  'Maya Rudolph': ['tt1727388', 'tt1176740', 'tt1478338', 'tt1791528'],
#  'Horatio Sanz': ['tt0285462', 'tt1920849', 'tt0215129', 'tt1045778'],
#  'Tom Schiller': ['tt9068272'],
#  'Paul Shaffer': ['tt0088258', 'tt0119282', 'tt0118747', 'tt4537842'],
#  'Molly Shannon': ['tt3675186'],
#  'Sarah Silverman': ['tt0332379', 'tt0821375', 'tt1772341', 'tt5848272'],
#  'Robert Smigel': ['tt0185431', 'tt0072562', 'tt0106052', 'tt0272338'],
#  'Pamela Stephenson': ['tt0080253', 'tt0086393', 'tt0082517', 'tt0199218'],
#  'Jason Sudeikis': ['tt1723121', 'tt10986410', 'tt4680182', 'tt1499658'],
#  'Julia Sweeney': ['\\N'],
#  'Terry Sweeney': ['tt2474812'],
#  'Kenan Thompson': ['tt0417148', 'tt0072562', 'tt0115231', 'tt0119215'],
#  'Danitra Vance': ['tt0098621', 'tt0102316', 'tt0102174', 'tt0086759'],
#  'Dan Vitale': ['tt4656450', 'tt5903450'],
#  'Patrick Weathers': ['tt1741243', 'tt1790886', 'tt1996346', 'tt0094291'],
#  'Casey Wilson': ['tt3263490'],
#  'Fred Wolf': ['tt3910602', 'tt10222674', 'tt0072562'],
#  'Alan Zweibel': ['tt0090459', 'tt0072562', 'tt0092925', 'tt0110687'],
#  'Seth Meyers': ['tt6528132', 'tt0496571'],
#  'Lauren Holt': ['tt8394996', 'tt8937092', 'tt0072562', 'tt7546290'],
#  'Michaela Watkins': ['tt1932718', 'tt1655460', 'tt2294677', 'tt1212436'],
#  'Heidi Gardner': ['\\N'],
#  'Sarah Sherman': ['tt8218988'],
#  'Bobby Moynihan': ['tt13622982', 'tt10662034', 'tt0072562'],
#  'Kristen Wiig': ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249'],
#  'Kyle Mooney': ['tt3823130'],
#  'Rob Riggle': ['tt2096672', 'tt1119646', 'tt0115147', 'tt1232829'],
#  'Finesse Mitchell': ['tt0785077', 'tt0072562', 'tt0951216', 'tt0790804'],
#  'Mikey Day': ['tt0072562', 'tt2076347', 'tt1217217', 'tt4000956'],
#  'Andy Samberg': ['tt0072562', 'tt3960412', 'tt2467372', 'tt9484998'],
#  'Paul Brittain': ['tt0837562', 'tt0072562', 'tt2176287', 'tt2510894'],
#  'Nasim Pedrad': ['tt6139732', 'tt1690953', 'tt10338160', 'tt2490326'],
#  'Colin Jost': ['tt0072562', 'tt1292566', 'tt1361336', 'tt6802400'],
#  'Abby Elliott': ['tt0072562', 'tt1291150', 'tt1663143', 'tt1411238'],
#  'John Milhiser': ['tt0072562', 'tt5990096', 'tt1289401', 'tt4061080'],
#  'Alex Moffat': ['tt6851750'],
#  'Aristotle Athari': ['tt9173436', 'tt5918784', 'tt5917146', 'tt7322648'],
#  'Jenny Slate': ['tt2709768', 'tt2948356', 'tt4481414', 'tt2910274'],
#  'Beck Bennett': ['tt3470600', 'tt7979580', 'tt5531466', 'tt1086064'],
#  'Vanessa Bayer': ['tt0072562', 'tt2989524', 'tt1711525', 'tt3152624'],
#  'Sasheer Zamata': ['tt4018068', 'tt11394332', 'tt4018066', 'tt6791096'],
#  'Noël Wells': ['tt0072562', 'tt7713450', 'tt6212496', 'tt9184820'],
#  'Luke Null': ['tt1545490', 'tt0072562', 'tt9881938', 'tt3146066'],
#  'Melissa Villaseñor': ['tt1809001', 'tt0072562', 'tt5848272', 'tt10682266'],
#  'Michael Che': ['tt0072562', 'tt12762460', 'tt0499556', 'tt2784678'],
#  'Jay Pharoah': ['tt0072562', 'tt5774044', 'tt1408253', 'tt7153766'],
#  'Jon Rudnitsky': ['tt0072562', 'tt5719700'],
#  'James Austin Johnson': ['tt0072562', 'tt8036272', 'tt3032476', 'tt0475290'],
#  'Chloe Fineman': ['tt0072562', 'tt8577458', 'tt6527474', 'tt5460226'],
#  'Ego Nwodim': ['tt6110318', 'tt3598030', 'tt0072562', 'tt7379494'],
#  'Brooks Wheelan': ['tt10050772', 'tt0072562', 'tt1600194', 'tt5244974'],
#  'Cecily Strong': ['tt0072562', 'tt11808942', 'tt2702724', 'tt1289401'],
#  'Aidy Bryant': ['tt5462602', 'tt11092142', 'tt8962130', 'tt0072562'],
#  'Chris Redd': ['tt3960412', 'tt5884792', 'tt7286456', 'tt0072562'],
#  'Jim Downey': ['\\N'],
#  'Bowen Yang': ['tt2587452', 'tt6078096', 'tt2452244'],
#  'Andrew Dismukes': ['tt14508698', 'tt0072562', 'tt13858722', 'tt6279022'],
#  'Siobhan Fallon': ['tt6463510'],
#  'Punkie Johnson': ['tt7242698', 'tt5821764', 'tt5117666', 'tt7778796']}

# %%
# struggling quite a bit to get the unique project IDs
for i in SNL_name_check:
    unique_titles = []
    if i[1]== 'Bill Murray':
        print(set(i))
#     pattern = "[t]{2}[0-9]{7}"
#     regex = re.compile(pattern)
#     for i in regex.findall(SNL_name_check(i)):
#         unique_titles.append(i)
#         print(unique_titles)
# Out:
# {'Bill Murray', 'tt1748122,tt0128445,tt0362270,tt0335266', '\\N', 'nm0000195', '1950', 'actor,soundtrack,writer'}
# {'Bill Murray', '\\N', 'miscellaneous', 'nm0614853', 'tt0097132'}
# {'Bill Murray', '\\N', 'actor', 'nm10343807', 'tt6384192,tt13998382'}
# {'Bill Murray', 'camera_department', '\\N', 'nm1162741', 'tt0288154,tt0189500'}
# {'Bill Murray', nan, 'nm12931864', '\\N'}
# {'Bill Murray', '\\N', 'actor', 'nm1386521', 'tt0351810'}
# {'Bill Murray', 'tt0448004', '\\N', 'cinematographer', 'nm1831668'}
# {'nm1907457', 'actor,writer', 'Bill Murray', '\\N', 'tt0457251,tt0961721'}
# {'Bill Murray', 'tt0122145', '\\N', 'actor', 'nm1981812'}
# {'Bill Murray', nan, '\\N', 'tt0281438', 'nm2018971'}
# {'Bill Murray', 'nm2966932', '\\N', 'tt1732762,tt1210095', 'editor,editorial_department'}
# {'Bill Murray', '\\N', 'nm3578809', 'tt1490534', 'producer'}
# {'nm3673242', nan, 'Bill Murray', '1986', '1908', 'tt1687207,tt1600694,tt1538443'}
# {'Bill Murray', nan, 'nm3890281', '\\N'}
# {'Bill Murray', 'nm4257796', '\\N', 'tt1810727', 'actor'}
# {'Bill Murray', nan, '\\N', 'nm4289813', 'tt1740656'}
# {'Bill Murray', 'nm4310690', '\\N', 'sound_department,art_department,camera_department', 'tt2147467,tt1837678'}
# {'Bill Murray', '\\N', 'actor', 'nm4435047', 'tt1911645,tt2450652,tt2282941'}
# {'Bill Murray', '\\N', 'actor', 'tt1884251', 'nm4481414'}
# {'Bill Murray', '\\N', 'nm4520392', 'tt1972582', 'cinematographer,camera_department'}
# {'Bill Murray', 'art_department', '\\N', 'nm4826405', 'tt2147467'}
# {'Bill Murray', '\\N', 'tt2202391', 'actor', 'nm4926467'}
# {'Bill Murray', '\\N', 'nm5139377', 'sound_department', 'tt2243836'}
# {'Bill Murray', 'nm5230632', '\\N', 'sound_department', 'tt2356940'}
# {'Bill Murray', nan, '\\N', 'nm5629957'}
# {'Bill Murray', nan, 'nm5872054', '\\N'}
# {'nm5894755', 'Bill Murray', '\\N', 'tt3091734', 'actor'}
# {'Bill Murray', 'tt3147486', 'nm5905712', '\\N', 'actor'}
# {'Bill Murray', '\\N', 'nm5987491', 'actor', 'tt3231836'}
# {'Bill Murray', '\\N', 'editor', 'tt0115367', 'nm6344885'}
# {'Bill Murray', '\\N', 'tt3603706', 'nm6365877', 'director'}
# {'Bill Murray', nan, 'nm6695372', '\\N'}
# {'nm6908017', 'Bill Murray', '\\N', 'tt3790306', 'actor'}
# {'Bill Murray', 'nm7234377', '\\N', 'tt4571940', 'writer'}
# {'Bill Murray', nan, '\\N', 'nm8271258', 'tt5156614'}

# %% [markdown]
# `import pygraphviz as pgv
#
# G = pgv.AGraph(edges,
#                strict=True,
#                directed=True,
#                rankdir="RL",
#                ranksep="0.25",
#                ordering="in")
#
# G.layout('dot')
#
# G.draw('curr.png')
#
# G.draw('curr.svg')`

# %%
type(SNL_name_check)
# Out:
# list

# %%
for i in (SNL_name_check):
    unique_titles = []
    for x in i:
        if str(x).startswith('tt'):
            tt = x.split(',')
            for title in tt:
                if title not in unique_titles:
                    unique_titles.append(title)
            for name in names_title_dict:
                if i[1] == name:
                    names_title_dict[name].append(unique_titles)

#                     print(i[1],unique_titles)

# %%
names_title_dict
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5y/htsjngjd7nd_3ddqv2q24ynh0000gq/T/ipykernel_42719/892567171.py in <module>
# ----> 1 print(names_title_dict)
#
# KeyboardInterrupt:

# %%
for i in (SNL_name_check):
    unique_titles = []
    for x in i:
        for name in names_title_dict:
            if str(x).startswith('tt'):
                tt = str(x).split(',')
#                 print(tt)
                if i[1] == name:
                    unique_titles.append(tt)
                    names_title_dict.update({i[1]:unique_titles})

                    print(i[1],unique_titles)
#                 print(unique_titles)
# Out:
# John Belushi [['tt0078723', 'tt0072562', 'tt0077975', 'tt0080455']]
# Dan Aykroyd [['tt0097428', 'tt0118747', 'tt0087332', 'tt0080455']]
# Bill Murray [['tt1748122', 'tt0128445', 'tt0362270', 'tt0335266']]
# Mike Myers [['tt0295178', 'tt0145660', 'tt0118655', 'tt0811138']]
# Chevy Chase [['tt0085995', 'tt0097958', 'tt0080487', 'tt0092086']]
# Billy Crystal [['tt0101587', 'tt0098635', 'tt0113097', 'tt0122933']]
# Joan Cusack [['tt0119229', 'tt1659337', 'tt0119360', 'tt0096463']]
# Robert Downey Jr. [['tt1300854', 'tt0371746', 'tt4154796', 'tt0988045']]
# Chris Farley [['tt0118708', 'tt0115697', 'tt0114694', 'tt0106598']]
# Janeane Garofalo [['tt0382932', 'tt0132347', 'tt0117979', 'tt0243655']]
# Julia Louis-Dreyfus [['tt0462128', 'tt1759761', 'tt2390361', 'tt0098904']]
# Eddie Murphy [['tt0117218', 'tt0443489', 'tt0094898', 'tt0126029']]
# Jim Belushi [['tt0097637', 'tt0072562', 'tt0117468', 'tt0095963']]
# Dana Carvey [['tt0072562', 'tt0108525', 'tt0105793', 'tt0295427']]
# Adam Sandler [['tt0120484', 'tt0120888', 'tt0142342', 'tt0185431']]
# Christopher Guest [['tt0218839', 'tt0310281', 'tt0088258', 'tt0118111']]
# Anthony Michael Hall [['tt0468569', 'tt2361317', 'tt4758646', 'tt1100089']]
# Jon Lovitz [['tt0104694', 'tt0107659', 'tt0147612', 'tt0437863']]
# Jay Mohr [['tt0116695', 'tt0120241', 'tt0139239', 'tt0180052']]
# Randy Quaid [['tt0097958', 'tt0116629', 'tt0116778', 'tt0388795']]
# Chris Rock [['tt2784678', 'tt0325537', 'tt0398165', 'tt0351283']]
# Rob Schneider [['tt0255798', 'tt0302640', 'tt0367652', 'tt0205000']]
# Martin Short [['tt0093260', 'tt0452681', 'tt0092086', 'tt1791528']]
# Ben Stiller [['tt0196229', 'tt0359950', 'tt0942385', 'tt1608290']]
# Damon Wayans [['tt0110443', 'tt0104897', 'tt0273855', 'tt0102266']]
# Christine Ebersole [['tt0115697', 'tt0993846', 'tt0086879', 'tt0110989']]
# Will Ferrell [['tt0357413', 'tt0445934', 'tt1229340', 'tt0415306']]
# Jane Curtin [['tt0106598', 'tt0115082', 'tt0086742', 'tt1155056']]
# Nora Dunn [['tt0405336', 'tt0910936', 'tt0157503', 'tt0120188']]
# Tim Meadows [['tt0841046', 'tt0377092', 'tt3960412', 'tt0213790']]
# Kevin Nealon [['tt0072562', 'tt0116483', 'tt0439100', 'tt0120888']]
# David Spade [['tt0245686', 'tt0120917', 'tt0437863', 'tt0114694']]
# Fred Armisen [['tt0357413', 'tt1282140', 'tt0072562', 'tt1780441']]
# Peter Aykroyd [['tt0106598', 'tt0095687', 'tt0090056', 'tt0102558']]
# Morwenna Banks [['tt0760141', 'tt0466664', 'tt2245003', 'tt5839960']]
# Jim Breuer [['tt1222817', 'tt0120693', 'tt0120913', 'tt0144168']]
# A. Whitney Brown [['tt0096708', 'tt0072562', 'tt0166039', 'tt1094991']]
# Beth Cahill [['tt0155764', 'tt0262411', 'tt0164930', 'tt0072562']]
# Ellen Cleghorne [['tt0120591', 'tt0200550', 'tt2126357', 'tt0185431']]
# George Coe [['tt1399103', 'tt0089901', 'tt0073747', 'tt0092666']]
# Pete Davidson [['tt9686708', 'tt5304992', 'tt0800325', 'tt6334354']]
# Tom Davis [['tt0086465', 'tt0251075', 'tt0106598', 'tt0072562']]
# Tom Davis [['tt0120241', 'tt0100613', 'tt0803033', 'tt0087998']]
# Tom Davis [['tt0124718', 'tt0463970']]
# Tom Davis [['tt0118632']]
# Denny Dillon [['tt0475276', 'tt0098780', 'tt0268380', 'tt0076666']]
# Brian Doyle-Murray [['tt0105793', 'tt0102138', 'tt0080487', 'tt0097958']]
# Rachel Dratch [['tt1564367', 'tt0389860', 'tt0814331', 'tt8169446']]
# Robin Duke [['tt0075578', 'tt0117108', 'tt0107048', 'tt0072562']]
# Dean Edwards [['tt0910898', 'tt2784678', 'tt0421143', 'tt0413300']]
# Chris Elliott [['tt0107048', 'tt0109361', 'tt0129387', 'tt0096754']]
# Chris Elliott [['tt0103873', 'tt0834001', 'tt0110311', 'tt0107822']]
# Chris Elliott [['tt0222820']]
# Jimmy Fallon [['tt3444938', 'tt1231460', 'tt0332047', 'tt0316732']]
# Tina Fey [['tt1850457', 'tt0377092', 'tt1279935', 'tt0496424']]
# Will Forte [['tt3230454', 'tt1490017', 'tt1470023', 'tt1821549']]
# Al Franken [['tt0114571', 'tt0368008', 'tt0086465', 'tt0072562']]
# Ana Gasteyer [['tt0207201', 'tt1232200', 'tt4366830', 'tt0377092']]
# Gilbert Gottfried [['tt0103639', 'tt0092644', 'tt0098987', 'tt0100419']]
# Mary Gross [['tt0120791', 'tt0243736', 'tt0094846', 'tt0072562']]
# Bill Hader [['tt1571249', 'tt3152624', 'tt7349950', 'tt2096673']]
# Brad Hall [['tt0120623', 'tt2080359', 'tt6388738', 'tt0101055']]
# Brad Hall [['tt0109830', 'tt0120399', 'tt0120829']]
# Brad Hall [['tt2468756', 'tt0800142', 'tt8793210', 'tt2953706']]
# Rich Hall [['tt0072562', 'tt0325939', 'tt0085065', 'tt1430607']]
# Darrell Hammond [['tt0799949', 'tt0118747', 'tt0306047', 'tt0072562']]
# Phil Hartman [['tt0122718', 'tt0108174', 'tt0116705', 'tt0112095']]
# Jan Hooks [['tt0103776', 'tt0115082', 'tt0106598', 'tt0089791']]
# Yvonne Hudson [['tt0277167', 'tt0072562']]
# Melanie Hutsell [['tt4789300', 'tt1478338', 'tt0072562', 'tt2191701']]
# Victoria Jackson [['tt1394227', 'tt0098546', 'tt0099819', 'tt0094846']]
# Leslie Jones [['tt0272338', 'tt1791528', 'tt1560747', 'tt0120863']]
# Leslie Jones [['tt0072562', 'tt6802400', 'tt1289401', 'tt2461150']]
# Leslie Jones [['tt0116442']]
# Leslie Jones [['tt0113492', 'tt0180073', 'tt0773756', 'tt0120738']]
# Leslie Jones [['tt0094643']]
# Chris Kattan [['tt0120770', 'tt0279493', 'tt2479478', 'tt0185371']]
# Tim Kazurinsky [['tt0090583', 'tt0089822', 'tt0082801', 'tt0072562']]
# Laura Kightlinger [['tt4116284', 'tt8324422', 'tt0460619', 'tt0157246']]
# Taran Killam [['tt2024544', 'tt0072562', 'tt5689068', 'tt4000956']]
# David Koechner [['tt0425061', 'tt0357413', 'tt0427944', 'tt1229340']]
# Gary Kroeger [['tt0200525', 'tt0072562', 'tt0046593', 'tt0086765']]
# Matthew Laurance [['tt0112111', 'tt0085475', 'tt0098772', 'tt0090060']]
# Gail Matthius [['tt0072562', 'tt0162796', 'tt0083530', 'tt0103373']]
# Michael McKean [['tt0088258', 'tt0088930', 'tt0310281', 'tt3032476']]
# Mark McKinney [['tt0387779', 'tt0096626', 'tt0120770', 'tt1159996']]
# Mark McKinney [['tt0277370', 'tt1212450', 'tt0107927', 'tt1731701']]
# Kate McKinnon [['tt4799050', 'tt0072562', 'tt6394270', 'tt1289401']]
# Laurie Metcalf [['tt0094540', 'tt0120082', 'tt0114709', 'tt4925292']]
# Dennis Miller [['tt0113957', 'tt0245686', 'tt0119731', 'tt0117826']]
# Dennis Miller [['tt0385463', 'tt0081561', 'tt0108709', 'tt0135848']]
# Dennis Miller [['tt0226416', 'tt0072792', 'tt0279429', 'tt0081563']]
# Jerry Minor [['tt2463288', 'tt0817538', 'tt0323633', 'tt0357413']]
# Tracy Morgan [['tt0074377', 'tt0074621', 'tt0069098', 'tt0068892']]
# Tracy Morgan [['tt0496424', 'tt0787474', 'tt1385867', 'tt0426592']]
# Garrett Morris [['tt0072562', 'tt0478970', 'tt0106598', 'tt0278488']]
# Bill Murray [['tt0097132']]
# Laraine Newman [['tt0102719', 'tt0106598', 'tt0116705', 'tt0120669']]
# Don Novello [['tt0072562', 'tt0112642', 'tt0099674', 'tt0230011']]
# Mike O'Brien [['tt0159876', 'tt0340434', 'tt0127341', 'tt0153362']]
# Mike O'Brien [['tt0094834', 'tt0117652', 'tt0110939', 'tt0109021']]
# Mike O'Brien [['tt2347497', 'tt1159996', 'tt1095174', 'tt0433400']]
# Michael O'Donoghue [['tt0096061', 'tt0079583', 'tt0079522', 'tt0072562']]
# Cheri Oteri [['tt0141369', 'tt0175142', 'tt0119528', 'tt0405336']]
# Chris Parnell [['tt0357413', 'tt2861424', 'tt0841046', 'tt1232829']]
# Joe Piscopo [['tt0092226', 'tt0072562', 'tt0094961', 'tt0087507']]
# Amy Poehler [['tt2096673', 'tt0871426', 'tt1266020', 'tt0072562']]
# Emily Prager [['tt0048860', 'tt0094674', 'tt0079583', 'tt0059992']]
# Colin Quinn [['tt3152624', 'tt3314416', 'tt1375670', 'tt0120770']]
# Gilda Radner [['tt0070290', 'tt0091178', 'tt0084049', 'tt0072562']]
# Tony Rosato [['tt0075578', 'tt0117593', 'tt0088582', 'tt0207701']]
# Jeff Richards [['tt0049578', 'tt0052932', 'tt0047472', 'tt0050327']]
# Jeff Richards [['tt0104254', 'tt0120800', 'tt0111333', 'tt0094449']]
# Jeff Richards [['tt0759475', 'tt0468999', 'tt4687632', 'tt0072562']]
# Jeff Richards [['tt0162349', 'tt0076781', 'tt0087348', 'tt0090631']]
# Ann Risley [['tt0072562', 'tt0081554', 'tt0081518', 'tt0082525']]
# Tim Robinson [['tt0088591', 'tt0834001', 'tt4698684', 'tt0443334']]
# Harry Shearer [['tt0120382', 'tt0310281', 'tt0096697', 'tt0088258']]
# Chris Rock [['tt0284126', 'tt9372772', 'tt0142646', 'tt0286159']]
# Charles Rocket [['tt0120913', 'tt0099348', 'tt0108122', 'tt0109686']]
# Maya Rudolph [['tt1727388', 'tt1176740', 'tt1478338', 'tt1791528']]
# Horatio Sanz [['tt0285462', 'tt1920849', 'tt0215129', 'tt1045778']]
# Tom Schiller [['tt0087817', 'tt0072562', 'tt3677742', 'tt0304046']]
# Paul Shaffer [['tt0088258', 'tt0119282', 'tt0118747', 'tt4537842']]
# Molly Shannon [['tt0362120', 'tt0167427', 'tt0151738', 'tt4158876']]
# Sarah Silverman [['tt0332379', 'tt0821375', 'tt1772341', 'tt5848272']]
# Robert Smigel [['tt0185431', 'tt0072562', 'tt0106052', 'tt0272338']]
# Pamela Stephenson [['tt0080253', 'tt0086393', 'tt0082517', 'tt0199218']]
# Jason Sudeikis [['tt1723121', 'tt10986410', 'tt4680182', 'tt1499658']]
# Julia Sweeney [['tt2467372', 'tt0498994', 'tt8962130', 'tt10417836']]
# Terry Sweeney [['tt0240596', 'tt0098300', 'tt0342139', 'tt0093443']]
# Kenan Thompson [['tt0417148', 'tt0072562', 'tt0115231', 'tt0119215']]
# Danitra Vance [['tt0098621', 'tt0102316', 'tt0102174', 'tt0086759']]
# Dan Vitale [['tt0088804', 'tt0086768', 'tt1744760', 'tt0072562']]
# Patrick Weathers [['tt1741243', 'tt1790886', 'tt1996346', 'tt0094291']]
# Casey Wilson [['tt0102034', 'tt0120611', 'tt0107415', 'tt0274164']]
# Fred Wolf [['tt0061421', 'tt0092345', 'tt0131613', 'tt0067595']]
# Fred Wolf [['tt0115697', 'tt0120654', 'tt2191701', 'tt0185431']]
# Fred Wolf [['tt2157952', 'tt0154574']]
# Alan Zweibel [['tt0090459', 'tt0072562', 'tt0092925', 'tt0110687']]
# Chris Elliott [['tt1167638', 'tt0120662', 'tt0118661', 'tt0203009']]
# Rich Hall [['tt0861361']]
# Jeff Richards [['tt0076598']]
# Tom Davis [['tt8948614']]
# Mike O'Brien [['tt3562462']]
# Colin Quinn [['tt8819940']]
# Seth Meyers [['tt1598822', 'tt4677934', 'tt0072562', 'tt3513388']]
# Chris Parnell [['tt0265736']]
# Dean Edwards [['tt0450852', 'tt0258476', 'tt1165357', 'tt1111291']]
# Bill Murray [['tt6384192', 'tt13998382']]
# Tom Davis [['tt9639868']]
# Dean Edwards [['tt3644198']]
# Mike O'Brien [['tt9734382', 'tt9883024']]
# Leslie Jones [['tt0123965']]
# Tom Davis [['tt0295476']]
# Brad Hall [['tt0294941']]
# Mike O'Brien [['tt1716744', 'tt1448500', 'tt7498020', 'tt0217061']]
# Tim Meadows [['tt10740136', 'tt13743066', 'tt10863916', 'tt14016930']]
# Tom Davis [['tt12649418']]
# Dennis Miller [['tt10974848']]
# Mike O'Brien [['tt11348726']]
# Tom Davis [['tt11137268']]
# Casey Wilson [['tt11475900']]
# Will Ferrell [['tt11462908']]
# Mike O'Brien [['tt11599804']]
# Mike O'Brien [['tt11394180']]
# Chris Farley [['tt1972591']]
# Michael O'Donoghue [['tt12003714']]
# Michaela Watkins [['tt1932718', 'tt1655460', 'tt2294677', 'tt1212436']]
# Tom Davis [['tt1020913']]
# Jeff Richards [['tt0116783']]
# Jerry Minor [['tt0401003']]
# Bill Murray [['tt0288154', 'tt0189500']]
# Jeff Richards [['tt11011652']]
# Mike O'Brien [['tt12661304']]
# Mike O'Brien [['tt3783812']]
# Martin Short [['tt12800308']]
# Tom Davis [['tt5295032']]
# Tim Robinson [['tt10505762']]
# Dennis Miller [['tt0325502']]
# Mike O'Brien [['tt14643040']]
# Eddie Murphy [['tt0830515', 'tt10539608', 'tt2802144', 'tt2527336']]
# Chris Elliott [['tt13026762']]
# Brad Hall [['tt1442550']]
# Tom Davis [['tt0262152', 'tt13471320']]
# Dan Vitale [['tt14236360']]
# Tim Meadows [['tt11394158']]
# Mike O'Brien [['tt14643040']]
# Tom Davis [['tt13682176']]
# Rob Schneider [['tt4829936']]
# Victoria Jackson [['tt6932494']]
# Victoria Jackson [['tt14855722']]
# Tom Davis [['tt0124718']]
# Jimmy Fallon [['tt6133466']]
# Victoria Jackson [['tt14894996']]
# Leslie Jones [['tt0341708']]
# Chris Farley [['tt14779558', 'tt16589596']]
# Bobby Moynihan [['tt13622982', 'tt10662034', 'tt0072562']]
# Leslie Jones [['tt8579674']]
# Casey Wilson [['tt15488832']]
# Mike O'Brien [['tt15669416']]
# Mike Myers [['tt15714650']]
# Kristen Wiig [['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']]
# Brad Hall [['tt13639450', 'tt12747694']]
# Leslie Jones [['tt0444631', 'tt0357577']]
# Victoria Jackson [['tt15659704']]
# Tim Robinson [['tt18546600']]
# Kyle Mooney [['tt18764878']]
# Tim Robinson [['tt6168110']]
# Bill Murray [['tt0351810']]
# Tim Robinson [['tt0968732', 'tt0775402', 'tt3558296', 'tt1715425']]
# Tracy Morgan [['tt1173421']]
# Rob Riggle [['tt2096672', 'tt1119646', 'tt0115147', 'tt1232829']]
# Finesse Mitchell [['tt0785077', 'tt0072562', 'tt0951216', 'tt0790804']]
# Rich Hall [['tt1517640', 'tt1330618', 'tt0108709']]
# Mikey Day [['tt0072562', 'tt2076347', 'tt1217217', 'tt4000956']]
# Mike O'Brien [['tt1387418', 'tt1730767', 'tt0398291']]
# Adam Sandler [['tt13689618', 'tt10428498', 'tt0068120', 'tt12116598']]
# Chris Elliott [['tt0399977', 'tt0412109', 'tt6261554', 'tt0338616']]
# Andy Samberg [['tt0072562', 'tt3960412', 'tt2467372', 'tt9484998']]
# Paul Brittain [['tt0413660']]
# Chris Rock [['tt0382992', 'tt0317705', 'tt0198781']]
# Christopher Guest [['tt0040053']]
# Mike Myers [['tt0476931', 'tt1020929', 'tt2140691', 'tt1045847']]
# Chris Rock [['tt0434026']]
# Tom Davis [['tt0439911']]
# Tim Robinson [['tt0083731']]
# Bill Murray [['tt0448004']]
# Nasim Pedrad [['tt6139732', 'tt1690953', 'tt10338160', 'tt2490326']]
# Jeff Richards [['tt1877853', 'tt0904115']]
# Victoria Jackson [['tt6769236', 'tt5941780', 'tt10483744', 'tt0455841']]
# Colin Jost [['tt0072562', 'tt1292566', 'tt1361336', 'tt6802400']]
# Bill Murray [['tt0457251', 'tt0961721']]
# Mike O'Brien [['tt0120841']]
# Tom Davis [['tt4276112', 'tt2062966', 'tt1215983', 'tt0789775']]
# Casey Wilson [['tt0457394']]
# Tim Robinson [['tt0105986']]
# Tim Robinson [['tt0483776', 'tt5786442', 'tt1309181', 'tt0484257']]
# Bill Murray [['tt0122145']]
# Casey Wilson [['tt0901476', 'tt1509788', 'tt1103153', 'tt2267998']]
# Bill Murray [['tt0281438']]
# Christopher Guest [['tt12716280', 'tt10538562', 'tt1822842', 'tt8022434']]
# Leslie Jones [['tt0106179', 'tt0120901', 'tt0242733', 'tt0204993']]
# Victoria Jackson [['tt1334555']]
# Tim Robinson [['tt0497043']]
# Dean Edwards [['tt0482481', 'tt2551436', 'tt0354333', 'tt1529670']]
# Phil Hartman [['tt2417108', 'tt0844479', 'tt0409182']]
# Mike Myers [['tt0079945']]
# Tom Davis [['tt0787424', 'tt0496360', 'tt9822404', 'tt0123338']]
# Abby Elliott [['tt0072562', 'tt1291150', 'tt1663143', 'tt1411238']]
# Tom Davis [['tt0458339', 'tt3748528', 'tt0816711', 'tt1446714']]
# Tom Davis [['tt1474200', 'tt0770745', 'tt0882741']]
# Chris Elliott [['tt0861343']]
# Tim Robinson [['tt0803030', 'tt0818620', 'tt0758745', 'tt0427848']]
# Tom Davis [['tt0494235']]
# John Milhiser [['tt0072562', 'tt5990096', 'tt1289401', 'tt4061080']]
# Mike O'Brien [['tt4397866', 'tt1636189', 'tt1636331', 'tt0181269']]
# Michael O'Donoghue [['tt1642373', 'tt1811323', 'tt0840371']]
# Dennis Miller [['tt0119277']]
# Chris Elliott [['tt0972846']]
# Michael McKean [['tt0129910']]
# Tim Robinson [['tt0382382']]
# Jeff Richards [['tt0368257']]
# Mike O'Brien [['tt0238304', 'tt0238305', 'tt0238303', 'tt0104512']]
# Dean Edwards [['tt14773254', 'tt13645690', 'tt12058768', 'tt0298674']]
# Mike Myers [['tt0115279']]
# Tom Davis [['tt6306064', 'tt0095408']]
# Mike O'Brien [['tt0457433', 'tt0470023', 'tt1107855', 'tt0464041']]
# Chris Elliott [['tt3765728', 'tt1242542']]
# Sarah Sherman [['tt1006983', 'tt3773358', 'tt14945492', 'tt9170758']]
# Tom Davis [['tt1272878', 'tt0765010', 'tt0452625', 'tt0457572']]
# Mike O'Brien [['tt0949671']]
# Lauren Holt [['tt1022605', 'tt3449322', 'tt0815250']]
# Dennis Miller [['tt0846694', 'tt0416779']]
# Tom Davis [['tt0349903']]
# Rob Schneider [['tt1039621']]
# Fred Wolf [['tt1032874']]
# Alex Moffat [['tt0112230', 'tt0111999']]
# Dennis Miller [['tt0874300', 'tt1751105', 'tt3529198', 'tt8651594']]
# Chris Parnell [['tt1020109', 'tt0343316']]
# Michael O'Donoghue [['tt0099566']]
# Aristotle Athari [['tt9173436', 'tt5918784', 'tt5917146', 'tt7322648']]
# Tim Robinson [['tt2421910', 'tt1112661']]
# Jenny Slate [['tt2709768', 'tt2948356', 'tt4481414', 'tt2910274']]
# Tom Davis [['tt1136478', 'tt2787132']]
# Mike O'Brien [['tt2719804', 'tt1357005', 'tt1100051']]
# Tom Davis [['tt0106137']]
# Tom Davis [['tt0086192']]
# Michael O'Donoghue [['tt0133302', 'tt1626811', 'tt0115355', 'tt0120801']]
# Bill Murray [['tt1732762', 'tt1210095']]
# Brad Hall [['tt0400410', 'tt0939564']]
# Martin Short [['tt0079687']]
# Kate McKinnon [['tt0092225']]
# Mike O'Brien [['tt0051297']]
# Tom Davis [['tt1250756']]
# Mike O'Brien [['tt4229954', 'tt0775529', 'tt0494864']]
# Beck Bennett [['tt3470600', 'tt7979580', 'tt5531466', 'tt1086064']]
# Leslie Jones [['tt0031055']]
# Mike O'Brien [['tt1366945', 'tt1107855', 'tt2182211', 'tt0313038']]
# Jeff Richards [['tt0393274']]
# Mike O'Brien [['tt1584933', 'tt0401759', 'tt9248866', 'tt0368107']]
# Mike O'Brien [['tt1326172']]
# Chris Rock [['tt0174392']]
# Mike Myers [['tt1362049']]
# Kyle Mooney [['tt15977708', 'tt2139555', 'tt1608290', 'tt5805752']]
# Vanessa Bayer [['tt0072562', 'tt2989524', 'tt1711525', 'tt3152624']]
# Leslie Jones [['tt1279966']]
# Tom Davis [['tt0128707']]
# Tim Robinson [['tt1462862', 'tt1507979', 'tt1462856']]
# Sasheer Zamata [['tt4018068', 'tt11394332', 'tt4018066', 'tt6791096']]
# Bill Murray [['tt1490534']]
# Jeff Richards [['tt1587314', 'tt1505388']]
# Mike O'Brien [['tt1493558']]
# Noël Wells [['tt0072562', 'tt7713450', 'tt6212496', 'tt9184820']]
# Bill Murray [['tt1687207', 'tt1600694', 'tt1538443']]
# Jeff Richards [['tt0072265']]
# Rich Hall [['tt1542770']]
# Chris Elliott [['tt1551638']]
# Tom Davis [['tt1517228']]
# Casey Wilson [['tt2265215', 'tt1982864', 'tt1565981', 'tt2382015']]
# Leslie Jones [['tt1575557']]
# Luke Null [['tt1545490', 'tt0072562', 'tt9881938', 'tt3146066']]
# Melissa Villaseñor [['tt1809001', 'tt0072562', 'tt5848272', 'tt10682266']]
# Michael Che [['tt0072562', 'tt12762460', 'tt0499556', 'tt2784678']]
# Tom Davis [['tt1326139']]
# Jeff Richards [['tt0380060']]
# Chris Rock [['tt1556078']]
# Mike O'Brien [['tt1193138']]
# Casey Wilson [['tt6091368', 'tt2445666', 'tt6083648', 'tt9748306']]
# Tim Robinson [['tt0389911', 'tt1663232', 'tt4502270', 'tt4504130']]
# Tim Robinson [['tt1664843']]
# Dennis Miller [['tt0829176']]
# Casey Wilson [['tt1687906']]
# Jay Pharoah [['tt0072562', 'tt5774044', 'tt1408253', 'tt7153766']]
# Michael O'Donoghue [['tt2790032', 'tt2790152', 'tt2798906']]
# Mike Myers [['tt0096563']]
# Mike Myers [['tt1708468']]
# Sarah Sherman [['tt1518327']]
# Chris Elliott [['tt0262152']]
# Tim Robinson [['tt1777032']]
# Tim Robinson [['tt10050772', 'tt6343706', 'tt4779762', 'tt0072562']]
# Paul Brittain [['tt0837562', 'tt0072562', 'tt2176287', 'tt2510894']]
# Martin Short [['tt1791798', 'tt0938980', 'tt5747320', 'tt1297329']]
# Chris Elliott [['tt1493151', 'tt1813516']]
# Bill Murray [['tt1810727']]
# Tom Davis [['tt4468740', 'tt4158096', 'tt4673856', 'tt8096690']]
# Bill Murray [['tt1740656']]
# Bill Murray [['tt2147467', 'tt1837678']]
# Eddie Murphy [['tt0492509']]
# Jon Rudnitsky [['tt0072562', 'tt5719700']]
# Tom Davis [['tt1850339']]
# Tim Robinson [['tt1857742']]
# Mike Myers [['tt5657856', 'tt1817273', 'tt6133466', 'tt1219289']]
# Mike O'Brien [['tt1885305']]
# Bill Murray [['tt1911645', 'tt2450652', 'tt2282941']]
# Mike O'Brien [['tt1434435']]
# Bill Murray [['tt1884251']]
# Casey Wilson [['tt1951191']]
# Bill Murray [['tt1972582']]
# Casey Wilson [['tt1982864']]
# Mike Myers [['tt1984991']]
# James Austin Johnson [['tt0072562', 'tt8036272', 'tt3032476', 'tt0475290']]
# Sarah Sherman [['tt1999871']]
# Yvonne Hudson [['tt2033480', 'tt3526474', 'tt2142935', 'tt2156935']]
# Tracy Morgan [['tt1887882']]
# Mike O'Brien [['tt2043951']]
# Mike Myers [['tt2004334']]
# Tom Davis [['tt0321473']]
# Mike O'Brien [['tt1170243']]
# Chloe Fineman [['tt0072562', 'tt8577458', 'tt6527474', 'tt5460226']]
# Bill Murray [['tt2147467']]
# Tom Davis [['tt2288153', 'tt0189246', 'tt0081857', 'tt2161907']]
# Rich Hall [['tt0146386']]
# Mike O'Brien [['tt2247021']]
# Bill Murray [['tt2202391']]
# Tim Robinson [['tt2275949']]
# Chris Farley [['tt2275913']]
# Ego Nwodim [['tt6110318', 'tt3598030', 'tt0072562', 'tt7379494']]
# Mike O'Brien [['tt2300919']]
# Leslie Jones [['tt0104423']]
# Yvonne Hudson [['tt2355949']]
# Tracy Morgan [['tt0063892']]
# Brooks Wheelan [['tt10050772', 'tt0072562', 'tt1600194', 'tt5244974']]
# Terry Sweeney [['tt2386353', 'tt2576688', 'tt3313760', 'tt3517306']]
# Bill Murray [['tt2243836']]
# Dennis Miller [['tt1275472']]
# Cecily Strong [['tt0072562', 'tt11808942', 'tt2702724', 'tt1289401']]
# Chris Farley [['tt2328612']]
# Bill Murray [['tt2356940']]
# Jeff Richards [['tt3218622', 'tt5648234', 'tt2378652', 'tt11940818']]
# Aidy Bryant [['tt5462602', 'tt11092142', 'tt8962130', 'tt0072562']]
# Leslie Jones [['tt0297607', 'tt0360255', 'tt0358809', 'tt4568496']]
# Mike O'Brien [['tt2423776']]
# Tom Schiller [['tt9068272']]
# Leslie Jones [['tt1957867']]
# Terry Sweeney [['tt2474812']]
# Rich Hall [['tt1650554']]
# Chris Redd [['tt3960412', 'tt5884792', 'tt7286456', 'tt0072562']]
# Tim Robinson [['tt2582038']]
# Mike O'Brien [['tt2625536']]
# Rich Hall [['tt2369573']]
# Seth Meyers [['tt0124932']]
# Jeff Richards [['tt2671586']]
# Victoria Jackson [['tt2307673']]
# Tom Davis [['tt2728770']]
# Mike Myers [['tt0299712']]
# Leslie Jones [['tt2803888']]
# Sarah Sherman [['tt2803096']]
# Sarah Sherman [['tt2261238']]
# Tom Davis [['tt4742812', 'tt2828570', 'tt3503754', 'tt5774598']]
# Dennis Miller [['tt2866916']]
# Brad Hall [['tt0122827']]
# Dennis Miller [['tt0123338']]
# Mike O'Brien [['tt3856408', 'tt3972208', 'tt1535977']]
# Mike Myers [['tt2916548']]
# Mark McKinney [['tt2954994']]
# Brad Hall [['tt2953902']]
# Tim Robinson [['tt7525600', 'tt2826134', 'tt7525638', 'tt6227116']]
# Alex Moffat [['tt9866072', 'tt1217217', 'tt5848272', 'tt3219194']]
# Tracy Morgan [['tt0100332']]
# Chris Rock [['tt2357748']]
# Bill Murray [['tt3091734']]
# Bill Murray [['tt3147486']]
# Heidi Gardner [['tt4180560', 'tt5101204', 'tt10324166', 'tt5619332']]
# Tom Davis [['tt0133302']]
# Brad Hall [['tt3162968']]
# Mike Myers [['tt3185956']]
# Molly Shannon [['tt0362542']]
# Bill Murray [['tt3231836']]
# Jim Downey [['tt3281976']]
# Christopher Guest [['tt3384430']]
# Chris Parnell [['tt3402362']]
# Tom Davis [['tt2510894', 'tt4624424', 'tt4633694', 'tt5220122']]
# Chris Elliott [['tt3449744']]
# Tom Davis [['tt3512322']]
# Dennis Miller [['tt3458560']]
# Mark McKinney [['tt1179069']]
# Bowen Yang [['tt2587452', 'tt6078096', 'tt2452244']]
# Victoria Jackson [['tt3172618']]
# Tim Robinson [['tt8909686', 'tt14435296', 'tt0199257', 'tt8909538']]
# Bill Murray [['tt0115367']]
# Bill Murray [['tt3603706']]
# Sarah Sherman [['tt4575056', 'tt2630898', 'tt3548962', 'tt3562626']]
# Michael O'Donoghue [['tt0084264']]
# Lauren Holt [['tt3597448']]
# Jeff Richards [['tt3650844']]
# Tom Davis [['tt3793204']]
# Leslie Jones [['tt3800692', 'tt4056158']]
# Sarah Sherman [['tt3815734']]
# Kyle Mooney [['tt3823130']]
# Jeff Richards [['tt3872944']]
# Casey Wilson [['tt3263490']]
# Tom Davis [['tt3970482']]
# Chris Elliott [['tt8386350']]
# Bill Murray [['tt3790306']]
# Will Ferrell [['tt0061240', 'tt0058797', 'tt0061296', 'tt0062994']]
# Chris Elliott [['tt4203440']]
# Mike O'Brien [['tt4475006']]
# Alex Moffat [['tt3381008', 'tt5104604', 'tt2652092', 'tt5628302']]
# Tim Robinson [['tt4049528']]
# Bill Murray [['tt4571940']]
# Jeff Richards [['tt3696804']]
# Christopher Guest [['tt4334642', 'tt1024855']]
# Rob Schneider [['tt4432798']]
# Dan Vitale [['tt4656450', 'tt5903450']]
# Phil Hartman [['tt4662448']]
# Mike Myers [['tt4670472']]
# Mike Myers [['tt4497152']]
# Dean Edwards [['tt0122905']]
# Jeff Richards [['tt4780202']]
# Brad Hall [['tt1554356']]
# Mark McKinney [['tt6225166']]
# Mark McKinney [['tt5441646', 'tt4823678']]
# Phil Hartman [['tt4828104']]
# Fred Wolf [['tt3910602', 'tt10222674', 'tt0072562']]
# Phil Hartman [['tt4701488']]
# Mike Myers [['tt4853866']]
# Victoria Jackson [['tt4906964']]
# Sarah Sherman [['tt9534540', 'tt15467926', 'tt8425308', 'tt14601874']]
# Lauren Holt [['tt8394996', 'tt8937092', 'tt0072562', 'tt7546290']]
# Tim Robinson [['tt4661598']]
# Molly Shannon [['tt3675186']]
# Chris Elliott [['tt5124078']]
# Chris Farley [['tt0142235']]
# Brad Hall [['tt5173520', 'tt6738058']]
# Mike O'Brien [['tt3906560']]
# Mark McKinney [['tt3739110']]
# Phil Hartman [['tt5298646']]
# Chris Rock [['tt5346900']]
# Mike O'Brien [['tt7119506', 'tt5352578']]
# Mike Myers [['tt5442834', 'tt6137590']]
# Mike Myers [['tt3109150']]
# Mike O'Brien [['tt5542640']]
# Jeff Richards [['tt3859146']]
# Mark McKinney [['tt1216491', 'tt0795461', 'tt6285944']]
# Tom Davis [['tt5631362', 'tt5631298']]
# Leslie Jones [['tt0093204']]
# Mark McKinney [['tt2954994']]
# Dennis Miller [['tt2114006']]
# Dennis Miller [['tt2114006']]
# Mike O'Brien [['tt4977374']]
# Will Ferrell [['tt5779664']]
# Bill Murray [['tt5156614']]
# Michael O'Donoghue [['tt5880050']]
# Dean Edwards [['tt5896628']]
# Sarah Sherman [['tt5924202']]
# Sarah Sherman [['tt5924202']]
# Victoria Jackson [['tt5941780']]
# Tom Davis [['tt7689318', 'tt6074820', 'tt6063510']]
# Tom Davis [['tt5993092']]
# Tom Davis [['tt7252334', 'tt6142826', 'tt5870978', 'tt10607616']]
# Mike O'Brien [['tt6157660']]
# Dean Edwards [['tt6166222']]
# Chris Elliott [['tt6185624']]
# Dennis Miller [['tt11993098']]
# Andrew Dismukes [['tt14508698', 'tt0072562', 'tt13858722', 'tt6279022']]
# Chris Farley [['tt6329792']]
# Siobhan Fallon [['tt6463510']]
# Leslie Jones [['tt6464314']]
# Jeff Richards [['tt6512646']]
# Mike O'Brien [['tt2998406']]
# Chris Elliott [['tt6264596']]
# Tim Robinson [['tt6391108']]
# Seth Meyers [['tt6528132', 'tt0496571']]
# Pete Davidson [['tt6806604']]
# Alex Moffat [['tt6851750']]
# Colin Quinn [['tt3948764']]
# Chris Elliott [['tt7233816']]
# Dean Edwards [['tt6186672', 'tt0354333', 'tt1565436']]
# Rich Hall [['tt8364112', 'tt7286604']]
# Mike Myers [['tt1302137', 'tt0460843']]
# Tom Davis [['tt7309462']]
# Michael O'Donoghue [['tt7465694', 'tt8526284', 'tt7615118']]
# Victoria Jackson [['tt0383760']]
# Mike O'Brien [['tt7493170']]
# Mike O'Brien [['tt7528072']]
# Tracy Morgan [['tt7587656']]
# Leslie Jones [['tt7604526']]
# Tom Davis [['tt7638698']]
# Brad Hall [['tt0121946']]
# Rob Schneider [['tt2642912']]
# Tim Robinson [['tt0112193', 'tt0396362', 'tt0335620', 'tt9090184']]
# Tracy Morgan [['tt11833964', 'tt3644198']]
# Dennis Miller [['tt3471592']]
# Brad Hall [['tt8106790']]
# Rob Schneider [['tt11239422', 'tt8280446']]
# Punkie Johnson [['tt7242698', 'tt5821764', 'tt5117666', 'tt7778796']]
# Sarah Sherman [['tt8218988']]
# Michael O'Donoghue [['tt1715425']]
# Mike O'Brien [['tt8554874']]
# Chris Parnell [['tt7396544']]
# Mary Gross [['tt0423652']]

# %%
Counter(names_title_dict.keys())
# Out:
# Counter({'John Belushi': 1,
#          'Dan Aykroyd': 1,
#          'Bill Murray': 1,
#          'Mike Myers': 1,
#          'Chevy Chase': 1,
#          'Billy Crystal': 1,
#          'Joan Cusack': 1,
#          'Robert Downey Jr.': 1,
#          'Chris Farley': 1,
#          'Janeane Garofalo': 1,
#          'Julia Louis-Dreyfus': 1,
#          'Eddie Murphy': 1,
#          'Jim Belushi': 1,
#          'Dana Carvey': 1,
#          'Adam Sandler': 1,
#          'Christopher Guest': 1,
#          'Anthony Michael Hall': 1,
#          'Jon Lovitz': 1,
#          'Jay Mohr': 1,
#          'Randy Quaid': 1,
#          'Chris Rock': 1,
#          'Rob Schneider': 1,
#          'Martin Short': 1,
#          'Ben Stiller': 1,
#          'Damon Wayans': 1,
#          'Christine Ebersole': 1,
#          'Will Ferrell': 1,
#          'Jane Curtin': 1,
#          'Nora Dunn': 1,
#          'Tim Meadows': 1,
#          'Kevin Nealon': 1,
#          'David Spade': 1,
#          'Fred Armisen': 1,
#          'Peter Aykroyd': 1,
#          'Morwenna Banks': 1,
#          'Jim Breuer': 1,
#          'A. Whitney Brown': 1,
#          'Beth Cahill': 1,
#          'Ellen Cleghorne': 1,
#          'George Coe': 1,
#          'Pete Davidson': 1,
#          'Tom Davis': 1,
#          'Denny Dillon': 1,
#          'Brian Doyle-Murray': 1,
#          'Rachel Dratch': 1,
#          'Robin Duke': 1,
#          'Dean Edwards': 1,
#          'Chris Elliott': 1,
#          'Jimmy Fallon': 1,
#          'Tina Fey': 1,
#          'Will Forte': 1,
#          'Al Franken': 1,
#          'Ana Gasteyer': 1,
#          'Gilbert Gottfried': 1,
#          'Mary Gross': 1,
#          'Bill Hader': 1,
#          'Brad Hall': 1,
#          'Rich Hall': 1,
#          'Darrell Hammond': 1,
#          'Phil Hartman': 1,
#          'Jan Hooks': 1,
#          'Yvonne Hudson': 1,
#          'Melanie Hutsell': 1,
#          'Victoria Jackson': 1,
#          'Leslie Jones': 1,
#          'Chris Kattan': 1,
#          'Tim Kazurinsky': 1,
#          'Laura Kightlinger': 1,
#          'Taran Killam': 1,
#          'David Koechner': 1,
#          'Gary Kroeger': 1,
#          'Matthew Laurance': 1,
#          'Gail Matthius': 1,
#          'Michael McKean': 1,
#          'Mark McKinney': 1,
#          'Kate McKinnon': 1,
#          'Laurie Metcalf': 1,
#          'Dennis Miller': 1,
#          'Jerry Minor': 1,
#          'Tracy Morgan': 1,
#          'Garrett Morris': 1,
#          'Laraine Newman': 1,
#          'Don Novello': 1,
#          "Mike O'Brien": 1,
#          "Michael O'Donoghue": 1,
#          'Cheri Oteri': 1,
#          'Chris Parnell': 1,
#          'Joe Piscopo': 1,
#          'Amy Poehler': 1,
#          'Emily Prager': 1,
#          'Colin Quinn': 1,
#          'Gilda Radner': 1,
#          'Tony Rosato': 1,
#          'Jeff Richards': 1,
#          'Ann Risley': 1,
#          'Tim Robinson': 1,
#          'Harry Shearer': 1,
#          'Charles Rocket': 1,
#          'Maya Rudolph': 1,
#          'Horatio Sanz': 1,
#          'Tom Schiller': 1,
#          'Paul Shaffer': 1,
#          'Molly Shannon': 1,
#          'Sarah Silverman': 1,
#          'Robert Smigel': 1,
#          'Pamela Stephenson': 1,
#          'Jason Sudeikis': 1,
#          'Julia Sweeney': 1,
#          'Terry Sweeney': 1,
#          'Kenan Thompson': 1,
#          'Danitra Vance': 1,
#          'Dan Vitale': 1,
#          'Patrick Weathers': 1,
#          'Casey Wilson': 1,
#          'Fred Wolf': 1,
#          'Alan Zweibel': 1,
#          'Seth Meyers': 1,
#          'Lauren Holt': 1,
#          'Michaela Watkins': 1,
#          'Heidi Gardner': 1,
#          'Sarah Sherman': 1,
#          'Bobby Moynihan': 1,
#          'Kristen Wiig': 1,
#          'Kyle Mooney': 1,
#          'Rob Riggle': 1,
#          'Finesse Mitchell': 1,
#          'Mikey Day': 1,
#          'Andy Samberg': 1,
#          'Paul Brittain': 1,
#          'Nasim Pedrad': 1,
#          'Colin Jost': 1,
#          'Abby Elliott': 1,
#          'John Milhiser': 1,
#          'Alex Moffat': 1,
#          'Aristotle Athari': 1,
#          'Jenny Slate': 1,
#          'Beck Bennett': 1,
#          'Vanessa Bayer': 1,
#          'Sasheer Zamata': 1,
#          'Noël Wells': 1,
#          'Luke Null': 1,
#          'Melissa Villaseñor': 1,
#          'Michael Che': 1,
#          'Jay Pharoah': 1,
#          'Jon Rudnitsky': 1,
#          'James Austin Johnson': 1,
#          'Chloe Fineman': 1,
#          'Ego Nwodim': 1,
#          'Brooks Wheelan': 1,
#          'Cecily Strong': 1,
#          'Aidy Bryant': 1,
#          'Chris Redd': 1,
#          'Jim Downey': 1,
#          'Bowen Yang': 1,
#          'Andrew Dismukes': 1,
#          'Siobhan Fallon': 1,
#          'Punkie Johnson': 1})

# %%
for i in (SNL_name_check):
    for x in i:
        unique_titles = []
        if str(x).startswith('tt'):
            tt = x.split(',')
            unique_titles = unique_titles.append(tt)
#             print(unique_titles)
    if i[1] == names_title_dict.keys():
        names_title_dict.items(unique_titles)
    print(i[1], tt)
# Out:
# John Belushi ['tt0078723', 'tt0072562', 'tt0077975', 'tt0080455']
# Dan Aykroyd ['tt0097428', 'tt0118747', 'tt0087332', 'tt0080455']
# Bill Murray ['tt1748122', 'tt0128445', 'tt0362270', 'tt0335266']
# Mike Myers ['tt0295178', 'tt0145660', 'tt0118655', 'tt0811138']
# Chevy Chase ['tt0085995', 'tt0097958', 'tt0080487', 'tt0092086']
# Billy Crystal ['tt0101587', 'tt0098635', 'tt0113097', 'tt0122933']
# Joan Cusack ['tt0119229', 'tt1659337', 'tt0119360', 'tt0096463']
# Robert Downey Jr. ['tt1300854', 'tt0371746', 'tt4154796', 'tt0988045']
# Chris Farley ['tt0118708', 'tt0115697', 'tt0114694', 'tt0106598']
# Janeane Garofalo ['tt0382932', 'tt0132347', 'tt0117979', 'tt0243655']
# Julia Louis-Dreyfus ['tt0462128', 'tt1759761', 'tt2390361', 'tt0098904']
# Eddie Murphy ['tt0117218', 'tt0443489', 'tt0094898', 'tt0126029']
# Jim Belushi ['tt0097637', 'tt0072562', 'tt0117468', 'tt0095963']
# Dana Carvey ['tt0072562', 'tt0108525', 'tt0105793', 'tt0295427']
# Adam Sandler ['tt0120484', 'tt0120888', 'tt0142342', 'tt0185431']
# Christopher Guest ['tt0218839', 'tt0310281', 'tt0088258', 'tt0118111']
# Anthony Michael Hall ['tt0468569', 'tt2361317', 'tt4758646', 'tt1100089']
# Jon Lovitz ['tt0104694', 'tt0107659', 'tt0147612', 'tt0437863']
# Jay Mohr ['tt0116695', 'tt0120241', 'tt0139239', 'tt0180052']
# Randy Quaid ['tt0097958', 'tt0116629', 'tt0116778', 'tt0388795']
# Chris Rock ['tt2784678', 'tt0325537', 'tt0398165', 'tt0351283']
# Rob Schneider ['tt0255798', 'tt0302640', 'tt0367652', 'tt0205000']
# Martin Short ['tt0093260', 'tt0452681', 'tt0092086', 'tt1791528']
# Ben Stiller ['tt0196229', 'tt0359950', 'tt0942385', 'tt1608290']
# Damon Wayans ['tt0110443', 'tt0104897', 'tt0273855', 'tt0102266']
# Christine Ebersole ['tt0115697', 'tt0993846', 'tt0086879', 'tt0110989']
# Will Ferrell ['tt0357413', 'tt0445934', 'tt1229340', 'tt0415306']
# Jane Curtin ['tt0106598', 'tt0115082', 'tt0086742', 'tt1155056']
# Nora Dunn ['tt0405336', 'tt0910936', 'tt0157503', 'tt0120188']
# Tim Meadows ['tt0841046', 'tt0377092', 'tt3960412', 'tt0213790']
# Kevin Nealon ['tt0072562', 'tt0116483', 'tt0439100', 'tt0120888']
# David Spade ['tt0245686', 'tt0120917', 'tt0437863', 'tt0114694']
# Fred Armisen ['tt0357413', 'tt1282140', 'tt0072562', 'tt1780441']
# Peter Aykroyd ['tt0106598', 'tt0095687', 'tt0090056', 'tt0102558']
# Morwenna Banks ['tt0760141', 'tt0466664', 'tt2245003', 'tt5839960']
# Jim Breuer ['tt1222817', 'tt0120693', 'tt0120913', 'tt0144168']
# A. Whitney Brown ['tt0096708', 'tt0072562', 'tt0166039', 'tt1094991']
# Beth Cahill ['tt0155764', 'tt0262411', 'tt0164930', 'tt0072562']
# Ellen Cleghorne ['tt0120591', 'tt0200550', 'tt2126357', 'tt0185431']
# George Coe ['tt1399103', 'tt0089901', 'tt0073747', 'tt0092666']
# Pete Davidson ['tt9686708', 'tt5304992', 'tt0800325', 'tt6334354']
# Tom Davis ['tt0086465', 'tt0251075', 'tt0106598', 'tt0072562']
# Tom Davis ['tt0120241', 'tt0100613', 'tt0803033', 'tt0087998']
# Tom Davis ['tt0124718', 'tt0463970']
# Tom Davis ['tt0118632']
# Denny Dillon ['tt0475276', 'tt0098780', 'tt0268380', 'tt0076666']
# Brian Doyle-Murray ['tt0105793', 'tt0102138', 'tt0080487', 'tt0097958']
# Rachel Dratch ['tt1564367', 'tt0389860', 'tt0814331', 'tt8169446']
# Robin Duke ['tt0075578', 'tt0117108', 'tt0107048', 'tt0072562']
# Dean Edwards ['tt0910898', 'tt2784678', 'tt0421143', 'tt0413300']
# Chris Elliott ['tt0107048', 'tt0109361', 'tt0129387', 'tt0096754']
# Chris Elliott ['tt0103873', 'tt0834001', 'tt0110311', 'tt0107822']
# Chris Elliott ['tt0222820']
# Jimmy Fallon ['tt3444938', 'tt1231460', 'tt0332047', 'tt0316732']
# Tina Fey ['tt1850457', 'tt0377092', 'tt1279935', 'tt0496424']
# Will Forte ['tt3230454', 'tt1490017', 'tt1470023', 'tt1821549']
# Al Franken ['tt0114571', 'tt0368008', 'tt0086465', 'tt0072562']
# Ana Gasteyer ['tt0207201', 'tt1232200', 'tt4366830', 'tt0377092']
# Gilbert Gottfried ['tt0103639', 'tt0092644', 'tt0098987', 'tt0100419']
# Mary Gross ['tt0120791', 'tt0243736', 'tt0094846', 'tt0072562']
# Bill Hader ['tt1571249', 'tt3152624', 'tt7349950', 'tt2096673']
# Brad Hall ['tt0120623', 'tt2080359', 'tt6388738', 'tt0101055']
# Brad Hall ['tt0109830', 'tt0120399', 'tt0120829']
# Brad Hall ['tt2468756', 'tt0800142', 'tt8793210', 'tt2953706']
# Rich Hall ['tt0072562', 'tt0325939', 'tt0085065', 'tt1430607']
# Darrell Hammond ['tt0799949', 'tt0118747', 'tt0306047', 'tt0072562']
# Phil Hartman ['tt0122718', 'tt0108174', 'tt0116705', 'tt0112095']
# Jan Hooks ['tt0103776', 'tt0115082', 'tt0106598', 'tt0089791']
# Yvonne Hudson ['tt0277167', 'tt0072562']
# Melanie Hutsell ['tt4789300', 'tt1478338', 'tt0072562', 'tt2191701']
# Victoria Jackson ['tt1394227', 'tt0098546', 'tt0099819', 'tt0094846']
# Leslie Jones ['tt0272338', 'tt1791528', 'tt1560747', 'tt0120863']
# Leslie Jones ['tt0072562', 'tt6802400', 'tt1289401', 'tt2461150']
# Leslie Jones ['tt0116442']
# Leslie Jones ['tt0113492', 'tt0180073', 'tt0773756', 'tt0120738']
# Leslie Jones ['tt0094643']
# Chris Kattan ['tt0120770', 'tt0279493', 'tt2479478', 'tt0185371']
# Tim Kazurinsky ['tt0090583', 'tt0089822', 'tt0082801', 'tt0072562']
# Laura Kightlinger ['tt4116284', 'tt8324422', 'tt0460619', 'tt0157246']
# Taran Killam ['tt2024544', 'tt0072562', 'tt5689068', 'tt4000956']
# David Koechner ['tt0425061', 'tt0357413', 'tt0427944', 'tt1229340']
# Gary Kroeger ['tt0200525', 'tt0072562', 'tt0046593', 'tt0086765']
# Matthew Laurance ['tt0112111', 'tt0085475', 'tt0098772', 'tt0090060']
# Gail Matthius ['tt0072562', 'tt0162796', 'tt0083530', 'tt0103373']
# Michael McKean ['tt0088258', 'tt0088930', 'tt0310281', 'tt3032476']
# Mark McKinney ['tt0387779', 'tt0096626', 'tt0120770', 'tt1159996']
# Mark McKinney ['tt0277370', 'tt1212450', 'tt0107927', 'tt1731701']
# Kate McKinnon ['tt4799050', 'tt0072562', 'tt6394270', 'tt1289401']
# Laurie Metcalf ['tt0094540', 'tt0120082', 'tt0114709', 'tt4925292']
# Dennis Miller ['tt0113957', 'tt0245686', 'tt0119731', 'tt0117826']
# Dennis Miller ['tt0385463', 'tt0081561', 'tt0108709', 'tt0135848']
# Dennis Miller ['tt0226416', 'tt0072792', 'tt0279429', 'tt0081563']
# Jerry Minor ['tt2463288', 'tt0817538', 'tt0323633', 'tt0357413']
# Tracy Morgan ['tt0074377', 'tt0074621', 'tt0069098', 'tt0068892']
# Tracy Morgan ['tt0496424', 'tt0787474', 'tt1385867', 'tt0426592']
# Garrett Morris ['tt0072562', 'tt0478970', 'tt0106598', 'tt0278488']
# Bill Murray ['tt0097132']
# Laraine Newman ['tt0102719', 'tt0106598', 'tt0116705', 'tt0120669']
# Don Novello ['tt0072562', 'tt0112642', 'tt0099674', 'tt0230011']
# Mike O'Brien ['tt0159876', 'tt0340434', 'tt0127341', 'tt0153362']
# Mike O'Brien ['tt0094834', 'tt0117652', 'tt0110939', 'tt0109021']
# Mike O'Brien ['tt2347497', 'tt1159996', 'tt1095174', 'tt0433400']
# Michael O'Donoghue ['tt0096061', 'tt0079583', 'tt0079522', 'tt0072562']
# Cheri Oteri ['tt0141369', 'tt0175142', 'tt0119528', 'tt0405336']
# Chris Parnell ['tt0357413', 'tt2861424', 'tt0841046', 'tt1232829']
# Joe Piscopo ['tt0092226', 'tt0072562', 'tt0094961', 'tt0087507']
# Amy Poehler ['tt2096673', 'tt0871426', 'tt1266020', 'tt0072562']
# Emily Prager ['tt0048860', 'tt0094674', 'tt0079583', 'tt0059992']
# Colin Quinn ['tt3152624', 'tt3314416', 'tt1375670', 'tt0120770']
# Gilda Radner ['tt0070290', 'tt0091178', 'tt0084049', 'tt0072562']
# Tony Rosato ['tt0075578', 'tt0117593', 'tt0088582', 'tt0207701']
# Jeff Richards ['tt0049578', 'tt0052932', 'tt0047472', 'tt0050327']
# Jeff Richards ['tt0104254', 'tt0120800', 'tt0111333', 'tt0094449']
# Jeff Richards ['tt0759475', 'tt0468999', 'tt4687632', 'tt0072562']
# Jeff Richards ['tt0162349', 'tt0076781', 'tt0087348', 'tt0090631']
# Ann Risley ['tt0072562', 'tt0081554', 'tt0081518', 'tt0082525']
# Tim Robinson ['tt0088591', 'tt0834001', 'tt4698684', 'tt0443334']
# Harry Shearer ['tt0120382', 'tt0310281', 'tt0096697', 'tt0088258']
# Chris Rock ['tt0284126', 'tt9372772', 'tt0142646', 'tt0286159']
# Charles Rocket ['tt0120913', 'tt0099348', 'tt0108122', 'tt0109686']
# Maya Rudolph ['tt1727388', 'tt1176740', 'tt1478338', 'tt1791528']
# Horatio Sanz ['tt0285462', 'tt1920849', 'tt0215129', 'tt1045778']
# Tom Schiller ['tt0087817', 'tt0072562', 'tt3677742', 'tt0304046']
# Paul Shaffer ['tt0088258', 'tt0119282', 'tt0118747', 'tt4537842']
# Molly Shannon ['tt0362120', 'tt0167427', 'tt0151738', 'tt4158876']
# Sarah Silverman ['tt0332379', 'tt0821375', 'tt1772341', 'tt5848272']
# Robert Smigel ['tt0185431', 'tt0072562', 'tt0106052', 'tt0272338']
# Pamela Stephenson ['tt0080253', 'tt0086393', 'tt0082517', 'tt0199218']
# Jason Sudeikis ['tt1723121', 'tt10986410', 'tt4680182', 'tt1499658']
# Julia Sweeney ['tt2467372', 'tt0498994', 'tt8962130', 'tt10417836']
# Terry Sweeney ['tt0240596', 'tt0098300', 'tt0342139', 'tt0093443']
# Kenan Thompson ['tt0417148', 'tt0072562', 'tt0115231', 'tt0119215']
# Danitra Vance ['tt0098621', 'tt0102316', 'tt0102174', 'tt0086759']
# Dan Vitale ['tt0088804', 'tt0086768', 'tt1744760', 'tt0072562']
# Patrick Weathers ['tt1741243', 'tt1790886', 'tt1996346', 'tt0094291']
# Casey Wilson ['tt0102034', 'tt0120611', 'tt0107415', 'tt0274164']
# Fred Wolf ['tt0061421', 'tt0092345', 'tt0131613', 'tt0067595']
# Fred Wolf ['tt0115697', 'tt0120654', 'tt2191701', 'tt0185431']
# Fred Wolf ['tt2157952', 'tt0154574']
# Alan Zweibel ['tt0090459', 'tt0072562', 'tt0092925', 'tt0110687']
# Chris Elliott ['tt1167638', 'tt0120662', 'tt0118661', 'tt0203009']
# Rich Hall ['tt0861361']
# Jeff Richards ['tt0076598']
# Tom Davis ['tt8948614']
# Mike O'Brien ['tt3562462']
# Colin Quinn ['tt8819940']
# Seth Meyers ['tt1598822', 'tt4677934', 'tt0072562', 'tt3513388']
# Pete Davidson ['tt1598822', 'tt4677934', 'tt0072562', 'tt3513388']
# Chris Elliott ['tt1598822', 'tt4677934', 'tt0072562', 'tt3513388']
# Chris Parnell ['tt0265736']
# Dean Edwards ['tt0450852', 'tt0258476', 'tt1165357', 'tt1111291']
# Bill Murray ['tt6384192', 'tt13998382']
# Tom Davis ['tt6384192', 'tt13998382']
# Tom Davis ['tt9639868']
# Dean Edwards ['tt3644198']
# Chris Rock ['tt3644198']
# Mark McKinney ['tt3644198']
# Mike O'Brien ['tt9734382', 'tt9883024']
# Leslie Jones ['tt0123965']
# Tom Davis ['tt0295476']
# Brad Hall ['tt0294941']
# Lauren Holt ['tt0294941']
# Tom Davis ['tt0294941']
# Tom Davis ['tt0294941']
# Tim Robinson ['tt0294941']
# Eddie Murphy ['tt0294941']
# Tim Robinson ['tt0294941']
# Mike O'Brien ['tt0294941']
# Tom Davis ['tt0294941']
# Mike O'Brien ['tt0294941']
# Mike O'Brien ['tt1716744', 'tt1448500', 'tt7498020', 'tt0217061']
# Victoria Jackson ['tt1716744', 'tt1448500', 'tt7498020', 'tt0217061']
# Terry Sweeney ['tt1716744', 'tt1448500', 'tt7498020', 'tt0217061']
# Tim Meadows ['tt10740136', 'tt13743066', 'tt10863916', 'tt14016930']
# Tom Davis ['tt12649418']
# Tom Davis ['tt12649418']
# Dennis Miller ['tt10974848']
# Mike O'Brien ['tt11348726']
# Tom Davis ['tt11137268']
# Casey Wilson ['tt11475900']
# Will Ferrell ['tt11462908']
# Mike O'Brien ['tt11599804']
# Mike O'Brien ['tt11394180']
# Chris Farley ['tt1972591']
# Tom Davis ['tt1972591']
# Fred Wolf ['tt1972591']
# Chris Elliott ['tt1972591']
# Michael O'Donoghue ['tt12003714']
# Michaela Watkins ['tt1932718', 'tt1655460', 'tt2294677', 'tt1212436']
# Tom Davis ['tt1020913']
# Jeff Richards ['tt0116783']
# Jerry Minor ['tt0401003']
# Dan Vitale ['tt0401003']
# Leslie Jones ['tt0401003']
# Bill Murray ['tt0288154', 'tt0189500']
# Jeff Richards ['tt11011652']
# Mike O'Brien ['tt12661304']
# Heidi Gardner ['tt12661304']
# Casey Wilson ['tt12661304']
# Mike O'Brien ['tt3783812']
# Martin Short ['tt12800308']
# Tom Davis ['tt5295032']
# Victoria Jackson ['tt5295032']
# Dennis Miller ['tt5295032']
# Victoria Jackson ['tt5295032']
# Mike O'Brien ['tt5295032']
# Tim Robinson ['tt10505762']
# Sarah Sherman ['tt10505762']
# Dennis Miller ['tt0325502']
# Mike O'Brien ['tt14643040']
# Eddie Murphy ['tt0830515', 'tt10539608', 'tt2802144', 'tt2527336']
# Tom Davis ['tt0830515', 'tt10539608', 'tt2802144', 'tt2527336']
# Chris Elliott ['tt13026762']
# Brad Hall ['tt1442550']
# Leslie Jones ['tt1442550']
# Dean Edwards ['tt1442550']
# Tom Davis ['tt0262152', 'tt13471320']
# Dan Vitale ['tt14236360']
# Victoria Jackson ['tt14236360']
# Tim Meadows ['tt11394158']
# Mike O'Brien ['tt14643040']
# Tom Davis ['tt13682176']
# Rob Schneider ['tt4829936']
# Victoria Jackson ['tt6932494']
# Victoria Jackson ['tt14855722']
# Tom Davis ['tt14855722']
# Mike Myers ['tt14855722']
# Tom Davis ['tt0124718']
# Victoria Jackson ['tt0124718']
# Jimmy Fallon ['tt6133466']
# Victoria Jackson ['tt14894996']
# Leslie Jones ['tt0341708']
# Chris Farley ['tt14779558', 'tt16589596']
# Colin Quinn ['tt14779558', 'tt16589596']
# Christopher Guest ['tt14779558', 'tt16589596']
# Bill Murray ['tt14779558', 'tt16589596']
# Bobby Moynihan ['tt13622982', 'tt10662034', 'tt0072562']
# Leslie Jones ['tt8579674']
# Casey Wilson ['tt15488832']
# Michael O'Donoghue ['tt15488832']
# Mike O'Brien ['tt15669416']
# Mike Myers ['tt15714650']
# Eddie Murphy ['tt15714650']
# Victoria Jackson ['tt15714650']
# Kristen Wiig ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']
# Jeff Richards ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']
# Mike O'Brien ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']
# Tom Davis ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']
# Dennis Miller ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']
# Leslie Jones ['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']
# Brad Hall ['tt13639450', 'tt12747694']
# Tim Robinson ['tt13639450', 'tt12747694']
# Chris Parnell ['tt13639450', 'tt12747694']
# Leslie Jones ['tt0444631', 'tt0357577']
# Tim Meadows ['tt0444631', 'tt0357577']
# Rich Hall ['tt0444631', 'tt0357577']
# Victoria Jackson ['tt15659704']
# Tim Robinson ['tt18546600']
# Kyle Mooney ['tt18764878']
# Tim Robinson ['tt6168110']
# Mike Myers ['tt6168110']
# Bill Murray ['tt0351810']
# Tim Robinson ['tt0968732', 'tt0775402', 'tt3558296', 'tt1715425']
# Martin Short ['tt0968732', 'tt0775402', 'tt3558296', 'tt1715425']
# Tracy Morgan ['tt1173421']
# Rob Riggle ['tt2096672', 'tt1119646', 'tt0115147', 'tt1232829']
# Finesse Mitchell ['tt0785077', 'tt0072562', 'tt0951216', 'tt0790804']
# Rich Hall ['tt1517640', 'tt1330618', 'tt0108709']
# Mikey Day ['tt0072562', 'tt2076347', 'tt1217217', 'tt4000956']
# Mike O'Brien ['tt1387418', 'tt1730767', 'tt0398291']
# Adam Sandler ['tt13689618', 'tt10428498', 'tt0068120', 'tt12116598']
# Chris Elliott ['tt0399977', 'tt0412109', 'tt6261554', 'tt0338616']
# Andy Samberg ['tt0072562', 'tt3960412', 'tt2467372', 'tt9484998']
# Paul Brittain ['tt0413660']
# Chris Rock ['tt0382992', 'tt0317705', 'tt0198781']
# Christopher Guest ['tt0040053']
# Mike Myers ['tt0476931', 'tt1020929', 'tt2140691', 'tt1045847']
# Chris Rock ['tt0434026']
# Tom Davis ['tt0439911']
# Tim Robinson ['tt0083731']
# Bill Murray ['tt0448004']
# Nasim Pedrad ['tt6139732', 'tt1690953', 'tt10338160', 'tt2490326']
# Jeff Richards ['tt1877853', 'tt0904115']
# Victoria Jackson ['tt6769236', 'tt5941780', 'tt10483744', 'tt0455841']
# Colin Jost ['tt0072562', 'tt1292566', 'tt1361336', 'tt6802400']
# Bill Murray ['tt0457251', 'tt0961721']
# Mike O'Brien ['tt0120841']
# Tom Davis ['tt4276112', 'tt2062966', 'tt1215983', 'tt0789775']
# Casey Wilson ['tt0457394']
# Tim Robinson ['tt0105986']
# Tim Robinson ['tt0483776', 'tt5786442', 'tt1309181', 'tt0484257']
# Bill Murray ['tt0122145']
# Casey Wilson ['tt0901476', 'tt1509788', 'tt1103153', 'tt2267998']
# Bill Murray ['tt0281438']
# Mike O'Brien ['tt0281438']
# Christopher Guest ['tt12716280', 'tt10538562', 'tt1822842', 'tt8022434']
# Leslie Jones ['tt0106179', 'tt0120901', 'tt0242733', 'tt0204993']
# Victoria Jackson ['tt1334555']
# Tim Robinson ['tt0497043']
# Dean Edwards ['tt0482481', 'tt2551436', 'tt0354333', 'tt1529670']
# Phil Hartman ['tt2417108', 'tt0844479', 'tt0409182']
# Mike Myers ['tt0079945']
# Tom Davis ['tt0787424', 'tt0496360', 'tt9822404', 'tt0123338']
# Abby Elliott ['tt0072562', 'tt1291150', 'tt1663143', 'tt1411238']
# Tom Davis ['tt0458339', 'tt3748528', 'tt0816711', 'tt1446714']
# Tom Davis ['tt1474200', 'tt0770745', 'tt0882741']
# Chris Elliott ['tt0861343']
# Tim Robinson ['tt0803030', 'tt0818620', 'tt0758745', 'tt0427848']
# Tom Davis ['tt0494235']
# John Milhiser ['tt0072562', 'tt5990096', 'tt1289401', 'tt4061080']
# Mike O'Brien ['tt4397866', 'tt1636189', 'tt1636331', 'tt0181269']
# Michael O'Donoghue ['tt1642373', 'tt1811323', 'tt0840371']
# Dennis Miller ['tt0119277']
# Chris Elliott ['tt0972846']
# Michael McKean ['tt0129910']
# Tim Robinson ['tt0382382']
# Jeff Richards ['tt0368257']
# Mike O'Brien ['tt0238304', 'tt0238305', 'tt0238303', 'tt0104512']
# Dean Edwards ['tt14773254', 'tt13645690', 'tt12058768', 'tt0298674']
# Mike Myers ['tt0115279']
# Tom Davis ['tt6306064', 'tt0095408']
# Mike O'Brien ['tt0457433', 'tt0470023', 'tt1107855', 'tt0464041']
# Chris Elliott ['tt3765728', 'tt1242542']
# Sarah Sherman ['tt1006983', 'tt3773358', 'tt14945492', 'tt9170758']
# Tom Davis ['tt1272878', 'tt0765010', 'tt0452625', 'tt0457572']
# Mike O'Brien ['tt0949671']
# Lauren Holt ['tt1022605', 'tt3449322', 'tt0815250']
# Dennis Miller ['tt0846694', 'tt0416779']
# Tom Davis ['tt0349903']
# Rob Schneider ['tt1039621']
# Fred Wolf ['tt1032874']
# Alex Moffat ['tt0112230', 'tt0111999']
# Dennis Miller ['tt0874300', 'tt1751105', 'tt3529198', 'tt8651594']
# Chris Parnell ['tt1020109', 'tt0343316']
# Michael O'Donoghue ['tt0099566']
# Aristotle Athari ['tt9173436', 'tt5918784', 'tt5917146', 'tt7322648']
# Tim Robinson ['tt2421910', 'tt1112661']
# Jenny Slate ['tt2709768', 'tt2948356', 'tt4481414', 'tt2910274']
# Tom Davis ['tt1136478', 'tt2787132']
# Fred Wolf ['tt1136478', 'tt2787132']
# Mike O'Brien ['tt2719804', 'tt1357005', 'tt1100051']
# Tom Davis ['tt0106137']
# Tom Davis ['tt0086192']
# Michael O'Donoghue ['tt0133302', 'tt1626811', 'tt0115355', 'tt0120801']
# Bill Murray ['tt1732762', 'tt1210095']
# Brad Hall ['tt0400410', 'tt0939564']
# Martin Short ['tt0079687']
# Kate McKinnon ['tt0092225']
# Mike O'Brien ['tt0051297']
# Tom Davis ['tt1250756']
# Mike O'Brien ['tt4229954', 'tt0775529', 'tt0494864']
# Beck Bennett ['tt3470600', 'tt7979580', 'tt5531466', 'tt1086064']
# Leslie Jones ['tt0031055']
# Mike O'Brien ['tt1366945', 'tt1107855', 'tt2182211', 'tt0313038']
# Jeff Richards ['tt0393274']
# Mike O'Brien ['tt1584933', 'tt0401759', 'tt9248866', 'tt0368107']
# Mike O'Brien ['tt1326172']
# Chris Rock ['tt0174392']
# Mike Myers ['tt1362049']
# Kyle Mooney ['tt15977708', 'tt2139555', 'tt1608290', 'tt5805752']
# Vanessa Bayer ['tt0072562', 'tt2989524', 'tt1711525', 'tt3152624']
# Leslie Jones ['tt1279966']
# Tom Davis ['tt0128707']
# Tim Robinson ['tt1462862', 'tt1507979', 'tt1462856']
# Sasheer Zamata ['tt4018068', 'tt11394332', 'tt4018066', 'tt6791096']
# Bill Murray ['tt1490534']
# Jeff Richards ['tt1587314', 'tt1505388']
# Mike O'Brien ['tt1493558']
# Noël Wells ['tt0072562', 'tt7713450', 'tt6212496', 'tt9184820']
# Bill Murray ['tt1687207', 'tt1600694', 'tt1538443']
# Jeff Richards ['tt0072265']
# Rich Hall ['tt1542770']
# Chris Elliott ['tt1551638']
# Tom Davis ['tt1517228']
# Casey Wilson ['tt2265215', 'tt1982864', 'tt1565981', 'tt2382015']
# Leslie Jones ['tt1575557']
# Luke Null ['tt1545490', 'tt0072562', 'tt9881938', 'tt3146066']
# Melissa Villaseñor ['tt1809001', 'tt0072562', 'tt5848272', 'tt10682266']
# Michael Che ['tt0072562', 'tt12762460', 'tt0499556', 'tt2784678']
# Bill Murray ['tt0072562', 'tt12762460', 'tt0499556', 'tt2784678']
# Tom Davis ['tt1326139']
# Jeff Richards ['tt0380060']
# Chris Rock ['tt1556078']
# Mike O'Brien ['tt1193138']
# Casey Wilson ['tt6091368', 'tt2445666', 'tt6083648', 'tt9748306']
# Tim Robinson ['tt0389911', 'tt1663232', 'tt4502270', 'tt4504130']
# Tim Robinson ['tt1664843']
# Dennis Miller ['tt0829176']
# Chris Elliott ['tt0829176']
# Casey Wilson ['tt1687906']
# Jay Pharoah ['tt0072562', 'tt5774044', 'tt1408253', 'tt7153766']
# Michael O'Donoghue ['tt2790032', 'tt2790152', 'tt2798906']
# Mike Myers ['tt0096563']
# Mike Myers ['tt1708468']
# Tim Robinson ['tt1708468']
# Emily Prager ['tt1708468']
# Sarah Sherman ['tt1518327']
# Chris Elliott ['tt0262152']
# Tim Robinson ['tt1777032']
# Tim Robinson ['tt10050772', 'tt6343706', 'tt4779762', 'tt0072562']
# Paul Brittain ['tt0837562', 'tt0072562', 'tt2176287', 'tt2510894']
# Martin Short ['tt1791798', 'tt0938980', 'tt5747320', 'tt1297329']
# Chris Elliott ['tt1493151', 'tt1813516']
# Bill Murray ['tt1810727']
# Tom Davis ['tt4468740', 'tt4158096', 'tt4673856', 'tt8096690']
# Bill Murray ['tt1740656']
# Bill Murray ['tt2147467', 'tt1837678']
# Eddie Murphy ['tt0492509']
# Jon Rudnitsky ['tt0072562', 'tt5719700']
# Tom Davis ['tt1850339']
# Tim Robinson ['tt1857742']
# Mike Myers ['tt5657856', 'tt1817273', 'tt6133466', 'tt1219289']
# Mike O'Brien ['tt1885305']
# Bill Murray ['tt1911645', 'tt2450652', 'tt2282941']
# Mike O'Brien ['tt1434435']
# Bill Murray ['tt1884251']
# Casey Wilson ['tt1951191']
# Bill Murray ['tt1972582']
# Casey Wilson ['tt1982864']
# Mike Myers ['tt1984991']
# James Austin Johnson ['tt0072562', 'tt8036272', 'tt3032476', 'tt0475290']
# Tracy Morgan ['tt0072562', 'tt8036272', 'tt3032476', 'tt0475290']
# Sarah Sherman ['tt1999871']
# Yvonne Hudson ['tt2033480', 'tt3526474', 'tt2142935', 'tt2156935']
# Mike O'Brien ['tt2033480', 'tt3526474', 'tt2142935', 'tt2156935']
# Tracy Morgan ['tt1887882']
# Mike O'Brien ['tt2043951']
# Mike Myers ['tt2004334']
# Tom Davis ['tt0321473']
# Mike O'Brien ['tt1170243']
# Chloe Fineman ['tt0072562', 'tt8577458', 'tt6527474', 'tt5460226']
# Bill Murray ['tt2147467']
# Tracy Morgan ['tt2147467']
# Tom Davis ['tt2288153', 'tt0189246', 'tt0081857', 'tt2161907']
# Dennis Miller ['tt2288153', 'tt0189246', 'tt0081857', 'tt2161907']
# Rich Hall ['tt0146386']
# Mike O'Brien ['tt2247021']
# Bill Murray ['tt2202391']
# Tim Robinson ['tt2275949']
# Chris Farley ['tt2275913']
# Ego Nwodim ['tt6110318', 'tt3598030', 'tt0072562', 'tt7379494']
# Mike O'Brien ['tt2300919']
# Leslie Jones ['tt0104423']
# Yvonne Hudson ['tt2355949']
# Tracy Morgan ['tt0063892']
# Brooks Wheelan ['tt10050772', 'tt0072562', 'tt1600194', 'tt5244974']
# Terry Sweeney ['tt2386353', 'tt2576688', 'tt3313760', 'tt3517306']
# Kyle Mooney ['tt2386353', 'tt2576688', 'tt3313760', 'tt3517306']
# Bill Murray ['tt2243836']
# Dennis Miller ['tt1275472']
# Cecily Strong ['tt0072562', 'tt11808942', 'tt2702724', 'tt1289401']
# Chris Farley ['tt2328612']
# Bill Murray ['tt2356940']
# Jeff Richards ['tt3218622', 'tt5648234', 'tt2378652', 'tt11940818']
# Aidy Bryant ['tt5462602', 'tt11092142', 'tt8962130', 'tt0072562']
# Leslie Jones ['tt0297607', 'tt0360255', 'tt0358809', 'tt4568496']
# Terry Sweeney ['tt0297607', 'tt0360255', 'tt0358809', 'tt4568496']
# Mike O'Brien ['tt0297607', 'tt0360255', 'tt0358809', 'tt4568496']
# Mike O'Brien ['tt2423776']
# Chris Elliott ['tt2423776']
# Tom Schiller ['tt9068272']
# Leslie Jones ['tt1957867']
# Terry Sweeney ['tt2474812']
# Rich Hall ['tt1650554']
# Chris Redd ['tt3960412', 'tt5884792', 'tt7286456', 'tt0072562']
# Phil Hartman ['tt3960412', 'tt5884792', 'tt7286456', 'tt0072562']
# Tim Robinson ['tt2582038']
# Mike O'Brien ['tt2625536']
# Rich Hall ['tt2369573']
# Seth Meyers ['tt0124932']
# Tim Robinson ['tt0124932']
# Jeff Richards ['tt2671586']
# Victoria Jackson ['tt2307673']
# Tom Davis ['tt2728770']
# Mike Myers ['tt0299712']
# Leslie Jones ['tt2803888']
# Sarah Sherman ['tt2803096']
# Sarah Sherman ['tt2261238']
# Tom Davis ['tt4742812', 'tt2828570', 'tt3503754', 'tt5774598']
# Bill Murray ['tt4742812', 'tt2828570', 'tt3503754', 'tt5774598']
# Dennis Miller ['tt4742812', 'tt2828570', 'tt3503754', 'tt5774598']
# Mike O'Brien ['tt4742812', 'tt2828570', 'tt3503754', 'tt5774598']
# Dennis Miller ['tt2866916']
# Brad Hall ['tt0122827']
# Dennis Miller ['tt0123338']
# Mike O'Brien ['tt3856408', 'tt3972208', 'tt1535977']
# Leslie Jones ['tt3856408', 'tt3972208', 'tt1535977']
# Mike Myers ['tt2916548']
# Mark McKinney ['tt2954994']
# Brad Hall ['tt2953902']
# Tim Robinson ['tt7525600', 'tt2826134', 'tt7525638', 'tt6227116']
# Alex Moffat ['tt9866072', 'tt1217217', 'tt5848272', 'tt3219194']
# Tracy Morgan ['tt0100332']
# Chris Rock ['tt2357748']
# Bill Murray ['tt2357748']
# Bill Murray ['tt3091734']
# Bill Murray ['tt3147486']
# Heidi Gardner ['tt4180560', 'tt5101204', 'tt10324166', 'tt5619332']
# Tom Davis ['tt0133302']
# Brad Hall ['tt3162968']
# Mike Myers ['tt3185956']
# Molly Shannon ['tt0362542']
# Alex Moffat ['tt0362542']
# Bill Murray ['tt3231836']
# Jim Downey ['tt3281976']
# Christopher Guest ['tt3384430']
# Chris Parnell ['tt3402362']
# Tom Davis ['tt2510894', 'tt4624424', 'tt4633694', 'tt5220122']
# Chris Elliott ['tt3449744']
# Tom Davis ['tt3512322']
# Dennis Miller ['tt3458560']
# Jeff Richards ['tt3458560']
# Mark McKinney ['tt1179069']
# Bowen Yang ['tt2587452', 'tt6078096', 'tt2452244']
# Victoria Jackson ['tt3172618']
# Tim Robinson ['tt8909686', 'tt14435296', 'tt0199257', 'tt8909538']
# Bill Murray ['tt0115367']
# Chris Parnell ['tt0115367']
# Bill Murray ['tt3603706']
# Sarah Sherman ['tt4575056', 'tt2630898', 'tt3548962', 'tt3562626']
# Michael O'Donoghue ['tt0084264']
# Lauren Holt ['tt3597448']
# Jeff Richards ['tt3650844']
# Tom Davis ['tt3793204']
# Leslie Jones ['tt3800692', 'tt4056158']
# Sarah Sherman ['tt3815734']
# Kyle Mooney ['tt3823130']
# Jeff Richards ['tt3872944']
# Bill Murray ['tt3872944']
# Casey Wilson ['tt3263490']
# Tom Davis ['tt3970482']
# Sarah Sherman ['tt3970482']
# Chris Elliott ['tt8386350']
# Bill Murray ['tt3790306']
# Tim Robinson ['tt3790306']
# Sarah Sherman ['tt3790306']
# Rich Hall ['tt3790306']
# Will Ferrell ['tt0061240', 'tt0058797', 'tt0061296', 'tt0062994']
# Chris Elliott ['tt4203440']
# Mike O'Brien ['tt4475006']
# Alex Moffat ['tt3381008', 'tt5104604', 'tt2652092', 'tt5628302']
# Tim Robinson ['tt4049528']
# Bill Murray ['tt4571940']
# Jeff Richards ['tt3696804']
# Christopher Guest ['tt4334642', 'tt1024855']
# Rob Schneider ['tt4432798']
# Dan Vitale ['tt4656450', 'tt5903450']
# Phil Hartman ['tt4662448']
# Mike Myers ['tt4670472']
# Heidi Gardner ['tt4670472']
# Mike Myers ['tt4497152']
# Dean Edwards ['tt0122905']
# Jeff Richards ['tt4780202']
# Brad Hall ['tt1554356']
# Mark McKinney ['tt6225166']
# Mark McKinney ['tt5441646', 'tt4823678']
# Phil Hartman ['tt4828104']
# Fred Wolf ['tt3910602', 'tt10222674', 'tt0072562']
# Phil Hartman ['tt4701488']
# Mike Myers ['tt4853866']
# Chris Farley ['tt4853866']
# Victoria Jackson ['tt4906964']
# Sarah Sherman ['tt9534540', 'tt15467926', 'tt8425308', 'tt14601874']
# Lauren Holt ['tt8394996', 'tt8937092', 'tt0072562', 'tt7546290']
# Tim Robinson ['tt4661598']
# Molly Shannon ['tt3675186']
# Chris Elliott ['tt5124078']
# Chris Farley ['tt0142235']
# Brad Hall ['tt5173520', 'tt6738058']
# Mike O'Brien ['tt3906560']
# Rich Hall ['tt3906560']
# Mark McKinney ['tt3739110']
# Phil Hartman ['tt5298646']
# Chris Rock ['tt5346900']
# Mike O'Brien ['tt7119506', 'tt5352578']
# Mike Myers ['tt5442834', 'tt6137590']
# Michael O'Donoghue ['tt5442834', 'tt6137590']
# Mike Myers ['tt3109150']
# Mike O'Brien ['tt5542640']
# Jeff Richards ['tt3859146']
# Mark McKinney ['tt1216491', 'tt0795461', 'tt6285944']
# Tom Davis ['tt5631362', 'tt5631298']
# Leslie Jones ['tt0093204']
# Mark McKinney ['tt2954994']
# Dennis Miller ['tt2114006']
# Dennis Miller ['tt2114006']
# Mike O'Brien ['tt4977374']
# Will Ferrell ['tt5779664']
# Bill Murray ['tt5156614']
# Michael O'Donoghue ['tt5880050']
# Dean Edwards ['tt5896628']
# Sarah Sherman ['tt5924202']
# Sarah Sherman ['tt5924202']
# Victoria Jackson ['tt5941780']
# Tom Davis ['tt7689318', 'tt6074820', 'tt6063510']
# Sarah Sherman ['tt7689318', 'tt6074820', 'tt6063510']
# Tom Davis ['tt5993092']
# Tom Davis ['tt7252334', 'tt6142826', 'tt5870978', 'tt10607616']
# Mike O'Brien ['tt6157660']
# Dean Edwards ['tt6166222']
# Chris Elliott ['tt6185624']
# Dennis Miller ['tt11993098']
# Dean Edwards ['tt11993098']
# Andrew Dismukes ['tt14508698', 'tt0072562', 'tt13858722', 'tt6279022']
# Chris Farley ['tt6329792']
# Siobhan Fallon ['tt6463510']
# Leslie Jones ['tt6464314']
# Jeff Richards ['tt6512646']
# Mike O'Brien ['tt2998406']
# Chris Elliott ['tt6264596']
# Tim Robinson ['tt6391108']
# Seth Meyers ['tt6528132', 'tt0496571']
# Pete Davidson ['tt6806604']
# Alex Moffat ['tt6851750']
# Colin Quinn ['tt3948764']
# Chris Elliott ['tt7233816']
# Dean Edwards ['tt6186672', 'tt0354333', 'tt1565436']
# Leslie Jones ['tt6186672', 'tt0354333', 'tt1565436']
# Rich Hall ['tt8364112', 'tt7286604']
# Mike Myers ['tt1302137', 'tt0460843']
# Tom Davis ['tt7309462']
# Chris Parnell ['tt7309462']
# Michael O'Donoghue ['tt7465694', 'tt8526284', 'tt7615118']
# Victoria Jackson ['tt0383760']
# Mike O'Brien ['tt7493170']
# Mike O'Brien ['tt7528072']
# Tracy Morgan ['tt7528072']
# Tracy Morgan ['tt7587656']
# Colin Quinn ['tt7587656']
# Leslie Jones ['tt7604526']
# Joe Piscopo ['tt7604526']
# Tom Davis ['tt7638698']
# Brad Hall ['tt0121946']
# Rob Schneider ['tt2642912']
# Mike Myers ['tt2642912']
# Tim Robinson ['tt0112193', 'tt0396362', 'tt0335620', 'tt9090184']
# Mike O'Brien ['tt0112193', 'tt0396362', 'tt0335620', 'tt9090184']
# Tracy Morgan ['tt11833964', 'tt3644198']
# Dennis Miller ['tt3471592']
# Chris Elliott ['tt3471592']
# Brad Hall ['tt8106790']
# Julia Sweeney ['tt8106790']
# Chris Rock ['tt8106790']
# Rob Schneider ['tt11239422', 'tt8280446']
# Punkie Johnson ['tt7242698', 'tt5821764', 'tt5117666', 'tt7778796']
# Sarah Sherman ['tt8218988']
# Michael O'Donoghue ['tt1715425']
# Mike O'Brien ['tt8554874']
# Chris Parnell ['tt7396544']
# Jim Downey ['tt7396544']
# Chris Farley ['tt7396544']
# Mary Gross ['tt0423652']

# %%
names_title_dict
# Out:
# {'John Belushi': [['tt0078723', 'tt0072562', 'tt0077975', 'tt0080455']],
#  'Dan Aykroyd': [['tt0097428', 'tt0118747', 'tt0087332', 'tt0080455']],
#  'Bill Murray': [['tt5156614']],
#  'Mike Myers': [['tt1302137', 'tt0460843']],
#  'Chevy Chase': [['tt0085995', 'tt0097958', 'tt0080487', 'tt0092086']],
#  'Billy Crystal': [['tt0101587', 'tt0098635', 'tt0113097', 'tt0122933']],
#  'Joan Cusack': [['tt0119229', 'tt1659337', 'tt0119360', 'tt0096463']],
#  'Robert Downey Jr.': [['tt1300854', 'tt0371746', 'tt4154796', 'tt0988045']],
#  'Chris Farley': [['tt6329792']],
#  'Janeane Garofalo': [['tt0382932', 'tt0132347', 'tt0117979', 'tt0243655']],
#  'Julia Louis-Dreyfus': [['tt0462128', 'tt1759761', 'tt2390361', 'tt0098904']],
#  'Eddie Murphy': [['tt0492509']],
#  'Jim Belushi': [['tt0097637', 'tt0072562', 'tt0117468', 'tt0095963']],
#  'Dana Carvey': [['tt0072562', 'tt0108525', 'tt0105793', 'tt0295427']],
#  'Adam Sandler': [['tt13689618', 'tt10428498', 'tt0068120', 'tt12116598']],
#  'Christopher Guest': [['tt4334642', 'tt1024855']],
#  'Anthony Michael Hall': [['tt0468569',
#    'tt2361317',
#    'tt4758646',
#    'tt1100089']],
#  'Jon Lovitz': [['tt0104694', 'tt0107659', 'tt0147612', 'tt0437863']],
#  'Jay Mohr': [['tt0116695', 'tt0120241', 'tt0139239', 'tt0180052']],
#  'Randy Quaid': [['tt0097958', 'tt0116629', 'tt0116778', 'tt0388795']],
#  'Chris Rock': [['tt5346900']],
#  'Rob Schneider': [['tt11239422', 'tt8280446']],
#  'Martin Short': [['tt1791798', 'tt0938980', 'tt5747320', 'tt1297329']],
#  'Ben Stiller': [['tt0196229', 'tt0359950', 'tt0942385', 'tt1608290']],
#  'Damon Wayans': [['tt0110443', 'tt0104897', 'tt0273855', 'tt0102266']],
#  'Christine Ebersole': [['tt0115697', 'tt0993846', 'tt0086879', 'tt0110989']],
#  'Will Ferrell': [['tt5779664']],
#  'Jane Curtin': [['tt0106598', 'tt0115082', 'tt0086742', 'tt1155056']],
#  'Nora Dunn': [['tt0405336', 'tt0910936', 'tt0157503', 'tt0120188']],
#  'Tim Meadows': [['tt11394158']],
#  'Kevin Nealon': [['tt0072562', 'tt0116483', 'tt0439100', 'tt0120888']],
#  'David Spade': [['tt0245686', 'tt0120917', 'tt0437863', 'tt0114694']],
#  'Fred Armisen': [['tt0357413', 'tt1282140', 'tt0072562', 'tt1780441']],
#  'Peter Aykroyd': [['tt0106598', 'tt0095687', 'tt0090056', 'tt0102558']],
#  'Morwenna Banks': [['tt0760141', 'tt0466664', 'tt2245003', 'tt5839960']],
#  'Jim Breuer': [['tt1222817', 'tt0120693', 'tt0120913', 'tt0144168']],
#  'A. Whitney Brown': [['tt0096708', 'tt0072562', 'tt0166039', 'tt1094991']],
#  'Beth Cahill': [['tt0155764', 'tt0262411', 'tt0164930', 'tt0072562']],
#  'Ellen Cleghorne': [['tt0120591', 'tt0200550', 'tt2126357', 'tt0185431']],
#  'George Coe': [['tt1399103', 'tt0089901', 'tt0073747', 'tt0092666']],
#  'Pete Davidson': [['tt6806604']],
#  'Tom Davis': [['tt7638698']],
#  'Denny Dillon': [['tt0475276', 'tt0098780', 'tt0268380', 'tt0076666']],
#  'Brian Doyle-Murray': [['tt0105793', 'tt0102138', 'tt0080487', 'tt0097958']],
#  'Rachel Dratch': [['tt1564367', 'tt0389860', 'tt0814331', 'tt8169446']],
#  'Robin Duke': [['tt0075578', 'tt0117108', 'tt0107048', 'tt0072562']],
#  'Dean Edwards': [['tt6186672', 'tt0354333', 'tt1565436']],
#  'Chris Elliott': [['tt7233816']],
#  'Jimmy Fallon': [['tt6133466']],
#  'Tina Fey': [['tt1850457', 'tt0377092', 'tt1279935', 'tt0496424']],
#  'Will Forte': [['tt3230454', 'tt1490017', 'tt1470023', 'tt1821549']],
#  'Al Franken': [['tt0114571', 'tt0368008', 'tt0086465', 'tt0072562']],
#  'Ana Gasteyer': [['tt0207201', 'tt1232200', 'tt4366830', 'tt0377092']],
#  'Gilbert Gottfried': [['tt0103639', 'tt0092644', 'tt0098987', 'tt0100419']],
#  'Mary Gross': [['tt0423652']],
#  'Bill Hader': [['tt1571249', 'tt3152624', 'tt7349950', 'tt2096673']],
#  'Brad Hall': [['tt8106790']],
#  'Rich Hall': [['tt8364112', 'tt7286604']],
#  'Darrell Hammond': [['tt0799949', 'tt0118747', 'tt0306047', 'tt0072562']],
#  'Phil Hartman': [['tt5298646']],
#  'Jan Hooks': [['tt0103776', 'tt0115082', 'tt0106598', 'tt0089791']],
#  'Yvonne Hudson': [['tt2355949']],
#  'Melanie Hutsell': [['tt4789300', 'tt1478338', 'tt0072562', 'tt2191701']],
#  'Victoria Jackson': [['tt0383760']],
#  'Leslie Jones': [['tt7604526']],
#  'Chris Kattan': [['tt0120770', 'tt0279493', 'tt2479478', 'tt0185371']],
#  'Tim Kazurinsky': [['tt0090583', 'tt0089822', 'tt0082801', 'tt0072562']],
#  'Laura Kightlinger': [['tt4116284', 'tt8324422', 'tt0460619', 'tt0157246']],
#  'Taran Killam': [['tt2024544', 'tt0072562', 'tt5689068', 'tt4000956']],
#  'David Koechner': [['tt0425061', 'tt0357413', 'tt0427944', 'tt1229340']],
#  'Gary Kroeger': [['tt0200525', 'tt0072562', 'tt0046593', 'tt0086765']],
#  'Matthew Laurance': [['tt0112111', 'tt0085475', 'tt0098772', 'tt0090060']],
#  'Gail Matthius': [['tt0072562', 'tt0162796', 'tt0083530', 'tt0103373']],
#  'Michael McKean': [['tt0129910']],
#  'Mark McKinney': [['tt2954994']],
#  'Kate McKinnon': [['tt0092225']],
#  'Laurie Metcalf': [['tt0094540', 'tt0120082', 'tt0114709', 'tt4925292']],
#  'Dennis Miller': [['tt3471592']],
#  'Jerry Minor': [['tt0401003']],
#  'Tracy Morgan': [['tt11833964', 'tt3644198']],
#  'Garrett Morris': [['tt0072562', 'tt0478970', 'tt0106598', 'tt0278488']],
#  'Laraine Newman': [['tt0102719', 'tt0106598', 'tt0116705', 'tt0120669']],
#  'Don Novello': [['tt0072562', 'tt0112642', 'tt0099674', 'tt0230011']],
#  "Mike O'Brien": [['tt8554874']],
#  "Michael O'Donoghue": [['tt1715425']],
#  'Cheri Oteri': [['tt0141369', 'tt0175142', 'tt0119528', 'tt0405336']],
#  'Chris Parnell': [['tt7396544']],
#  'Joe Piscopo': [['tt0092226', 'tt0072562', 'tt0094961', 'tt0087507']],
#  'Amy Poehler': [['tt2096673', 'tt0871426', 'tt1266020', 'tt0072562']],
#  'Emily Prager': [['tt0048860', 'tt0094674', 'tt0079583', 'tt0059992']],
#  'Colin Quinn': [['tt3948764']],
#  'Gilda Radner': [['tt0070290', 'tt0091178', 'tt0084049', 'tt0072562']],
#  'Tony Rosato': [['tt0075578', 'tt0117593', 'tt0088582', 'tt0207701']],
#  'Jeff Richards': [['tt6512646']],
#  'Ann Risley': [['tt0072562', 'tt0081554', 'tt0081518', 'tt0082525']],
#  'Tim Robinson': [['tt0112193', 'tt0396362', 'tt0335620', 'tt9090184']],
#  'Harry Shearer': [['tt0120382', 'tt0310281', 'tt0096697', 'tt0088258']],
#  'Charles Rocket': [['tt0120913', 'tt0099348', 'tt0108122', 'tt0109686']],
#  'Maya Rudolph': [['tt1727388', 'tt1176740', 'tt1478338', 'tt1791528']],
#  'Horatio Sanz': [['tt0285462', 'tt1920849', 'tt0215129', 'tt1045778']],
#  'Tom Schiller': [['tt9068272']],
#  'Paul Shaffer': [['tt0088258', 'tt0119282', 'tt0118747', 'tt4537842']],
#  'Molly Shannon': [['tt3675186']],
#  'Sarah Silverman': [['tt0332379', 'tt0821375', 'tt1772341', 'tt5848272']],
#  'Robert Smigel': [['tt0185431', 'tt0072562', 'tt0106052', 'tt0272338']],
#  'Pamela Stephenson': [['tt0080253', 'tt0086393', 'tt0082517', 'tt0199218']],
#  'Jason Sudeikis': [['tt1723121', 'tt10986410', 'tt4680182', 'tt1499658']],
#  'Julia Sweeney': [['tt2467372', 'tt0498994', 'tt8962130', 'tt10417836']],
#  'Terry Sweeney': [['tt2474812']],
#  'Kenan Thompson': [['tt0417148', 'tt0072562', 'tt0115231', 'tt0119215']],
#  'Danitra Vance': [['tt0098621', 'tt0102316', 'tt0102174', 'tt0086759']],
#  'Dan Vitale': [['tt4656450', 'tt5903450']],
#  'Patrick Weathers': [['tt1741243', 'tt1790886', 'tt1996346', 'tt0094291']],
#  'Casey Wilson': [['tt3263490']],
#  'Fred Wolf': [['tt3910602', 'tt10222674', 'tt0072562']],
#  'Alan Zweibel': [['tt0090459', 'tt0072562', 'tt0092925', 'tt0110687']],
#  'Seth Meyers': [['tt6528132', 'tt0496571']],
#  'Lauren Holt': [['tt8394996', 'tt8937092', 'tt0072562', 'tt7546290']],
#  'Michaela Watkins': [['tt1932718', 'tt1655460', 'tt2294677', 'tt1212436']],
#  'Heidi Gardner': [['tt4180560', 'tt5101204', 'tt10324166', 'tt5619332']],
#  'Sarah Sherman': [['tt8218988']],
#  'Bobby Moynihan': [['tt13622982', 'tt10662034', 'tt0072562']],
#  'Kristen Wiig': [['tt1478338', 'tt1608290', 'tt0359950', 'tt1571249']],
#  'Kyle Mooney': [['tt3823130']],
#  'Rob Riggle': [['tt2096672', 'tt1119646', 'tt0115147', 'tt1232829']],
#  'Finesse Mitchell': [['tt0785077', 'tt0072562', 'tt0951216', 'tt0790804']],
#  'Mikey Day': [['tt0072562', 'tt2076347', 'tt1217217', 'tt4000956']],
#  'Andy Samberg': [['tt0072562', 'tt3960412', 'tt2467372', 'tt9484998']],
#  'Paul Brittain': [['tt0837562', 'tt0072562', 'tt2176287', 'tt2510894']],
#  'Nasim Pedrad': [['tt6139732', 'tt1690953', 'tt10338160', 'tt2490326']],
#  'Colin Jost': [['tt0072562', 'tt1292566', 'tt1361336', 'tt6802400']],
#  'Abby Elliott': [['tt0072562', 'tt1291150', 'tt1663143', 'tt1411238']],
#  'John Milhiser': [['tt0072562', 'tt5990096', 'tt1289401', 'tt4061080']],
#  'Alex Moffat': [['tt6851750']],
#  'Aristotle Athari': [['tt9173436', 'tt5918784', 'tt5917146', 'tt7322648']],
#  'Jenny Slate': [['tt2709768', 'tt2948356', 'tt4481414', 'tt2910274']],
#  'Beck Bennett': [['tt3470600', 'tt7979580', 'tt5531466', 'tt1086064']],
#  'Vanessa Bayer': [['tt0072562', 'tt2989524', 'tt1711525', 'tt3152624']],
#  'Sasheer Zamata': [['tt4018068', 'tt11394332', 'tt4018066', 'tt6791096']],
#  'Noël Wells': [['tt0072562', 'tt7713450', 'tt6212496', 'tt9184820']],
#  'Luke Null': [['tt1545490', 'tt0072562', 'tt9881938', 'tt3146066']],
#  'Melissa Villaseñor': [['tt1809001', 'tt0072562', 'tt5848272', 'tt10682266']],
#  'Michael Che': [['tt0072562', 'tt12762460', 'tt0499556', 'tt2784678']],
#  'Jay Pharoah': [['tt0072562', 'tt5774044', 'tt1408253', 'tt7153766']],
#  'Jon Rudnitsky': [['tt0072562', 'tt5719700']],
#  'James Austin Johnson': [['tt0072562',
#    'tt8036272',
#    'tt3032476',
#    'tt0475290']],
#  'Chloe Fineman': [['tt0072562', 'tt8577458', 'tt6527474', 'tt5460226']],
#  'Ego Nwodim': [['tt6110318', 'tt3598030', 'tt0072562', 'tt7379494']],
#  'Brooks Wheelan': [['tt10050772', 'tt0072562', 'tt1600194', 'tt5244974']],
#  'Cecily Strong': [['tt0072562', 'tt11808942', 'tt2702724', 'tt1289401']],
#  'Aidy Bryant': [['tt5462602', 'tt11092142', 'tt8962130', 'tt0072562']],
#  'Chris Redd': [['tt3960412', 'tt5884792', 'tt7286456', 'tt0072562']],
#  'Jim Downey': [['tt3281976']],
#  'Bowen Yang': [['tt2587452', 'tt6078096', 'tt2452244']],
#  'Andrew Dismukes': [['tt14508698', 'tt0072562', 'tt13858722', 'tt6279022']],
#  'Siobhan Fallon': [['tt6463510']],
#  'Punkie Johnson': [['tt7242698', 'tt5821764', 'tt5117666', 'tt7778796']]}
